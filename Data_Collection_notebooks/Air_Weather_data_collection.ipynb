# %%
import pandas as pd
import numpy as np
import requests
import time
import osmnx as ox
from datetime import datetime

# ==========================================
# 1. CONFIGURATION
# ==========================================
OWM_API_KEY = "1c63d4b087353b1d4e226954d3db89cb"  # <--- PASTE KEY HERE
SATELLITES_PER_CITY = 5   # Center + 4 random points
RADIUS_KM = 5             # Radius to scatter points

# ==========================================
# 2. CITY DATA (Your List)
# ==========================================
TARGET_COUNTRIES = {
    "India": [
        "New Delhi", "Mumbai", "Bangalore", "Hyderabad", "Ahmedabad",
        "Chennai", "Kolkata", "Surat", "Pune", "Jaipur",
        "Lucknow", "Kanpur", "Nagpur", "Indore", "Thane",
        "Bhopal", "Visakhapatnam", "Pimpri-Chinchwad", "Patna", "Vadodara",
        "Ghaziabad", "Ludhiana", "Agra", "Nashik", "Faridabad",
        "Meerut", "Rajkot", "Kalyan-Dombivli", "Vasai-Virar", "Varanasi",
        "Srinagar", "Aurangabad", "Dhanbad", "Amritsar", "Navi Mumbai",
        "Allahabad", "Howrah", "Ranchi", "Gwalior", "Jabalpur",
        "Coimbatore", "Vijayawada", "Jodhpur", "Madurai", "Raipur",
        "Kota", "Chandigarh", "Guwahati", "Solapur", "Hubli-Dharwad"
    ],
    "USA": [
        "New York", "Los Angeles", "Chicago", "Houston", "Phoenix",
        "Philadelphia", "San Antonio", "San Diego", "Dallas", "San Jose",
        "Austin", "Jacksonville", "Fort Worth", "Columbus", "Indianapolis",
        "Charlotte", "San Francisco", "Seattle", "Denver", "Oklahoma City",
        "Nashville", "El Paso", "Washington", "Boston", "Las Vegas",
        "Detroit", "Portland", "Memphis", "Louisville", "Baltimore",
        "Milwaukee", "Albuquerque", "Tucson", "Fresno", "Mesa",
        "Sacramento", "Atlanta", "Kansas City", "Colorado Springs", "Omaha",
        "Raleigh", "Miami", "Long Beach", "Virginia Beach", "Oakland",
        "Minneapolis", "Tulsa", "Tampa", "Arlington", "New Orleans"
    ],
    "China": [
        "Chongqing", "Shanghai", "Beijing", "Chengdu", "Guangzhou",
        "Shenzhen", "Tianjin", "Wuhan", "Dongguan", "Xi'an",
        "Hangzhou", "Foshan", "Nanjing", "Shenyang", "Qingdao",
        "Zhengzhou", "Changsha", "Kunming", "Jinan", "Shantou",
        "Hefei", "Harbin", "Suzhou", "Dalian", "Ningbo",
        "Xiamen", "Changchun", "Taiyuan", "Nanning", "Wuxi",
        "Guiyang", "Ürümqi", "Fuzhou", "Zibo", "Tangshan",
        "Zhongshan", "Yantai", "Baotou", "Lanzhou", "Huai'an",
        "Nanchang", "Daqing", "Weifang", "Handan", "Luoyang",
        "Linyi", "Xuzhou", "Quanzhou", "Changzhou", "Nantong"
    ],
    "Germany": [
        "Berlin", "Hamburg", "Munich", "Cologne", "Frankfurt",
        "Stuttgart", "Düsseldorf", "Leipzig", "Dortmund", "Essen",
        "Bremen", "Dresden", "Hanover", "Nuremberg", "Duisburg",
        "Bochum", "Wuppertal", "Bielefeld", "Bonn", "Münster",
        "Karlsruhe", "Mannheim", "Augsburg", "Wiesbaden", "Gelsenkirchen",
        "Mönchengladbach", "Braunschweig", "Chemnitz", "Kiel", "Aachen",
        "Halle", "Magdeburg", "Freiburg", "Krefeld", "Lübeck",
        "Oberhausen", "Erfurt", "Mainz", "Rostock", "Kassel",
        "Hagen", "Saarbrücken", "Hamm", "Potsdam", "Mülheim",
        "Ludwigshafen", "Oldenburg", "Leverkusen", "Osnabrück", "Solingen"
    ],
    "Brazil": [
        "São Paulo", "Rio de Janeiro", "Brasília", "Salvador", "Fortaleza",
        "Belo Horizonte", "Manaus", "Curitiba", "Recife", "Goiânia",
        "Belém", "Porto Alegre", "Guarulhos", "Campinas", "São Luís",
        "São Gonçalo", "Maceió", "Duque de Caxias", "Natal", "Teresina",
        "Campo Grande", "Nova Iguaçu", "João Pessoa", "Santo André", "São Bernardo do Campo",
        "Osasco", "Jaboatão dos Guararapes", "Uberlândia", "Contagem", "Sorocaba",
        "Aracaju", "Feira de Santana", "Cuiabá", "Joinville", "Juiz de Fora",
        "Londrina", "Niterói", "Aparecida de Goiânia", "Ananindeua", "Caxias do Sul",
        "Porto Velho", "Serra", "Vila Velha", "Florianópolis", "Mauá",
        "São Vicente", "Mogi das Cruzes", "Betim", "Santos", "Diadema"
    ],
    "Indonesia": [
        "Jakarta", "Surabaya", "Bekasi", "Bandung", "Medan",
        "Depok", "Tangerang", "Palembang", "Semarang", "Makassar",
        "South Tangerang", "Batam", "Bogor", "Pekanbaru", "Bandar Lampung",
        "Padang", "Malang", "Denpasar", "Samarinda", "Tasikmalaya",
        "Pontianak", "Banjarmasin", "Jambi", "Cimahi", "Balikpapan",
        "Manado", "Yogyakarta", "Surakarta", "Serang", "Mataram",
        "Kupang", "Palu", "Ambon", "Kendari", "Bengkulu",
        "Pangkal Pinang", "Jayapura", "Cilegon", "Tegal", "Probolinggo",
        "Binjai", "Sukabumi", "Pematangsiantar", "Cirebon", "Banda Aceh",
        "Tanjungpinang", "Gorontalo", "Dumai", "Metro", "Bontang"
    ],
    "Pakistan": [
        "Karachi", "Lahore", "Faisalabad", "Rawalpindi", "Gujranwala",
        "Peshawar", "Multan", "Hyderabad", "Islamabad", "Quetta",
        "Bahawalpur", "Sargodha", "Sialkot", "Sukkur", "Larkana",
        "Sheikhupura", "Rahim Yar Khan", "Jhang", "Dera Ghazi Khan", "Gujrat",
        "Sahiwal", "Wah Cantonment", "Mardan", "Kasur", "Okara",
        "Mingora", "Nawabshah", "Chiniot", "Kotri", "Kamoke",
        "Hafizabad", "Sadiqabad", "Mirpur Khas", "Burewala", "Kohat",
        "Khanewal", "Dadu", "Muzaffargarh", "Jacobabad", "Shikarpur",
        "Jaranwala", "Khanpur", "Tando Allahyar", "Khairpur", "Chishtian",
        "Abbottabad", "Daska", "Pakpattan", "Bahawalnagar", "Tando Adam"
    ],
    "Nigeria": [
        "Lagos", "Kano", "Ibadan", "Abuja", "Port Harcourt",
        "Benin City", "Jos", "Ilora", "Kaduna", "Enugu",
        "Zaria", "Warri", "Maiduguri", "Aba", "Onitsha",
        "Ogbomosho", "Ikare", "Ado Ekiti", "Bauchi", "Ilorin",
        "Akure", "Owerri", "Sokoto", "Ebute Ikorodu", "Calabar",
        "Uyo", "Minna", "Abeokuta", "Osogbo", "Ifẹ",
        "Makurdi", "Ondo", "Jimeta", "Gusau", "Mubi",
        "Umuahia", "Ife", "Oyo", "Awka", "Damaturu",
        "Iwo", "Ilesa", "Katsina", "Nnewi", "Bida",
        "Ikot Ekpene", "Lafia", "Okene", "Suleja", "Nguru"
    ],
    "Bangladesh": [
        "Dhaka", "Chittagong", "Khulna", "Rajshahi", "Comilla",
        "Sylhet", "Barisal", "Rangpur", "Narsingdi", "Narayanganj",
        "Gazipur", "Mymensingh", "Bogra", "Jessore", "Dinajpur",
        "Saidpur", "Cox's Bazar", "Tangail", "Pabna", "Sirajganj",
        "Nawabganj", "Kushtia", "Faridpur", "Jamalpur", "Naogaon",
        "Feni", "Brahmanbaria", "Tongī", "Shibganj", "Savār",
        "Kishoreganj", "Habiganj", "Chandpur", "Patiya", "Natore",
        "Lakshmipur", "Bhola", "Noakhali", "Manikganj", "Chuadanga",
        "Satkhira", "Madaripur", "Meherpur", "Sherpur", "Panchagarh",
        "Kurigram", "Gaibandha", "Nilphamari", "Lalmonirhat", "Magura"
    ],
    "Russia": [
        "Moscow", "Saint Petersburg", "Novosibirsk", "Yekaterinburg", "Kazan",
        "Nizhny Novgorod", "Chelyabinsk", "Omsk", "Samara", "Rostov-on-Don",
        "Ufa", "Krasnoyarsk", "Voronezh", "Perm", "Volgograd",
        "Saratov", "Krasnodar", "Tolyatti", "Izhevsk", "Ulyanovsk",
        "Barnaul", "Tyumen", "Irkutsk", "Khabarovsk", "Makhachkala",
        "Vladivostok", "Yaroslavl", "Tomsk", "Orenburg", "Novokuznetsk",
        "Kemerovo", "Ryazan", "Astrakhan", "Penza", "Naberezhnye Chelny",
        "Lipetsk", "Tula", "Kirov", "Cheboksary", "Kaliningrad",
        "Bryansk", "Kursk", "Ivanovo", "Magnitogorsk", "Ulan-Ude",
        "Tver", "Stavropol", "Nizhny Tagil", "Belgorod", "Arkhangelsk"
    ]
}

# ==========================================
# 3. HELPER FUNCTIONS
# ==========================================

def get_coordinates(city, country):
    """
    Uses OSM to get the lat/lon of the city center.
    """
    try:
        query = f"{city}, {country}"
        lat, lon = ox.geocode(query)
        return lat, lon
    except Exception as e:
        print(f"  [Error] Geocoding failed for {city}: {e}")
        return None, None

def fetch_weather_pollution(lat, lon):
    """
    Calls OpenWeatherMap APIs for Weather and Air Pollution.
    """
    data = {}
    
    # --- A. Current Weather ---
    try:
        url_w = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={OWM_API_KEY}&units=metric"
        res_w = requests.get(url_w).json()
        
        if res_w.get('cod') == 200:
            data['Temperature'] = res_w['main']['temp']
            data['Humidity'] = res_w['main']['humidity']
            data['Wind_Speed'] = res_w['wind']['speed']
            data['Wind_Direction'] = res_w['wind'].get('deg', 0)
            data['Weather_Condition'] = res_w['weather'][0]['main']
        else:
            print(f"    [API Error] Weather: {res_w.get('message')}")
    except Exception as e:
        print(f"    [Net Error] Weather: {e}")

    # --- B. Air Pollution ---
    try:
        url_p = f"http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={OWM_API_KEY}"
        res_p = requests.get(url_p).json()
        
        if 'list' in res_p:
            comp = res_p['list'][0]['components']
            main = res_p['list'][0]['main']
            
            data['AQI'] = main['aqi']
            data['CO'] = comp['co']
            data['NO'] = comp['no']
            data['NO2'] = comp['no2']
            data['O3'] = comp['o3']
            data['SO2'] = comp['so2']
            data['PM2_5'] = comp['pm2_5']
            data['PM10'] = comp['pm10']
            data['NH3'] = comp['nh3']
        else:
             print(f"    [API Error] Pollution: No list found")
    except Exception as e:
        print(f"    [Net Error] Pollution: {e}")

    return data

# ==========================================
# 4. MAIN LOOP
# ==========================================

def main():
    print("--- Starting Master Data Collection ---")
    print(f"Target: {len(TARGET_COUNTRIES)} countries.")
    
    all_data = []
    
    for country, cities in TARGET_COUNTRIES.items():
        print(f"\nProcessing Country: {country.upper()}")
        
        for city in cities:
            print(f"  > Processing {city}...", end=" ", flush=True)
            
            # 1. Get City Center
            center_lat, center_lon = get_coordinates(city, country)
            
            if center_lat is None:
                continue # Skip if geocoding failed
                
            # 2. Define Points (Center + Satellites)
            points_to_check = []
            
            # Add Center
            points_to_check.append({
                'Location_Type': 'City Center',
                'lat': center_lat, 'lon': center_lon
            })
            
            # Add Random Satellites
            for i in range(SATELLITES_PER_CITY - 1):
                theta = np.random.uniform(0, 2 * np.pi)
                dist = np.random.uniform(1, RADIUS_KM)
                
                delta_lat = (dist / 111.0) * np.cos(theta)
                delta_lon = (dist / (111.0 * np.cos(np.radians(center_lat)))) * np.sin(theta)
                
                points_to_check.append({
                    'Location_Type': f'Sector_{i+1}',
                    'lat': round(center_lat + delta_lat, 5),
                    'lon': round(center_lon + delta_lon, 5)
                })
            
            # 3. Fetch Data for these Points
            for pt in points_to_check:
                # API Call
                env_data = fetch_weather_pollution(pt['lat'], pt['lon'])
                
                # Construct Row
                row = {
                    'Country': country,
                    'City': city,
                    'Location_Type': pt['Location_Type'],
                    'Latitude': pt['lat'],
                    'Longitude': pt['lon'],
                    'Timestamp': time.time()
                }
                # Merge dictionaries
                row.update(env_data)
                all_data.append(row)
                
            print(f"Done ({SATELLITES_PER_CITY} pts)")
            # Sleep slightly to avoid rate limits (60 calls/min free tier)
            time.sleep(0.5) 

    # 5. Save Master Dataset
    df = pd.DataFrame(all_data)
    
    # Reorder columns nicely
    cols = ['Country', 'City', 'Location_Type', 'Latitude', 'Longitude', 
            'AQI', 'PM2_5', 'NO2', 'SO2', 'O3', 'CO', 'PM10', 
            'Temperature', 'Humidity', 'Wind_Speed', 'Weather_Condition']
    
    # Keep only columns that exist (in case of API errors)
    final_cols = [c for c in cols if c in df.columns]
    df = df[final_cols]
    
    filename = "Pollution_Weather_ten_countries.csv"
    df.to_csv(filename, index=False)
    print(f"\nSUCCESS! Collected {len(df)} rows.")
    print(f"Data saved to: {filename}")

if __name__ == "__main__":
    main()
# Out:
# --- Starting Master Data Collection ---
# Target: 10 countries.
#
# Processing Country: INDIA
#   > Processing New Delhi... Done (5 pts)
#   > Processing Mumbai... Done (5 pts)
#   > Processing Bangalore... Done (5 pts)
#   > Processing Hyderabad... Done (5 pts)
#   > Processing Ahmedabad... Done (5 pts)
#   > Processing Chennai... Done (5 pts)
#   > Processing Kolkata... Done (5 pts)
#   > Processing Surat... Done (5 pts)
#   > Processing Pune... Done (5 pts)
#   > Processing Jaipur... Done (5 pts)
#   > Processing Lucknow... Done (5 pts)
#   > Processing Kanpur... Done (5 pts)
#   > Processing Nagpur... Done (5 pts)
#   > Processing Indore... Done (5 pts)
#   > Processing Thane... Done (5 pts)
#   > Processing Bhopal... Done (5 pts)
#   > Processing Visakhapatnam... Done (5 pts)
#   > Processing Pimpri-Chinchwad... Done (5 pts)
#   > Processing Patna... Done (5 pts)
#   > Processing Vadodara... Done (5 pts)
#   > Processing Ghaziabad... Done (5 pts)
#   > Processing Ludhiana... Done (5 pts)
#   > Processing Agra... Done (5 pts)
#   > Processing Nashik... Done (5 pts)
#   > Processing Faridabad... Done (5 pts)
#   > Processing Meerut... Done (5 pts)
#   > Processing Rajkot... Done (5 pts)
#   > Processing Kalyan-Dombivli... Done (5 pts)
#   > Processing Vasai-Virar... Done (5 pts)
#   > Processing Varanasi... Done (5 pts)
#   > Processing Srinagar... Done (5 pts)
#   > Processing Aurangabad... Done (5 pts)
#   > Processing Dhanbad... Done (5 pts)
#   > Processing Amritsar... Done (5 pts)
#   > Processing Navi Mumbai... Done (5 pts)
#   > Processing Allahabad... Done (5 pts)
#   > Processing Howrah... Done (5 pts)
#   > Processing Ranchi... Done (5 pts)
#   > Processing Gwalior... Done (5 pts)
#   > Processing Jabalpur... Done (5 pts)
#   > Processing Coimbatore... Done (5 pts)
#   > Processing Vijayawada... Done (5 pts)
#   > Processing Jodhpur... Done (5 pts)
#   > Processing Madurai... Done (5 pts)
#   > Processing Raipur... Done (5 pts)
#   > Processing Kota... Done (5 pts)
#   > Processing Chandigarh... Done (5 pts)
#   > Processing Guwahati... Done (5 pts)
#   > Processing Solapur... Done (5 pts)
#   > Processing Hubli-Dharwad... Done (5 pts)
#
# Processing Country: USA
#   > Processing New York... Done (5 pts)
#   > Processing Los Angeles... Done (5 pts)
#   > Processing Chicago... Done (5 pts)
#   > Processing Houston... Done (5 pts)
#   > Processing Phoenix... Done (5 pts)
#   > Processing Philadelphia... Done (5 pts)
#   > Processing San Antonio... Done (5 pts)
#   > Processing San Diego... Done (5 pts)
#   > Processing Dallas... Done (5 pts)
#   > Processing San Jose... Done (5 pts)
#   > Processing Austin... Done (5 pts)
#   > Processing Jacksonville... Done (5 pts)
#   > Processing Fort Worth... Done (5 pts)
#   > Processing Columbus... Done (5 pts)
#   > Processing Indianapolis... Done (5 pts)
#   > Processing Charlotte... Done (5 pts)
#   > Processing San Francisco... Done (5 pts)
#   > Processing Seattle... Done (5 pts)
#   > Processing Denver... Done (5 pts)
#   > Processing Oklahoma City... Done (5 pts)
#   > Processing Nashville... Done (5 pts)
#   > Processing El Paso... Done (5 pts)
#   > Processing Washington... Done (5 pts)
#   > Processing Boston... Done (5 pts)
#   > Processing Las Vegas... Done (5 pts)
#   > Processing Detroit... Done (5 pts)
#   > Processing Portland... Done (5 pts)
#   > Processing Memphis... Done (5 pts)
#   > Processing Louisville... Done (5 pts)
#   > Processing Baltimore... Done (5 pts)
#   > Processing Milwaukee... Done (5 pts)
#   > Processing Albuquerque... Done (5 pts)
#   > Processing Tucson... Done (5 pts)
#   > Processing Fresno... Done (5 pts)
#   > Processing Mesa... Done (5 pts)
#   > Processing Sacramento... Done (5 pts)
#   > Processing Atlanta... Done (5 pts)
#   > Processing Kansas City... Done (5 pts)
#   > Processing Colorado Springs... Done (5 pts)
#   > Processing Omaha... Done (5 pts)
#   > Processing Raleigh... Done (5 pts)
#   > Processing Miami... Done (5 pts)
#   > Processing Long Beach... Done (5 pts)
#   > Processing Virginia Beach... Done (5 pts)
#   > Processing Oakland... Done (5 pts)
#   > Processing Minneapolis... Done (5 pts)
#   > Processing Tulsa... Done (5 pts)
#   > Processing Tampa... Done (5 pts)
#   > Processing Arlington... Done (5 pts)
#   > Processing New Orleans... Done (5 pts)
#
# Processing Country: CHINA
#   > Processing Chongqing... Done (5 pts)
#   > Processing Shanghai... Done (5 pts)
#   > Processing Beijing... Done (5 pts)
#   > Processing Chengdu... Done (5 pts)
#   > Processing Guangzhou... Done (5 pts)
#   > Processing Shenzhen... Done (5 pts)
#   > Processing Tianjin... Done (5 pts)
#   > Processing Wuhan... Done (5 pts)
#   > Processing Dongguan... Done (5 pts)
#   > Processing Xi'an... Done (5 pts)
#   > Processing Hangzhou... Done (5 pts)
#   > Processing Foshan... Done (5 pts)
#   > Processing Nanjing... Done (5 pts)
#   > Processing Shenyang... Done (5 pts)
#   > Processing Qingdao... Done (5 pts)
#   > Processing Zhengzhou... Done (5 pts)
#   > Processing Changsha... Done (5 pts)
#   > Processing Kunming... Done (5 pts)
#   > Processing Jinan... Done (5 pts)
#   > Processing Shantou... Done (5 pts)
#   > Processing Hefei... Done (5 pts)
#   > Processing Harbin... Done (5 pts)
#   > Processing Suzhou... Done (5 pts)
#   > Processing Dalian... Done (5 pts)
#   > Processing Ningbo... Done (5 pts)
#   > Processing Xiamen... Done (5 pts)
#   > Processing Changchun... Done (5 pts)
#   > Processing Taiyuan... Done (5 pts)
#   > Processing Nanning... Done (5 pts)
#   > Processing Wuxi... Done (5 pts)
#   > Processing Guiyang... Done (5 pts)
#   > Processing Ürümqi... Done (5 pts)
#   > Processing Fuzhou... Done (5 pts)
#   > Processing Zibo... Done (5 pts)
#   > Processing Tangshan... Done (5 pts)
#   > Processing Zhongshan... Done (5 pts)
#   > Processing Yantai...   [Error] Geocoding failed for Yantai: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#   > Processing Baotou... Done (5 pts)
#   > Processing Lanzhou... Done (5 pts)
#   > Processing Huai'an... Done (5 pts)
#   > Processing Nanchang... Done (5 pts)
#   > Processing Daqing... Done (5 pts)
#   > Processing Weifang... Done (5 pts)
#   > Processing Handan... Done (5 pts)
#   > Processing Luoyang... Done (5 pts)
#   > Processing Linyi... Done (5 pts)
#   > Processing Xuzhou... Done (5 pts)
#   > Processing Quanzhou... Done (5 pts)
#   > Processing Changzhou... Done (5 pts)
#   > Processing Nantong... Done (5 pts)
#
# Processing Country: GERMANY
#   > Processing Berlin... Done (5 pts)
#   > Processing Hamburg... Done (5 pts)
#   > Processing Munich... Done (5 pts)
#   > Processing Cologne... Done (5 pts)
#   > Processing Frankfurt... Done (5 pts)
#   > Processing Stuttgart... Done (5 pts)
#   > Processing Düsseldorf... Done (5 pts)
#   > Processing Leipzig... Done (5 pts)
#   > Processing Dortmund... Done (5 pts)
#   > Processing Essen... Done (5 pts)
#   > Processing Bremen... Done (5 pts)
#   > Processing Dresden... Done (5 pts)
#   > Processing Hanover... Done (5 pts)
#   > Processing Nuremberg... Done (5 pts)
#   > Processing Duisburg... Done (5 pts)
#   > Processing Bochum... Done (5 pts)
#   > Processing Wuppertal... Done (5 pts)
#   > Processing Bielefeld... Done (5 pts)
#   > Processing Bonn... Done (5 pts)
#   > Processing Münster... Done (5 pts)
#   > Processing Karlsruhe... Done (5 pts)
#   > Processing Mannheim... Done (5 pts)
#   > Processing Augsburg... Done (5 pts)
#   > Processing Wiesbaden... Done (5 pts)
#   > Processing Gelsenkirchen... Done (5 pts)
#   > Processing Mönchengladbach... Done (5 pts)
#   > Processing Braunschweig... Done (5 pts)
#   > Processing Chemnitz... Done (5 pts)
#   > Processing Kiel... Done (5 pts)
#   > Processing Aachen... Done (5 pts)
#   > Processing Halle... Done (5 pts)
#   > Processing Magdeburg... Done (5 pts)
#   > Processing Freiburg... Done (5 pts)
#   > Processing Krefeld... Done (5 pts)
#   > Processing Lübeck... Done (5 pts)
#   > Processing Oberhausen... Done (5 pts)
#   > Processing Erfurt... Done (5 pts)
#   > Processing Mainz... Done (5 pts)
#   > Processing Rostock... Done (5 pts)
#   > Processing Kassel... Done (5 pts)
#   > Processing Hagen... Done (5 pts)
#   > Processing Saarbrücken... Done (5 pts)
#   > Processing Hamm... Done (5 pts)
#   > Processing Potsdam... Done (5 pts)
#   > Processing Mülheim... Done (5 pts)
#   > Processing Ludwigshafen... Done (5 pts)
#   > Processing Oldenburg... Done (5 pts)
#   > Processing Leverkusen... Done (5 pts)
#   > Processing Osnabrück... Done (5 pts)
#   > Processing Solingen... Done (5 pts)
#
# Processing Country: BRAZIL
#   > Processing São Paulo... Done (5 pts)
#   > Processing Rio de Janeiro... Done (5 pts)
#   > Processing Brasília... Done (5 pts)
#   > Processing Salvador... Done (5 pts)
#   > Processing Fortaleza... Done (5 pts)
#   > Processing Belo Horizonte... Done (5 pts)
#   > Processing Manaus... Done (5 pts)
#   > Processing Curitiba... Done (5 pts)
#   > Processing Recife... Done (5 pts)
#   > Processing Goiânia... Done (5 pts)
#   > Processing Belém... Done (5 pts)
#   > Processing Porto Alegre... Done (5 pts)
#   > Processing Guarulhos... Done (5 pts)
#   > Processing Campinas... Done (5 pts)
#   > Processing São Luís... Done (5 pts)
#   > Processing São Gonçalo... Done (5 pts)
#   > Processing Maceió... Done (5 pts)
#   > Processing Duque de Caxias... Done (5 pts)
#   > Processing Natal... Done (5 pts)
#   > Processing Teresina... Done (5 pts)
#   > Processing Campo Grande... Done (5 pts)
#   > Processing Nova Iguaçu... Done (5 pts)
#   > Processing João Pessoa... Done (5 pts)
#   > Processing Santo André... Done (5 pts)
#   > Processing São Bernardo do Campo... Done (5 pts)
#   > Processing Osasco... Done (5 pts)
#   > Processing Jaboatão dos Guararapes... Done (5 pts)
#   > Processing Uberlândia... Done (5 pts)
#   > Processing Contagem... Done (5 pts)
#   > Processing Sorocaba... Done (5 pts)
#   > Processing Aracaju... Done (5 pts)
#   > Processing Feira de Santana... Done (5 pts)
#   > Processing Cuiabá... Done (5 pts)
#   > Processing Joinville... Done (5 pts)
#   > Processing Juiz de Fora... Done (5 pts)
#   > Processing Londrina... Done (5 pts)
#   > Processing Niterói... Done (5 pts)
#   > Processing Aparecida de Goiânia... Done (5 pts)
#   > Processing Ananindeua... Done (5 pts)
#   > Processing Caxias do Sul... Done (5 pts)
#   > Processing Porto Velho... Done (5 pts)
#   > Processing Serra... Done (5 pts)
#   > Processing Vila Velha... Done (5 pts)
#   > Processing Florianópolis... Done (5 pts)
#   > Processing Mauá... Done (5 pts)
#   > Processing São Vicente... Done (5 pts)
#   > Processing Mogi das Cruzes... Done (5 pts)
#   > Processing Betim... Done (5 pts)
#   > Processing Santos... Done (5 pts)
#   > Processing Diadema... Done (5 pts)
#
# Processing Country: INDONESIA
#   > Processing Jakarta... Done (5 pts)
#   > Processing Surabaya... Done (5 pts)
#   > Processing Bekasi... Done (5 pts)
#   > Processing Bandung... Done (5 pts)
#   > Processing Medan... Done (5 pts)
#   > Processing Depok... Done (5 pts)
#   > Processing Tangerang... Done (5 pts)
#   > Processing Palembang... Done (5 pts)
#   > Processing Semarang... Done (5 pts)
#   > Processing Makassar... Done (5 pts)
#   > Processing South Tangerang... Done (5 pts)
#   > Processing Batam... Done (5 pts)
#   > Processing Bogor... Done (5 pts)
#   > Processing Pekanbaru... Done (5 pts)
#   > Processing Bandar Lampung... Done (5 pts)
#   > Processing Padang... Done (5 pts)
#   > Processing Malang... Done (5 pts)
#   > Processing Denpasar... Done (5 pts)
#   > Processing Samarinda... Done (5 pts)
#   > Processing Tasikmalaya... Done (5 pts)
#   > Processing Pontianak... Done (5 pts)
#   > Processing Banjarmasin... Done (5 pts)
#   > Processing Jambi... Done (5 pts)
#   > Processing Cimahi... Done (5 pts)
#   > Processing Balikpapan... Done (5 pts)
#   > Processing Manado... Done (5 pts)
#   > Processing Yogyakarta... Done (5 pts)
#   > Processing Surakarta... Done (5 pts)
#   > Processing Serang... Done (5 pts)
#   > Processing Mataram... Done (5 pts)
#   > Processing Kupang... Done (5 pts)
#   > Processing Palu... Done (5 pts)
#   > Processing Ambon... Done (5 pts)
#   > Processing Kendari... Done (5 pts)
#   > Processing Bengkulu... Done (5 pts)
#   > Processing Pangkal Pinang... Done (5 pts)
#   > Processing Jayapura... Done (5 pts)
#   > Processing Cilegon... Done (5 pts)
#   > Processing Tegal... Done (5 pts)
#   > Processing Probolinggo... Done (5 pts)
#   > Processing Binjai... Done (5 pts)
#   > Processing Sukabumi... Done (5 pts)
#   > Processing Pematangsiantar... Done (5 pts)
#   > Processing Cirebon... Done (5 pts)
#   > Processing Banda Aceh... Done (5 pts)
#   > Processing Tanjungpinang... Done (5 pts)
#   > Processing Gorontalo... Done (5 pts)
#   > Processing Dumai... Done (5 pts)
#   > Processing Metro... Done (5 pts)
#   > Processing Bontang... Done (5 pts)
#
# Processing Country: PAKISTAN
#   > Processing Karachi... Done (5 pts)
#   > Processing Lahore... Done (5 pts)
#   > Processing Faisalabad... Done (5 pts)
#   > Processing Rawalpindi... Done (5 pts)
#   > Processing Gujranwala... Done (5 pts)
#   > Processing Peshawar... Done (5 pts)
#   > Processing Multan... Done (5 pts)
#   > Processing Hyderabad... Done (5 pts)
#   > Processing Islamabad... Done (5 pts)
#   > Processing Quetta... Done (5 pts)
#   > Processing Bahawalpur... Done (5 pts)
#   > Processing Sargodha... Done (5 pts)
#   > Processing Sialkot... Done (5 pts)
#   > Processing Sukkur... Done (5 pts)
#   > Processing Larkana... Done (5 pts)
#   > Processing Sheikhupura... Done (5 pts)
#   > Processing Rahim Yar Khan... Done (5 pts)
#   > Processing Jhang... Done (5 pts)
#   > Processing Dera Ghazi Khan... Done (5 pts)
#   > Processing Gujrat... Done (5 pts)
#   > Processing Sahiwal... Done (5 pts)
#   > Processing Wah Cantonment... Done (5 pts)
#   > Processing Mardan... Done (5 pts)
#   > Processing Kasur... Done (5 pts)
#   > Processing Okara... Done (5 pts)
#   > Processing Mingora... Done (5 pts)
#   > Processing Nawabshah... Done (5 pts)
#   > Processing Chiniot... Done (5 pts)
#   > Processing Kotri... Done (5 pts)
#   > Processing Kamoke... Done (5 pts)
#   > Processing Hafizabad... Done (5 pts)
#   > Processing Sadiqabad... Done (5 pts)
#   > Processing Mirpur Khas... Done (5 pts)
#   > Processing Burewala... Done (5 pts)
#   > Processing Kohat... Done (5 pts)
#   > Processing Khanewal... Done (5 pts)
#   > Processing Dadu... Done (5 pts)
#   > Processing Muzaffargarh... Done (5 pts)
#   > Processing Jacobabad... Done (5 pts)
#   > Processing Shikarpur... Done (5 pts)
#   > Processing Jaranwala... Done (5 pts)
#   > Processing Khanpur... Done (5 pts)
#   > Processing Tando Allahyar... Done (5 pts)
#   > Processing Khairpur... Done (5 pts)
#   > Processing Chishtian... Done (5 pts)
#   > Processing Abbottabad... Done (5 pts)
#   > Processing Daska... Done (5 pts)
#   > Processing Pakpattan... Done (5 pts)
#   > Processing Bahawalnagar... Done (5 pts)
#   > Processing Tando Adam... Done (5 pts)
#
# Processing Country: NIGERIA
#   > Processing Lagos... Done (5 pts)
#   > Processing Kano... Done (5 pts)
#   > Processing Ibadan... Done (5 pts)
#   > Processing Abuja... Done (5 pts)
#   > Processing Port Harcourt... Done (5 pts)
#   > Processing Benin City... Done (5 pts)
#   > Processing Jos... Done (5 pts)
#   > Processing Ilora... Done (5 pts)
#   > Processing Kaduna... Done (5 pts)
#   > Processing Enugu... Done (5 pts)
#   > Processing Zaria... Done (5 pts)
#   > Processing Warri... Done (5 pts)
#   > Processing Maiduguri... Done (5 pts)
#   > Processing Aba... Done (5 pts)
#   > Processing Onitsha... Done (5 pts)
#   > Processing Ogbomosho... Done (5 pts)
#   > Processing Ikare... Done (5 pts)
#   > Processing Ado Ekiti... Done (5 pts)
#   > Processing Bauchi... Done (5 pts)
#   > Processing Ilorin... Done (5 pts)
#   > Processing Akure... Done (5 pts)
#   > Processing Owerri... Done (5 pts)
#   > Processing Sokoto... Done (5 pts)
#   > Processing Ebute Ikorodu... Done (5 pts)
#   > Processing Calabar... Done (5 pts)
#   > Processing Uyo... Done (5 pts)
#   > Processing Minna... Done (5 pts)
#   > Processing Abeokuta... Done (5 pts)
#   > Processing Osogbo... Done (5 pts)
#   > Processing Ifẹ... Done (5 pts)
#   > Processing Makurdi... Done (5 pts)
#   > Processing Ondo... Done (5 pts)
#   > Processing Jimeta... Done (5 pts)
#   > Processing Gusau... Done (5 pts)
#   > Processing Mubi... Done (5 pts)
#   > Processing Umuahia... Done (5 pts)
#   > Processing Ife... Done (5 pts)
#   > Processing Oyo... Done (5 pts)
#   > Processing Awka... Done (5 pts)
#   > Processing Damaturu... Done (5 pts)
#   > Processing Iwo... Done (5 pts)
#   > Processing Ilesa... Done (5 pts)
#   > Processing Katsina... Done (5 pts)
#   > Processing Nnewi... Done (5 pts)
#   > Processing Bida... Done (5 pts)
#   > Processing Ikot Ekpene... Done (5 pts)
#   > Processing Lafia... Done (5 pts)
#   > Processing Okene... Done (5 pts)
#   > Processing Suleja... Done (5 pts)
#   > Processing Nguru... Done (5 pts)
#
# Processing Country: BANGLADESH
#   > Processing Dhaka... Done (5 pts)
#   > Processing Chittagong... Done (5 pts)
#   > Processing Khulna... Done (5 pts)
#   > Processing Rajshahi... Done (5 pts)
#   > Processing Comilla... Done (5 pts)
#   > Processing Sylhet... Done (5 pts)
#   > Processing Barisal... Done (5 pts)
#   > Processing Rangpur... Done (5 pts)
#   > Processing Narsingdi... Done (5 pts)
#   > Processing Narayanganj... Done (5 pts)
#   > Processing Gazipur... Done (5 pts)
#   > Processing Mymensingh... Done (5 pts)
#   > Processing Bogra... Done (5 pts)
#   > Processing Jessore... Done (5 pts)
#   > Processing Dinajpur... Done (5 pts)
#   > Processing Saidpur... Done (5 pts)
#   > Processing Cox's Bazar... Done (5 pts)
#   > Processing Tangail... Done (5 pts)
#   > Processing Pabna... Done (5 pts)
#   > Processing Sirajganj... Done (5 pts)
#   > Processing Nawabganj... Done (5 pts)
#   > Processing Kushtia... Done (5 pts)
#   > Processing Faridpur... Done (5 pts)
#   > Processing Jamalpur... Done (5 pts)
#   > Processing Naogaon... Done (5 pts)
#   > Processing Feni... Done (5 pts)
#   > Processing Brahmanbaria... Done (5 pts)
#   > Processing Tongī... Done (5 pts)
#   > Processing Shibganj... Done (5 pts)
#   > Processing Savār... Done (5 pts)
#   > Processing Kishoreganj... Done (5 pts)
#   > Processing Habiganj... Done (5 pts)
#   > Processing Chandpur... Done (5 pts)
#   > Processing Patiya... Done (5 pts)
#   > Processing Natore... Done (5 pts)
#   > Processing Lakshmipur... Done (5 pts)
#   > Processing Bhola... Done (5 pts)
#   > Processing Noakhali... Done (5 pts)
#   > Processing Manikganj... Done (5 pts)
#   > Processing Chuadanga... Done (5 pts)
#   > Processing Satkhira... Done (5 pts)
#   > Processing Madaripur... Done (5 pts)
#   > Processing Meherpur... Done (5 pts)
#   > Processing Sherpur... Done (5 pts)
#   > Processing Panchagarh... Done (5 pts)
#   > Processing Kurigram... Done (5 pts)
#   > Processing Gaibandha... Done (5 pts)
#   > Processing Nilphamari...     [Net Error] Pollution: HTTPConnectionPool(host='api.openweathermap.org', port=80): Max retries exceeded with url: /data/2.5/air_pollution?lat=25.95487&lon=88.8586&appid=1c63d4b087353b1d4e226954d3db89cb (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x00000204506BB570>, 'Connection to api.openweathermap.org timed out. (connect timeout=None)'))
# Done (5 pts)
#   > Processing Lalmonirhat... Done (5 pts)
#   > Processing Magura... Done (5 pts)
#
# Processing Country: RUSSIA
#   > Processing Moscow... Done (5 pts)
#   > Processing Saint Petersburg... Done (5 pts)
#   > Processing Novosibirsk... Done (5 pts)
#   > Processing Yekaterinburg... Done (5 pts)
#   > Processing Kazan... Done (5 pts)
#   > Processing Nizhny Novgorod... Done (5 pts)
#   > Processing Chelyabinsk... Done (5 pts)
#   > Processing Omsk... Done (5 pts)
#   > Processing Samara... Done (5 pts)
#   > Processing Rostov-on-Don... Done (5 pts)
#   > Processing Ufa... Done (5 pts)
#   > Processing Krasnoyarsk... Done (5 pts)
#   > Processing Voronezh... Done (5 pts)
#   > Processing Perm... Done (5 pts)
#   > Processing Volgograd... Done (5 pts)
#   > Processing Saratov... Done (5 pts)
#   > Processing Krasnodar... Done (5 pts)
#   > Processing Tolyatti... Done (5 pts)
#   > Processing Izhevsk... Done (5 pts)
#   > Processing Ulyanovsk... Done (5 pts)
#   > Processing Barnaul... Done (5 pts)
#   > Processing Tyumen... Done (5 pts)
#   > Processing Irkutsk... Done (5 pts)
#   > Processing Khabarovsk... Done (5 pts)
#   > Processing Makhachkala... Done (5 pts)
#   > Processing Vladivostok... Done (5 pts)
#   > Processing Yaroslavl... Done (5 pts)
#   > Processing Tomsk... Done (5 pts)
#   > Processing Orenburg... Done (5 pts)
#   > Processing Novokuznetsk... Done (5 pts)
#   > Processing Kemerovo... Done (5 pts)
#   > Processing Ryazan... Done (5 pts)
#   > Processing Astrakhan... Done (5 pts)
#   > Processing Penza... Done (5 pts)
#   > Processing Naberezhnye Chelny... Done (5 pts)
#   > Processing Lipetsk... Done (5 pts)
#   > Processing Tula... Done (5 pts)
#   > Processing Kirov... Done (5 pts)
#   > Processing Cheboksary... Done (5 pts)
#   > Processing Kaliningrad... Done (5 pts)
#   > Processing Bryansk... Done (5 pts)
#   > Processing Kursk... Done (5 pts)
#   > Processing Ivanovo... Done (5 pts)
#   > Processing Magnitogorsk... Done (5 pts)
#   > Processing Ulan-Ude... Done (5 pts)
#   > Processing Tver... Done (5 pts)
#   > Processing Stavropol... Done (5 pts)
#   > Processing Nizhny Tagil... Done (5 pts)
#   > Processing Belgorod... Done (5 pts)
#   > Processing Arkhangelsk... Done (5 pts)
#
# SUCCESS! Collected 2495 rows.
# Data saved to: Pollution_Weather_ten_countries.csv
