# %%
# !pip install -U openaq pandas
# Out:
# Requirement already satisfied: openaq in /usr/local/lib/python3.12/dist-packages (0.6.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.3.3)
# Requirement already satisfied: httpx<1.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from openaq) (0.28.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.28.1->openaq) (4.12.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.28.1->openaq) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.28.1->openaq) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.28.1->openaq) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.28.1->openaq) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1.0,>=0.28.1->openaq) (4.15.0)

# %%
import os
from dotenv import load_dotenv
load_dotenv()  # Load environment variables from .env file if present
OPENAQ_API_KEY = os.getenv("a8060b7563411953d2087f65a23749625483e33f0ed95514c49dfe954780e65b")

# Force complete reimport of openaq module and its submodules
import sys
modules_to_remove = [key for key in sys.modules.keys() if key.startswith('openaq')]
for mod in modules_to_remove:
    del sys.modules[mod]

print("Cleaned up openaq modules from cache")
# Out:
# Cleaned up openaq modules from cache

# %%
import os
from google.colab import userdata

OPENAQ_API_KEY = userdata.get("OPENAQ_API_KEY")
import datetime
import time
import pandas as pd
from openaq import OpenAQ

# Karnataka (Bengaluru) - approximate center coordinates
# Karnataka state is represented using Bengaluru city for air quality analysis
# Bengaluru is located at approximately 12.97°N 77.59°E
KARNATAKA_LATITUDE = 12.97
KARNATAKA_LONGITUDE = 77.59
RADIUS_METERS = 25000  # 25 km radius (OpenAQ max limit)


# Define date range: last 30 days to today
date_to = datetime.datetime.now(datetime.timezone.utc)
date_from = date_to - datetime.timedelta(days=30)

print(f"Fetching data from {date_from.isoformat()} to {date_to.isoformat()}")
print(f"Location: Karnataka (Bengaluru) ({KARNATAKA_LATITUDE}, {KARNATAKA_LONGITUDE})")
print(f"Search radius: {RADIUS_METERS/1000} km")
print("-" * 60)

# Define the parameters we want to collect (flexible matching)
WANTED_KEYWORDS = {
    "pm25": ["pm25", "pm2.5", "pm2_5"],
    "pm10": ["pm10"],
    "no2": ["no2", "nitrogen dioxide"],
    "co": ["co", "carbon monoxide"],
    "so2": ["so2", "sulfur dioxide", "sulphur dioxide"],
    "o3": ["o3", "ozone"],
    "temperature": ["temperature", "temp", "at"],
    "humidity": ["humidity", "rh", "relativehumidity", "relative humidity"],
    "wind_speed": ["windspeed", "wind_speed", "ws", "wind speed"],
    "wind_direction": ["winddirection", "wind_direction", "wd", "wind direction"]
}

def is_wanted_parameter(param_name):
    """Check if parameter name matches any of our wanted parameters"""
    if not param_name:
        return None
    param_lower = param_name.lower().strip()
    for category, keywords in WANTED_KEYWORDS.items():
        for kw in keywords:
            if kw == param_lower or param_lower.startswith(kw):
                return category
    return None

def get_sensor_param_info(sensor):
    """Extract parameter info from sensor, handling both dict and object responses"""
    param_name = ""
    param_display = ""
    param_units = ""

    if hasattr(sensor, 'parameter'):
        param = sensor.parameter
        # Handle dict response
        if isinstance(param, dict):
            param_name = param.get('name', '')
            param_display = param.get('display_name', param_name)
            param_units = param.get('units', '')
        # Handle object response
        else:
            if hasattr(param, 'name') and param.name:
                param_name = param.name
            if hasattr(param, 'display_name') and param.display_name:
                param_display = param.display_name
            if hasattr(param, 'units') and param.units:
                param_units = param.units

    # If still empty, try the sensor name which often contains param info
    if not param_name and hasattr(sensor, 'name') and sensor.name:
        param_name = sensor.name.split()[0] if sensor.name else ""
        param_display = sensor.name

    return param_name, param_display, param_units

# Initialize the OpenAQ client with API key (OPENAQ_API_KEY should be loaded from Colab Secrets)
client = OpenAQ(api_key=OPENAQ_API_KEY)

# Step 1: Fetch all locations (monitoring stations) around Bengaluru
print("\n1. Fetching locations around Bengaluru...")
try:
    loc_response = client.locations.list(
        coordinates=(KARNATAKA_LATITUDE, KARNATAKA_LONGITUDE),
        radius=RADIUS_METERS,
        limit=1000
    )
    locations = loc_response.results
    print(f"   Found {len(locations)} monitoring location(s)")
except Exception as e:
    print(f"   Error fetching locations: {e}")
    locations = []

# Display location details
for loc in locations:
    print(f"\n   Location ID: {loc.id}")
    print(f"   Name: {loc.name}")
    print(f"   Coordinates: ({loc.coordinates.latitude}, {loc.coordinates.longitude})")
    if hasattr(loc, 'locality') and loc.locality:
        print(f"   Locality: {loc.locality}")

# Step 2: For each location, get sensors and fetch measurements
print("\n2. Fetching measurements for each location...")
all_data = []

for loc in locations:
    loc_id = loc.id
    loc_name = loc.name
    loc_lat = loc.coordinates.latitude
    loc_lon = loc.coordinates.longitude

    print(f"\n   Processing location: {loc_name} (ID: {loc_id})")

    # Get sensors for this location
    try:
        sensors_response = client.locations.sensors(loc_id)
        sensors = sensors_response.results
        print(f"   Found {len(sensors)} sensor(s)")
    except Exception as e:
        print(f"   Error fetching sensors: {e}")
        continue

    # Show all available parameters at this location
    print("   Available parameters:")
    for sensor in sensors:
        param_name, param_display, param_units = get_sensor_param_info(sensor)
        matched = is_wanted_parameter(param_name)
        match_indicator = " ✓" if matched else ""
        print(f"      - {param_display} ({param_name}) [{param_units}]{match_indicator}")

    # For each sensor, check if it measures a parameter we want
    for sensor in sensors:
        sensor_id = sensor.id
        param_name, param_display, param_units = get_sensor_param_info(sensor)

        # Check if this is a parameter we want
        matched_category = is_wanted_parameter(param_name)
        if not matched_category:
            continue

        print(f"\n      Fetching: {param_display} (Sensor ID: {sensor_id})")

        # Fetch measurements for this sensor with pagination
        page = 1
        sensor_records = 0

        while True:
            try:
                meas_response = client.measurements.list(
                    sensors_id=sensor_id,
                    datetime_from=date_from,
                    datetime_to=date_to,
                    page=page,
                    limit=1000
                )
                results = meas_response.results

                if not results:
                    break

                for m in results:
                    # Extract measurement datetime
                    datetime_utc = None
                    datetime_local = None

                    if hasattr(m, 'period') and m.period:
                        if hasattr(m.period, 'datetime_from'):
                            dt_from = m.period.datetime_from
                            if hasattr(dt_from, 'utc'):
                                datetime_utc = str(dt_from.utc)
                            if hasattr(dt_from, 'local'):
                                datetime_local = str(dt_from.local)

                    record = {
                        "location_id": loc_id,
                        "location_name": loc_name,
                        "sensor_id": sensor_id,
                        "parameter": matched_category,
                        "parameter_original": param_name,
                        "parameter_display": param_display,
                        "value": m.value if hasattr(m, 'value') else None,
                        "unit": param_units,
                        "datetime_utc": datetime_utc,
                        "datetime_local": datetime_local,
                        "latitude": loc_lat,
                        "longitude": loc_lon,
                    }
                    all_data.append(record)
                    sensor_records += 1

                page += 1
                time.sleep(0.1)  # Rate limiting

            except Exception as e:
                print(f"      Error fetching measurements (page {page}): {e}")
                break

        if sensor_records > 0:
            print(f"         Retrieved {sensor_records} measurement(s)")
        else:
            print(f"         No measurements found for this time range")

# Close the client connection
client.close()

# Step 3: Build DataFrame
print("\n" + "=" * 60)
print("3. Building DataFrame...")
df = pd.DataFrame(all_data)
print(f"   Total records fetched: {len(df)}")

if len(df) > 0:
    print("\n   Data Preview:")
    print(df.head(10))

    print("\n   Parameter distribution:")
    print(df["parameter"].value_counts())

    print("\n   Data summary by parameter:")
    summary = df.groupby("parameter")["value"].agg(["count", "mean", "min", "max"])
    print(summary)

    # Create data/raw directory if it doesn't exist
    os.makedirs("data/raw", exist_ok=True)

    # Save to CSV
    output_file = "data/raw/erode_aq_last30days.csv"
    df.to_csv(output_file, index=False)
    print(f"\n4. Saved data to '{output_file}'")
else:
    print("\n   No data found for the specified location and time range.")
    print("   This could mean:")
    print("   - No monitoring stations exist within the search radius")
    print("   - No data available for the last 30 days")
    print("   - The parameters you're looking for aren't measured at these stations")
    print("\n   Consider trying:")
    print("   - Increasing the search radius")
    print("   - Searching in a different location")
    print("   - Checking the OpenAQ website for available stations in your area")
# Out:
# Fetching data from 2025-11-14T10:43:24.141956+00:00 to 2025-12-14T10:43:24.141956+00:00
# Location: Karnataka (Bengaluru) (12.97, 77.59)
# Search radius: 25.0 km
# ------------------------------------------------------------
#
# 1. Fetching locations around Bengaluru...
#    Found 24 monitoring location(s)
#
#    Location ID: 412
#    Name: Peenya, Bengaluru - KSPCB
#    Coordinates: (13.0339, 77.51321111)
#
#    Location ID: 594
#    Name: BTM Layout, Bengaluru - KSPCB
#    Coordinates: (12.912811110000002, 77.60921944)
#
#    Location ID: 797
#    Name: City Railway Station - KSPCB
#    Coordinates: (12.9773472, 77.5706972222222)
#
#    Location ID: 2589
#    Name: SaneguravaHalli - KSPCB
#    Coordinates: (12.9916694, 77.5458305555555)
#
#    Location ID: 2592
#    Name: BWSSB Kadabesanahalli, Bengaluru - KSPCB
#    Coordinates: (12.93890556, 77.69727222)
#
#    Location ID: 5547
#    Name: BWSSB Kadabesanahalli, Bengaluru - CPCB
#    Coordinates: (12.9352049, 77.6814488)
#
#    Location ID: 5548
#    Name: BTM Layout, Bengaluru - CPCB
#    Coordinates: (12.9135218, 77.5950804)
#
#    Location ID: 5574
#    Name: City Railway Station, Bengaluru - KSPCB
#    Coordinates: (12.9756843, 77.5660749)
#
#    Location ID: 5607
#    Name: Peenya, Bengaluru - CPCB
#    Coordinates: (13.0270199, 77.494094)
#
#    Location ID: 5644
#    Name: Sanegurava Halli, Bengaluru - KSPCB
#    Coordinates: (12.990328, 77.5431385)
#
#    Location ID: 6973
#    Name: Jayanagar 5th Block, Bengaluru - KSPCB
#    Coordinates: (12.920984, 77.584908)
#
#    Location ID: 6974
#    Name: Bapuji Nagar, Bengaluru - KSPCB
#    Coordinates: (12.951913, 77.539784)
#
#    Location ID: 6975
#    Name: Silk Board, Bengaluru - KSPCB
#    Coordinates: (12.917348, 77.622813)
#
#    Location ID: 6983
#    Name: Hombegowda Nagar, Bengaluru - KSPCB
#    Coordinates: (12.938539, 77.5901)
#
#    Location ID: 6984
#    Name: Hebbal, Bengaluru - KSPCB
#    Coordinates: (13.029152, 77.585901)
#
#    Location ID: 229473
#    Name: blore_India_07_14_official
#    Coordinates: (13.003347077, 77.628012188)
#
#    Location ID: 2498781
#    Name: SiriJaya
#    Coordinates: (12.909153635368195, 77.52476183092863)
#
#    Location ID: 3409312
#    Name: BWSSB Kadabesanahalli, Bengaluru - CPCB
#    Coordinates: (12.9352049, 77.6814488)
#
#    Location ID: 3409385
#    Name: RVCE-Mailasandra, Bengaluru - KSPCB
#    Coordinates: (12.921418, 77.502466)
#
#    Location ID: 3409388
#    Name: Kasturi Nagar, Bengaluru - KSPCB
#    Coordinates: (13.003872, 77.664217)
#
#    Location ID: 3409393
#    Name: Shivapura_Peenya, Bengaluru - KSPCB
#    Coordinates: (13.0246342, 77.5080115)
#
#    Location ID: 3409434
#    Name: Jigani, Bengaluru - KSPCB
#    Coordinates: (12.7816279, 77.6299145)
#
#    Location ID: 6119271
#    Name: Kumaraswamy Layout
#    Coordinates: (12.9044, 77.5649)
#
#    Location ID: 6146655
#    Name: Bellandur
#    Coordinates: (12.9178128, 77.6955288)
#
# 2. Fetching measurements for each location...
#
#    Processing location: Peenya, Bengaluru - KSPCB (ID: 412)
#    Found 4 sensor(s)
#    Available parameters:
#       - NO₂ mass (no2) [µg/m³] ✓
#       - SO₂ mass (so2) [µg/m³] ✓
#       - PM2.5 (pm25) [µg/m³] ✓
#       - CO mass (co) [µg/m³] ✓
#
#       Fetching: NO₂ mass (Sensor ID: 1518)
#          No measurements found for this time range
#
#       Fetching: SO₂ mass (Sensor ID: 13853)
#          No measurements found for this time range
#
#       Fetching: PM2.5 (Sensor ID: 13852)
#          No measurements found for this time range
#
#       Fetching: CO mass (Sensor ID: 722)
#          No measurements found for this time range
#
#    Processing location: BTM Layout, Bengaluru - KSPCB (ID: 594)
#    Found 5 sensor(s)
#    Available parameters:
#       - CO mass (co) [µg/m³] ✓
#       - PM2.5 (pm25) [µg/m³] ✓
#       - O₃ mass (o3) [µg/m³] ✓
#       - NO₂ mass (no2) [µg/m³] ✓
#       - SO₂ mass (so2) [µg/m³] ✓
#
#       Fetching: CO mass (Sensor ID: 1048)
#          No measurements found for this time range
#
#       Fetching: PM2.5 (Sensor ID: 13836)
#          No measurements found for this time range
#
#       Fetching: O₃ mass (Sensor ID: 4886)
#          No measurements found for this time range
#
#       Fetching: NO₂ mass (Sensor ID: 1427)
#          No measurements found for this time range
#
#       Fetching: SO₂ mass (Sensor ID: 13837)
#          No measurements found for this time range
#
#    Processing location: City Railway Station - KSPCB (ID: 797)
#    Found 4 sensor(s)
#    Available parameters:
#       - SO₂ mass (so2) [µg/m³] ✓
#       - NO₂ mass (no2) [µg/m³] ✓
#       - CO mass (co) [µg/m³] ✓
#       - PM10 (pm10) [µg/m³] ✓
#
#       Fetching: SO₂ mass (Sensor ID: 14096)
#          No measurements found for this time range
#
#       Fetching: NO₂ mass (Sensor ID: 1383)
#          No measurements found for this time range
#
#       Fetching: CO mass (Sensor ID: 1384)
#          No measurements found for this time range
#
#       Fetching: PM10 (Sensor ID: 1382)
#          No measurements found for this time range
#
#    Processing location: SaneguravaHalli - KSPCB (ID: 2589)
#    Found 4 sensor(s)
#    Available parameters:
#       - NO₂ mass (no2) [µg/m³] ✓
#       - SO₂ mass (so2) [µg/m³] ✓
#       - PM10 (pm10) [µg/m³] ✓
#       - CO mass (co) [µg/m³] ✓
#
#       Fetching: NO₂ mass (Sensor ID: 5349)
#          No measurements found for this time range
#
#       Fetching: SO₂ mass (Sensor ID: 14129)
#          No measurements found for this time range
#
#       Fetching: PM10 (Sensor ID: 5348)
#          No measurements found for this time range
#
#       Fetching: CO mass (Sensor ID: 5350)
#          No measurements found for this time range
#
#    Processing location: BWSSB Kadabesanahalli, Bengaluru - KSPCB (ID: 2592)
#    Found 5 sensor(s)
#    Available parameters:
#       - NO₂ mass (no2) [µg/m³] ✓
#       - PM2.5 (pm25) [µg/m³] ✓
#       - O₃ mass (o3) [µg/m³] ✓
#       - CO mass (co) [µg/m³] ✓
#       - SO₂ mass (so2) [µg/m³] ✓
#
#       Fetching: NO₂ mass (Sensor ID: 5380)
#          No measurements found for this time range
#
#       Fetching: PM2.5 (Sensor ID: 13898)
#          No measurements found for this time range
#
#       Fetching: O₃ mass (Sensor ID: 5375)
#          No measurements found for this time range
#
#       Fetching: CO mass (Sensor ID: 5381)
#          No measurements found for this time range
#
#       Fetching: SO₂ mass (Sensor ID: 13888)
#          No measurements found for this time range
#
#    Processing location: BWSSB Kadabesanahalli, Bengaluru - CPCB (ID: 5547)
#    Found 6 sensor(s)
#    Available parameters:
#       - NO₂ mass (no2) [µg/m³] ✓
#       - O₃ mass (o3) [µg/m³] ✓
#       - SO₂ mass (so2) [µg/m³] ✓
#       - CO mass (co) [µg/m³] ✓
#       - PM10 (pm10) [µg/m³] ✓
#       - PM2.5 (pm25) [µg/m³] ✓
#
#       Fetching: NO₂ mass (Sensor ID: 14636)
#          No measurements found for this time range
#
#       Fetching: O₃ mass (Sensor ID: 14640)
#          No measurements found for this time range
#
#       Fetching: SO₂ mass (Sensor ID: 14634)
#          No measurements found for this time range
#
#       Fetching: CO mass (Sensor ID: 14637)
#          No measurements found for this time range
#
#       Fetching: PM10 (Sensor ID: 1303004)
#          No measurements found for this time range
#
#       Fetching: PM2.5 (Sensor ID: 14641)
#          No measurements found for this time range
#
#    Processing location: BTM Layout, Bengaluru - CPCB (ID: 5548)
#    Found 18 sensor(s)
#    Available parameters:
#       - NO₂ mass (no2) [µg/m³] ✓
#       - PM2.5 (pm25) [µg/m³] ✓
#       - PM10 (pm10) [µg/m³] ✓
#       - SO₂ mass (so2) [µg/m³] ✓
#       - CO mass (co) [µg/m³] ✓
#       - O₃ mass (o3) [µg/m³] ✓
#       - O₃ mass (o3) [µg/m³] ✓
#       - CO (co) [ppb] ✓
#       - SO₂ (so2) [ppb] ✓
#       - Temperature (C) (temperature) [c] ✓
#       - PM10 (pm10) [µg/m³] ✓
#       - PM2.5 (pm25) [µg/m³] ✓
#       - NO (no) [ppb]
#       - NO₂ (no2) [ppb] ✓
#       - RH (relativehumidity) [%] ✓
#       - Wind speed (wind_speed) [m/s] ✓
#       - Wind direction (wind_direction) [deg] ✓
#       - NOX (nox) [ppb]
#
#       Fetching: NO₂ mass (Sensor ID: 14639)
#          No measurements found for this time range
#
#       Fetching: PM2.5 (Sensor ID: 14635)
#          No measurements found for this time range
#
#       Fetching: PM10 (Sensor ID: 1305377)
#          No measurements found for this time range
#
#       Fetching: SO₂ mass (Sensor ID: 14642)
#          No measurements found for this time range
#
#       Fetching: CO mass (Sensor ID: 14657)
#          No measurements found for this time range
#
#       Fetching: O₃ mass (Sensor ID: 14658)
#          No measurements found for this time range
#
#       Fetching: O₃ mass (Sensor ID: 12235359)
#          Retrieved 1904 measurement(s)
#
#       Fetching: CO (Sensor ID: 12235356)
#          Retrieved 1905 measurement(s)
#
#       Fetching: SO₂ (Sensor ID: 12235363)
#          Retrieved 1905 measurement(s)
#
#       Fetching: Temperature (C) (Sensor ID: 12235364)
#          Retrieved 1909 measurement(s)
#
#       Fetching: PM10 (Sensor ID: 12235360)
#          Retrieved 1918 measurement(s)
#
#       Fetching: PM2.5 (Sensor ID: 12235361)
# ERROR:openaq:Rate limit exceeded
# NoneType: None
# ERROR:openaq:Rate limit exceeded
# NoneType: None
# ERROR:openaq:Rate limit exceeded
# NoneType: None
# ERROR:openaq:Rate limit exceeded
# NoneType: None
# ERROR:openaq:Rate limit exceeded
# NoneType: None
# ERROR:openaq:Rate limit exceeded
# NoneType: None
# ERROR:openaq:Rate limit exceeded
# NoneType: None
# ERROR:openaq:Rate limit exceeded
# NoneType: None
# ERROR:openaq:Rate limit exceeded
# NoneType: None
# ERROR:openaq:Rate limit exceeded
# NoneType: None
# ERROR:openaq:Rate limit exceeded
# NoneType: None
# ERROR:openaq:Rate limit exceeded
# NoneType: None
# ERROR:openaq:Rate limit exceeded
# NoneType: None
# ERROR:openaq:Rate limit exceeded
# NoneType: None
# ERROR:openaq:Rate limit exceeded
# NoneType: None
# ERROR:openaq:Rate limit exceeded
# NoneType: None
# ERROR:openaq:Rate limit exceeded
# NoneType: None
# ERROR:openaq:Rate limit exceeded
# NoneType: None
# ERROR:openaq:Rate limit exceeded
# NoneType: None
# ERROR:openaq:Rate limit exceeded
# NoneType: None
# ERROR:openaq:Rate limit exceeded
# NoneType: None
#          Retrieved 1913 measurement(s)
#
#       Fetching: NO₂ (Sensor ID: 12235358)
#       Error fetching measurements (page 1): Rate limit exceeded. Limit resets in 32 seconds
#          No measurements found for this time range
#
#       Fetching: RH (Sensor ID: 12235362)
#       Error fetching measurements (page 1): Rate limit exceeded. Limit resets in 32 seconds
#          No measurements found for this time range
#
#       Fetching: Wind speed (Sensor ID: 14341818)
#       Error fetching measurements (page 1): Rate limit exceeded. Limit resets in 32 seconds
#          No measurements found for this time range
#
#       Fetching: Wind direction (Sensor ID: 14341817)
#       Error fetching measurements (page 1): Rate limit exceeded. Limit resets in 32 seconds
#          No measurements found for this time range
#
#    Processing location: City Railway Station, Bengaluru - KSPCB (ID: 5574)
#    Error fetching sensors: Rate limit exceeded. Limit resets in 32 seconds
#
#    Processing location: Peenya, Bengaluru - CPCB (ID: 5607)
#    Error fetching sensors: Rate limit exceeded. Limit resets in 32 seconds
#
#    Processing location: Sanegurava Halli, Bengaluru - KSPCB (ID: 5644)
#    Error fetching sensors: Rate limit exceeded. Limit resets in 32 seconds
#
#    Processing location: Jayanagar 5th Block, Bengaluru - KSPCB (ID: 6973)
#    Error fetching sensors: Rate limit exceeded. Limit resets in 32 seconds
#
#    Processing location: Bapuji Nagar, Bengaluru - KSPCB (ID: 6974)
#    Error fetching sensors: Rate limit exceeded. Limit resets in 32 seconds
#
#    Processing location: Silk Board, Bengaluru - KSPCB (ID: 6975)
#    Error fetching sensors: Rate limit exceeded. Limit resets in 32 seconds
#
#    Processing location: Hombegowda Nagar, Bengaluru - KSPCB (ID: 6983)
#    Error fetching sensors: Rate limit exceeded. Limit resets in 32 seconds
#
#    Processing location: Hebbal, Bengaluru - KSPCB (ID: 6984)
#    Error fetching sensors: Rate limit exceeded. Limit resets in 32 seconds
#
#    Processing location: blore_India_07_14_official (ID: 229473)
#    Error fetching sensors: Rate limit exceeded. Limit resets in 32 seconds
#
#    Processing location: SiriJaya (ID: 2498781)
#    Error fetching sensors: Rate limit exceeded. Limit resets in 32 seconds
#
#    Processing location: BWSSB Kadabesanahalli, Bengaluru - CPCB (ID: 3409312)
#    Error fetching sensors: Rate limit exceeded. Limit resets in 32 seconds
#
#    Processing location: RVCE-Mailasandra, Bengaluru - KSPCB (ID: 3409385)
#    Error fetching sensors: Rate limit exceeded. Limit resets in 32 seconds
#
#    Processing location: Kasturi Nagar, Bengaluru - KSPCB (ID: 3409388)
#    Error fetching sensors: Rate limit exceeded. Limit resets in 32 seconds
#
#    Processing location: Shivapura_Peenya, Bengaluru - KSPCB (ID: 3409393)
#    Error fetching sensors: Rate limit exceeded. Limit resets in 32 seconds
#
#    Processing location: Jigani, Bengaluru - KSPCB (ID: 3409434)
#    Error fetching sensors: Rate limit exceeded. Limit resets in 32 seconds
#
#    Processing location: Kumaraswamy Layout (ID: 6119271)
#    Error fetching sensors: Rate limit exceeded. Limit resets in 32 seconds
#
#    Processing location: Bellandur (ID: 6146655)
#    Error fetching sensors: Rate limit exceeded. Limit resets in 32 seconds
#
# ============================================================
# 3. Building DataFrame...
#    Total records fetched: 11454
#
#    Data Preview:
#    location_id                 location_name  sensor_id parameter  \
# 0         5548  BTM Layout, Bengaluru - CPCB   12235359        o3
# 1         5548  BTM Layout, Bengaluru - CPCB   12235359        o3
# 2         5548  BTM Layout, Bengaluru - CPCB   12235359        o3
# 3         5548  BTM Layout, Bengaluru - CPCB   12235359        o3
# 4         5548  BTM Layout, Bengaluru - CPCB   12235359        o3
# 5         5548  BTM Layout, Bengaluru - CPCB   12235359        o3
# 6         5548  BTM Layout, Bengaluru - CPCB   12235359        o3
# 7         5548  BTM Layout, Bengaluru - CPCB   12235359        o3
# 8         5548  BTM Layout, Bengaluru - CPCB   12235359        o3
# 9         5548  BTM Layout, Bengaluru - CPCB   12235359        o3
#
#   parameter_original parameter_display  value   unit          datetime_utc  \
# 0                 o3           O₃ mass  22.98  µg/m³  2025-11-14T10:30:00Z
# 1                 o3           O₃ mass  23.08  µg/m³  2025-11-14T10:45:00Z
# 2                 o3           O₃ mass  22.65  µg/m³  2025-11-14T11:15:00Z
# 3                 o3           O₃ mass  23.06  µg/m³  2025-11-14T11:30:00Z
# 4                 o3           O₃ mass  23.86  µg/m³  2025-11-14T11:45:00Z
# 5                 o3           O₃ mass  23.00  µg/m³  2025-11-14T12:00:00Z
# 6                 o3           O₃ mass  23.50  µg/m³  2025-11-14T12:15:00Z
# 7                 o3           O₃ mass  23.78  µg/m³  2025-11-14T12:30:00Z
# 8                 o3           O₃ mass  23.52  µg/m³  2025-11-14T12:45:00Z
# 9                 o3           O₃ mass  22.48  µg/m³  2025-11-14T13:00:00Z
#
#               datetime_local   latitude  longitude
# 0  2025-11-14T16:00:00+05:30  12.913522   77.59508
# 1  2025-11-14T16:15:00+05:30  12.913522   77.59508
# 2  2025-11-14T16:45:00+05:30  12.913522   77.59508
# 3  2025-11-14T17:00:00+05:30  12.913522   77.59508
# 4  2025-11-14T17:15:00+05:30  12.913522   77.59508
# 5  2025-11-14T17:30:00+05:30  12.913522   77.59508
# 6  2025-11-14T17:45:00+05:30  12.913522   77.59508
# 7  2025-11-14T18:00:00+05:30  12.913522   77.59508
# 8  2025-11-14T18:15:00+05:30  12.913522   77.59508
# 9  2025-11-14T18:30:00+05:30  12.913522   77.59508
#
#    Parameter distribution:
# parameter
# pm10           1918
# pm25           1913
# temperature    1909
# co             1905
# so2            1905
# o3             1904
# Name: count, dtype: int64
#
#    Data summary by parameter:
#              count       mean    min     max
# parameter
# co            1905   0.957533   0.50    2.07
# o3            1904  22.386712  18.99   25.45
# pm10          1918  78.585991  60.54  103.05
# pm25          1913  48.181824  15.52  126.48
# so2           1905  13.873538  10.08   19.45
# temperature   1909  24.200592  20.29   28.43
#
# 4. Saved data to 'data/raw/erode_aq_last30days.csv'
