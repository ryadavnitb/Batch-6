# %%
#STEP-1 — Install & import libraries
# !pip install osmnx geopandas shapely
# Out:
# Requirement already satisfied: osmnx in c:\users\aditi\anaconda3\lib\site-packages (2.0.7)
# Requirement already satisfied: geopandas in c:\users\aditi\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: shapely in c:\users\aditi\anaconda3\lib\site-packages (2.1.2)
# Requirement already satisfied: networkx>=2.5 in c:\users\aditi\anaconda3\lib\site-packages (from osmnx) (3.1)
# Requirement already satisfied: numpy>=1.22 in c:\users\aditi\anaconda3\lib\site-packages (from osmnx) (1.26.4)
# Requirement already satisfied: pandas>=1.4 in c:\users\aditi\anaconda3\lib\site-packages (from osmnx) (2.1.4)
# Requirement already satisfied: requests>=2.27 in c:\users\aditi\anaconda3\lib\site-packages (from osmnx) (2.32.3)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\aditi\anaconda3\lib\site-packages (from geopandas) (0.12.1)
# Requirement already satisfied: packaging in c:\users\aditi\anaconda3\lib\site-packages (from geopandas) (23.1)
# Requirement already satisfied: pyproj>=3.5.0 in c:\users\aditi\anaconda3\lib\site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aditi\anaconda3\lib\site-packages (from pandas>=1.4->osmnx) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aditi\anaconda3\lib\site-packages (from pandas>=1.4->osmnx) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\aditi\anaconda3\lib\site-packages (from pandas>=1.4->osmnx) (2023.3)
# Requirement already satisfied: certifi in c:\users\aditi\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2025.1.31)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aditi\anaconda3\lib\site-packages (from requests>=2.27->osmnx) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aditi\anaconda3\lib\site-packages (from requests>=2.27->osmnx) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aditi\anaconda3\lib\site-packages (from requests>=2.27->osmnx) (2.0.7)
# Requirement already satisfied: six>=1.5 in c:\users\aditi\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4->osmnx) (1.16.0)

# %%
import osmnx as ox
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point

# %%
ox.settings.use_cache = True
ox.settings.log_console = False

# %%
#STEP-2 — Load your cleaned dataset
df = pd.read_csv("data/india_states/feature_engineered_dataset.csv")

print("Rows:", len(df))
df.head()
# Out:
# Rows: 953755
#    location_id            location_name  sensor_id parameter_original  \
# 0           17  R K Puram, Delhi - DPCC   12234784                no2
# 1           17  R K Puram, Delhi - DPCC   12234782                 co
# 2           17  R K Puram, Delhi - DPCC   12234790        temperature
# 3           17  R K Puram, Delhi - DPCC   12234788   relativehumidity
# 4           17  R K Puram, Delhi - DPCC   12234789                so2
#
#   parameter_display   value unit               datetime_utc  \
# 0               NO₂  110.20  ppb  2025-11-24 13:00:00+00:00
# 1                CO    3.85  ppb  2025-11-24 13:00:00+00:00
# 2   Temperature (C)   17.50    c  2025-11-24 13:00:00+00:00
# 3                RH   78.00    %  2025-11-24 13:00:00+00:00
# 4               SO₂    3.50  ppb  2025-11-24 13:00:00+00:00
#
#               datetime_local   latitude  ...  district_Visakhapatnam  \
# 0  2025-11-24T18:30:00+05:30  28.563262  ...                   False
# 1  2025-11-24T18:30:00+05:30  28.563262  ...                   False
# 2  2025-11-24T18:30:00+05:30  28.563262  ...                   False
# 3  2025-11-24T18:30:00+05:30  28.563262  ...                   False
# 4  2025-11-24T18:30:00+05:30  28.563262  ...                   False
#
#    parameter_humidity  parameter_no2  parameter_o3  parameter_pm10  \
# 0               False           True         False           False
# 1               False          False         False           False
# 2               False          False         False           False
# 3                True          False         False           False
# 4               False          False         False           False
#
#    parameter_pm25  parameter_so2  parameter_temperature  \
# 0           False          False                  False
# 1           False          False                  False
# 2           False          False                   True
# 3           False          False                  False
# 4           False           True                  False
#
#    parameter_wind_direction  parameter_wind_speed
# 0                     False                 False
# 1                     False                 False
# 2                     False                 False
# 3                     False                 False
# 4                     False                 False
#
# [5 rows x 100 columns]

# %%
stations = df[['location_id', 'latitude', 'longitude']].drop_duplicates()

stations['geometry'] = stations.apply(
    lambda r: Point(r['longitude'], r['latitude']), axis=1
)

gdf_stations = gpd.GeoDataFrame(stations, geometry='geometry', crs="EPSG:4326")
gdf_stations.head()
# Out:
#        location_id   latitude  longitude                   geometry
# 0               17  28.563262  77.186937  POINT (77.18694 28.56326)
# 18286         5408  16.515083  80.518167  POINT (80.51817 16.51508)
# 41355         5542  31.321907  75.578914  POINT (75.57891 31.32191)
# 62929         5544  30.349388  76.366642  POINT (76.36664 30.34939)
# 84885         5546  23.707909  86.414670  POINT (86.41467 23.70791)

# %%
#STEP-3 — Define OSM feature tags
TAGS = {
    'highway': True,  # any road type
    'landuse': ['industrial', 'farmland', 'landfill'],
    'amenity': ['waste_disposal', 'recycling']
}

# %%
SEARCH_RADIUS = 2000   # meters (2 km)

# %%
#STEP-4 — Function to fetch nearby OSM features
def get_osm_features(lat, lon, radius=SEARCH_RADIUS):
    try:
        gdf = ox.features_from_point((lat, lon), tags=TAGS, dist=radius)

        has_road = gdf['highway'].notna().any() if 'highway' in gdf else False
        has_industry = gdf['landuse'].isin(['industrial']).any() if 'landuse' in gdf else False
        has_farmland = gdf['landuse'].isin(['farmland']).any() if 'landuse' in gdf else False
        has_landfill = gdf['landuse'].isin(['landfill']).any() if 'landuse' in gdf else False
        has_dump = gdf['amenity'].isin(['waste_disposal', 'recycling']).any() if 'amenity' in gdf else False

        return pd.Series({
            "near_road": int(has_road),
            "near_industry": int(has_industry),
            "near_farmland": int(has_farmland),
            "near_landfill": int(has_landfill),
            "near_dumpyard": int(has_dump)
        })
    
    except Exception as e:
        return pd.Series({
            "near_road": 0,
            "near_industry": 0,
            "near_farmland": 0,
            "near_landfill": 0,
            "near_dumpyard": 0
        })

# %%
#STEP-5 — Apply to all monitoring locations (with progress)
from tqdm import tqdm
tqdm.pandas()

osm_features = gdf_stations.progress_apply(
    lambda r: get_osm_features(r.latitude, r.longitude), axis=1
)

gdf_stations = pd.concat([gdf_stations, osm_features], axis=1)
gdf_stations.head()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 51/51 [05:44<00:00,  6.76s/it]
#        location_id   latitude  longitude                   geometry  \
# 0               17  28.563262  77.186937  POINT (77.18694 28.56326)
# 18286         5408  16.515083  80.518167  POINT (80.51817 16.51508)
# 41355         5542  31.321907  75.578914  POINT (75.57891 31.32191)
# 62929         5544  30.349388  76.366642  POINT (76.36664 30.34939)
# 84885         5546  23.707909  86.414670  POINT (86.41467 23.70791)
#
#        near_road  near_industry  near_farmland  near_landfill  near_dumpyard
# 0              1              0              0              0              1
# 18286          1              0              1              0              0
# 41355          1              0              0              0              0
# 62929          1              1              0              0              0
# 84885          1              1              0              0              0

# %%
#STEP-6 — Merge OSM features back into main dataset
df = df.merge(
    gdf_stations[['location_id','near_road','near_industry','near_farmland','near_landfill','near_dumpyard']],
    on='location_id',
    how='left'
)

# %%
#fill missing values
df.fillna(0, inplace=True)

# %%
#STEP-7 — Save OSM-enriched dataset
output_file = "data/india_states/osm_enriched_dataset.csv"
df.to_csv(output_file, index=False)

print("Saved:", output_file)
# Out:
# Saved: data/india_states/osm_enriched_dataset.csv
