# %%
# Cell 1: Setup and Configuration
# OpenAQ API Key
import os
from dotenv import load_dotenv
#load_dotenv()  # Load environment variables from .env file if present
OPENAQ_API_KEY = "3a0c22ab3910a3cdaa3ba939eaa270dbe222a36406c7ed6bfc4a9dc325903de5"    

# Force complete reimport of openaq module
import sys
modules_to_remove = [key for key in sys.modules.keys() if key.startswith('openaq')]
for mod in modules_to_remove:
    del sys.modules[mod]

print("OpenAQ modules cleaned from cache")
print(f"API Key configured: {OPENAQ_API_KEY[:10]}...")
# Out:
# OpenAQ modules cleaned from cache
# API Key configured: 3a0c22ab39...

# %%
# Cell 2: Define India States and Major Districts with Coordinates

# Dictionary of Indian states with 5 major districts each
# Format: {state_name: [(district_name, latitude, longitude), ...]}

INDIA_STATES_DISTRICTS = {
    "Andhra Pradesh": [
        ("Visakhapatnam", 17.6868, 83.2185),
        ("Vijayawada", 16.5062, 80.6480),
        ("Guntur", 16.3067, 80.4365),
        ("Tirupati", 13.6288, 79.4192),
        ("Nellore", 14.4426, 79.9865),
    ],
    "Arunachal Pradesh": [
        ("Itanagar", 27.0844, 93.6053),
        ("Naharlagun", 27.1044, 93.6945),
        ("Pasighat", 28.0670, 95.3269),
        ("Tawang", 27.5861, 91.8594),
        ("Ziro", 27.5450, 93.8260),
    ],
    "Assam": [
        ("Guwahati", 26.1445, 91.7362),
        ("Silchar", 24.8333, 92.7789),
        ("Dibrugarh", 27.4728, 94.9120),
        ("Jorhat", 26.7509, 94.2037),
        ("Tezpur", 26.6528, 92.7926),
    ],
    "Bihar": [
        ("Patna", 25.5941, 85.1376),
        ("Gaya", 24.7914, 85.0002),
        ("Muzaffarpur", 26.1209, 85.3647),
        ("Bhagalpur", 25.2425, 86.9842),
        ("Darbhanga", 26.1542, 85.8918),
    ],
    "Chhattisgarh": [
        ("Raipur", 21.2514, 81.6296),
        ("Bhilai", 21.2094, 81.3509),
        ("Bilaspur", 22.0796, 82.1391),
        ("Korba", 22.3595, 82.7501),
        ("Durg", 21.1904, 81.2849),
    ],
    "Goa": [
        ("Panaji", 15.4909, 73.8278),
        ("Margao", 15.2832, 73.9862),
        ("Vasco da Gama", 15.3959, 73.8154),
        ("Mapusa", 15.5916, 73.8127),
        ("Ponda", 15.4034, 74.0152),
    ],
    "Gujarat": [
        ("Ahmedabad", 23.0225, 72.5714),
        ("Surat", 21.1702, 72.8311),
        ("Vadodara", 22.3072, 73.1812),
        ("Rajkot", 22.3039, 70.8022),
        ("Gandhinagar", 23.2156, 72.6369),
    ],
    "Haryana": [
        ("Gurugram", 28.4595, 77.0266),
        ("Faridabad", 28.4089, 77.3178),
        ("Panipat", 29.3909, 76.9635),
        ("Ambala", 30.3782, 76.7767),
        ("Hisar", 29.1492, 75.7217),
    ],
    "Himachal Pradesh": [
        ("Shimla", 31.1048, 77.1734),
        ("Dharamshala", 32.2190, 76.3234),
        ("Manali", 32.2396, 77.1887),
        ("Kullu", 31.9592, 77.1089),
        ("Solan", 30.9045, 77.0967),
    ],
    "Jharkhand": [
        ("Ranchi", 23.3441, 85.3096),
        ("Jamshedpur", 22.8046, 86.2029),
        ("Dhanbad", 23.7957, 86.4304),
        ("Bokaro", 23.6693, 86.1511),
        ("Hazaribagh", 23.9925, 85.3637),
    ],
    "Karnataka": [
        ("Bengaluru", 12.9716, 77.5946),
        ("Mysuru", 12.2958, 76.6394),
        ("Hubli", 15.3647, 75.1240),
        ("Mangaluru", 12.9141, 74.8560),
        ("Belgaum", 15.8497, 74.4977),
    ],
    "Kerala": [
        ("Thiruvananthapuram", 8.5241, 76.9366),
        ("Kochi", 9.9312, 76.2673),
        ("Kozhikode", 11.2588, 75.7804),
        ("Thrissur", 10.5276, 76.2144),
        ("Kannur", 11.8745, 75.3704),
    ],
    "Madhya Pradesh": [
        ("Bhopal", 23.2599, 77.4126),
        ("Indore", 22.7196, 75.8577),
        ("Jabalpur", 23.1815, 79.9864),
        ("Gwalior", 26.2183, 78.1828),
        ("Ujjain", 23.1765, 75.7885),
    ],
    "Maharashtra": [
        ("Mumbai", 19.0760, 72.8777),
        ("Pune", 18.5204, 73.8567),
        ("Nagpur", 21.1458, 79.0882),
        ("Nashik", 19.9975, 73.7898),
        ("Aurangabad", 19.8762, 75.3433),
    ],
    "Manipur": [
        ("Imphal", 24.8170, 93.9368),
        ("Thoubal", 24.6342, 94.0132),
        ("Bishnupur", 24.6270, 93.7610),
        ("Churachandpur", 24.3333, 93.6833),
        ("Ukhrul", 25.0492, 94.3616),
    ],
    "Meghalaya": [
        ("Shillong", 25.5788, 91.8933),
        ("Tura", 25.5144, 90.2003),
        ("Jowai", 25.4529, 92.2035),
        ("Nongpoh", 25.9042, 91.8806),
        ("Williamnagar", 25.4939, 90.6178),
    ],
    "Mizoram": [
        ("Aizawl", 23.7271, 92.7176),
        ("Lunglei", 22.8839, 92.7322),
        ("Champhai", 23.4567, 93.3281),
        ("Serchhip", 23.3067, 92.8506),
        ("Kolasib", 24.2239, 92.6789),
    ],
    "Nagaland": [
        ("Kohima", 25.6751, 94.1086),
        ("Dimapur", 25.9064, 93.7273),
        ("Mokokchung", 26.3167, 94.5167),
        ("Tuensang", 26.2667, 94.8333),
        ("Wokha", 26.1000, 94.2667),
    ],
    "Odisha": [
        ("Bhubaneswar", 20.2961, 85.8245),
        ("Cuttack", 20.4625, 85.8830),
        ("Rourkela", 22.2604, 84.8536),
        ("Puri", 19.8135, 85.8312),
        ("Sambalpur", 21.4669, 83.9756),
    ],
    "Punjab": [
        ("Ludhiana", 30.9010, 75.8573),
        ("Amritsar", 31.6340, 74.8723),
        ("Jalandhar", 31.3260, 75.5762),
        ("Patiala", 30.3398, 76.3869),
        ("Bathinda", 30.2110, 74.9455),
    ],
    "Rajasthan": [
        ("Jaipur", 26.9124, 75.7873),
        ("Jodhpur", 26.2389, 73.0243),
        ("Udaipur", 24.5854, 73.7125),
        ("Kota", 25.2138, 75.8648),
        ("Ajmer", 26.4499, 74.6399),
    ],
    "Sikkim": [
        ("Gangtok", 27.3389, 88.6065),
        ("Namchi", 27.1667, 88.3500),
        ("Gyalshing", 27.2833, 88.2500),
        ("Mangan", 27.5167, 88.5333),
        ("Rangpo", 27.1833, 88.5167),
    ],
    "Tamil Nadu": [
        ("Chennai", 13.0827, 80.2707),
        ("Coimbatore", 11.0168, 76.9558),
        ("Madurai", 9.9252, 78.1198),
        ("Tiruchirappalli", 10.7905, 78.7047),
        ("Salem", 11.6643, 78.1460),
    ],
    "Telangana": [
        ("Hyderabad", 17.3850, 78.4867),
        ("Warangal", 17.9784, 79.5941),
        ("Nizamabad", 18.6725, 78.0940),
        ("Karimnagar", 18.4386, 79.1288),
        ("Khammam", 17.2473, 80.1514),
    ],
    "Tripura": [
        ("Agartala", 23.8315, 91.2868),
        ("Dharmanagar", 24.3667, 92.1667),
        ("Udaipur", 23.5333, 91.4833),
        ("Kailashahar", 24.3333, 92.0167),
        ("Belonia", 23.2500, 91.4500),
    ],
    "Uttar Pradesh": [
        ("Lucknow", 26.8467, 80.9462),
        ("Kanpur", 26.4499, 80.3319),
        ("Varanasi", 25.3176, 82.9739),
        ("Agra", 27.1767, 78.0081),
        ("Noida", 28.5355, 77.3910),
    ],
    "Uttarakhand": [
        ("Dehradun", 30.3165, 78.0322),
        ("Haridwar", 29.9457, 78.1642),
        ("Rishikesh", 30.0869, 78.2676),
        ("Nainital", 29.3919, 79.4542),
        ("Haldwani", 29.2183, 79.5130),
    ],
    "West Bengal": [
        ("Kolkata", 22.5726, 88.3639),
        ("Howrah", 22.5958, 88.2636),
        ("Durgapur", 23.5204, 87.3119),
        ("Siliguri", 26.7271, 88.6393),
        ("Asansol", 23.6889, 86.9661),
    ],
    # Union Territories
    "Delhi": [
        ("New Delhi", 28.6139, 77.2090),
        ("Dwarka", 28.5921, 77.0460),
        ("Rohini", 28.7495, 77.0565),
        ("Shahdara", 28.6731, 77.2868),
        ("Najafgarh", 28.6092, 76.9798),
    ],
    "Chandigarh": [
        ("Chandigarh Sector 17", 30.7412, 76.7684),
        ("Chandigarh Sector 22", 30.7333, 76.7794),
        ("Chandigarh Sector 35", 30.7233, 76.7580),
        ("Chandigarh Sector 43", 30.7106, 76.7451),
        ("Manimajra", 30.7333, 76.8333),
    ],
    "Puducherry": [
        ("Puducherry", 11.9416, 79.8083),
        ("Karaikal", 10.9254, 79.8380),
        ("Mahe", 11.7036, 75.5360),
        ("Yanam", 16.7333, 82.2167),
        ("Ozhukarai", 11.9500, 79.7667),
    ],
    "Jammu and Kashmir": [
        ("Srinagar", 34.0837, 74.7973),
        ("Jammu", 32.7266, 74.8570),
        ("Anantnag", 33.7311, 75.1487),
        ("Baramulla", 34.2095, 74.3436),
        ("Udhampur", 32.9160, 75.1322),
    ],
    "Ladakh": [
        ("Leh", 34.1526, 77.5771),
        ("Kargil", 34.5539, 76.1349),
        ("Diskit", 34.5500, 77.5500),
        ("Nyoma", 33.2000, 78.6500),
        ("Zanskar", 33.7500, 76.8500),
    ],
}

print(f"Configured {len(INDIA_STATES_DISTRICTS)} states/UTs")
total_districts = sum(len(districts) for districts in INDIA_STATES_DISTRICTS.values())
print(f"Total districts to query: {total_districts}")
# Out:
# Configured 33 states/UTs
# Total districts to query: 165

# %%
# !pip install openaq
# Out:
# Requirement already satisfied: openaq in c:\users\aditi\anaconda3\lib\site-packages (0.6.0)
# Requirement already satisfied: httpx<1.0,>=0.28.1 in c:\users\aditi\anaconda3\lib\site-packages (from openaq) (0.28.1)
# Requirement already satisfied: anyio in c:\users\aditi\anaconda3\lib\site-packages (from httpx<1.0,>=0.28.1->openaq) (4.2.0)
# Requirement already satisfied: certifi in c:\users\aditi\anaconda3\lib\site-packages (from httpx<1.0,>=0.28.1->openaq) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\aditi\anaconda3\lib\site-packages (from httpx<1.0,>=0.28.1->openaq) (1.0.2)
# Requirement already satisfied: idna in c:\users\aditi\anaconda3\lib\site-packages (from httpx<1.0,>=0.28.1->openaq) (3.4)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\aditi\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.28.1->openaq) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\aditi\anaconda3\lib\site-packages (from anyio->httpx<1.0,>=0.28.1->openaq) (1.3.0)

# %%
# Cell 3: Import Libraries and Define Helper Functions

import datetime
import time
import os
import pandas as pd
from openaq import OpenAQ

# Search radius in meters (25 km)
RADIUS_METERS = 25000

# Define date range: last 30 days to today
date_to = datetime.datetime.now(datetime.timezone.utc)
date_from = date_to - datetime.timedelta(days=30)

print(f"Date range: {date_from.strftime('%Y-%m-%d')} to {date_to.strftime('%Y-%m-%d')}")
print(f"Search radius: {RADIUS_METERS/1000} km")

# Define the parameters we want to collect (flexible matching)
WANTED_KEYWORDS = {
    "pm25": ["pm25", "pm2.5", "pm2_5"],
    "pm10": ["pm10"],
    "no2": ["no2", "nitrogen dioxide"],
    "co": ["co", "carbon monoxide"],
    "so2": ["so2", "sulfur dioxide", "sulphur dioxide"],
    "o3": ["o3", "ozone"],
    "temperature": ["temperature", "temp", "at"],
    "humidity": ["humidity", "rh", "relativehumidity", "relative humidity"],
    "wind_speed": ["windspeed", "wind_speed", "ws", "wind speed"],
    "wind_direction": ["winddirection", "wind_direction", "wd", "wind direction"]
}

# Global set to track already-used location IDs (prevents duplicate data)
used_location_ids = set()

def is_wanted_parameter(param_name):
    """Check if parameter name matches any of our wanted parameters"""
    if not param_name:
        return None
    param_lower = param_name.lower().strip()
    for category, keywords in WANTED_KEYWORDS.items():
        for kw in keywords:
            if kw == param_lower or param_lower.startswith(kw):
                return category
    return None

def get_sensor_param_info(sensor):
    """Extract parameter info from sensor, handling both dict and object responses"""
    param_name = ""
    param_display = ""
    param_units = ""
    
    if hasattr(sensor, 'parameter'):
        param = sensor.parameter
        # Handle dict response
        if isinstance(param, dict):
            param_name = param.get('name', '')
            param_display = param.get('display_name', param_name)
            param_units = param.get('units', '')
        # Handle object response
        else:
            if hasattr(param, 'name') and param.name:
                param_name = param.name
            if hasattr(param, 'display_name') and param.display_name:
                param_display = param.display_name
            if hasattr(param, 'units') and param.units:
                param_units = param.units
    
    # If still empty, try the sensor name
    if not param_name and hasattr(sensor, 'name') and sensor.name:
        param_name = sensor.name.split()[0] if sensor.name else ""
        param_display = sensor.name
    
    return param_name, param_display, param_units

def fetch_district_data(client, state_name, district_name, latitude, longitude, date_from, date_to):
    """
    Fetch air quality data for a specific district.
    Uses only ONE unique location that hasn't been used before.
    """
    global used_location_ids
    district_data = []
    
    try:
        # Fetch locations around the district
        loc_response = client.locations.list(
            coordinates=(latitude, longitude),
            radius=RADIUS_METERS,
            limit=100
        )
        locations = loc_response.results
        
        if not locations:
            return district_data, 0, None, "no_stations"
        
        # Find the first location that hasn't been used yet
        selected_loc = None
        for loc in locations:
            if loc.id not in used_location_ids:
                selected_loc = loc
                break
        
        # If all locations were already used, skip this district
        if selected_loc is None:
            return district_data, len(locations), None, "all_used"
        
        # Mark this location as used
        used_location_ids.add(selected_loc.id)
        
        loc_id = selected_loc.id
        loc_name = selected_loc.name
        loc_lat = selected_loc.coordinates.latitude
        loc_lon = selected_loc.coordinates.longitude
        
        # Get sensors for this location
        try:
            sensors_response = client.locations.sensors(loc_id)
            sensors = sensors_response.results
        except Exception:
            return district_data, len(locations), loc_name, "sensor_error"
        
        # For each sensor, fetch measurements if it's a wanted parameter
        for sensor in sensors:
            sensor_id = sensor.id
            param_name, param_display, param_units = get_sensor_param_info(sensor)
            
            matched_category = is_wanted_parameter(param_name)
            if not matched_category:
                continue
            
            # Fetch measurements with pagination
            page = 1
            while True:
                try:
                    meas_response = client.measurements.list(
                        sensors_id=sensor_id,
                        datetime_from=date_from,
                        datetime_to=date_to,
                        page=page,
                        limit=1000
                    )
                    results = meas_response.results
                    
                    if not results:
                        break
                    
                    for m in results:
                        datetime_utc = None
                        datetime_local = None
                        
                        if hasattr(m, 'period') and m.period:
                            if hasattr(m.period, 'datetime_from'):
                                dt_from = m.period.datetime_from
                                if hasattr(dt_from, 'utc'):
                                    datetime_utc = str(dt_from.utc)
                                if hasattr(dt_from, 'local'):
                                    datetime_local = str(dt_from.local)
                        
                        record = {
                            "state": state_name,
                            "district": district_name,
                            "location_id": loc_id,
                            "location_name": loc_name,
                            "sensor_id": sensor_id,
                            "parameter": matched_category,
                            "parameter_original": param_name,
                            "parameter_display": param_display,
                            "value": m.value if hasattr(m, 'value') else None,
                            "unit": param_units,
                            "datetime_utc": datetime_utc,
                            "datetime_local": datetime_local,
                            "latitude": loc_lat,
                            "longitude": loc_lon,
                        }
                        district_data.append(record)
                    
                    page += 1
                    time.sleep(0.05)  # Rate limiting
                    
                except Exception:
                    break
        
        return district_data, len(locations), loc_name, "success"
        
    except Exception as e:
        return district_data, 0, None, "error"

print("Helper functions defined successfully!")
print("Note: Each location will only be used ONCE across all districts.")
# Out:
# Date range: 2025-11-24 to 2025-12-24
# Search radius: 25.0 km
# Helper functions defined successfully!
# Note: Each location will only be used ONCE across all districts.

# %%
# Cell 4: Main Data Collection Loop

# Reset the used locations tracker (important if re-running)
used_location_ids.clear()

# Initialize the OpenAQ client
client = OpenAQ(api_key=OPENAQ_API_KEY)

# Store all collected data
all_india_data = []

# Statistics tracking
stats = {
    "states_processed": 0,
    "districts_with_data": 0,
    "districts_without_stations": 0,
    "districts_skipped_duplicate": 0,
    "districts_no_params": 0,
    "total_records": 0,
    "unique_locations_used": 0
}

print("="*70)
print("Starting India-wide Air Quality Data Collection")
print("(Using ONLY 1 UNIQUE location per district - no duplicates)")
print("="*70)

for state_name, districts in INDIA_STATES_DISTRICTS.items():
    print(f"\n{'='*60}")
    print(f"Processing: {state_name}")
    print(f"{'='*60}")
    
    state_records = 0
    
    for district_name, lat, lon in districts:
        print(f"  📍 {district_name} ({lat:.4f}, {lon:.4f})...", end=" ")
        
        district_data, num_locations, location_used, status = fetch_district_data(
            client, state_name, district_name, lat, lon, date_from, date_to
        )
        
        if status == "success" and district_data:
            all_india_data.extend(district_data)
            stats["districts_with_data"] += 1
            stats["unique_locations_used"] += 1
            state_records += len(district_data)
            print(f"✓ {len(district_data)} records from '{location_used}'")
        elif status == "all_used":
            stats["districts_skipped_duplicate"] += 1
            print(f"⏭️ Skipped (all {num_locations} nearby stations already used)")
        elif status == "no_stations":
            stats["districts_without_stations"] += 1
            print(f"✗ No monitoring stations found")
        elif status == "success" and not district_data:
            stats["districts_no_params"] += 1
            print(f"⚠️ Station found but no matching parameters")
        else:
            stats["districts_without_stations"] += 1
            print(f"✗ Error fetching data")
        
        # Small delay between districts
        time.sleep(0.1)
    
    stats["states_processed"] += 1
    stats["total_records"] += state_records
    print(f"  📊 State total: {state_records} records")

# Close the client
client.close()

print("\n" + "="*70)
print("Data Collection Complete!")
print("="*70)
print(f"States/UTs processed: {stats['states_processed']}")
print(f"Districts with data: {stats['districts_with_data']}")
print(f"Districts skipped (duplicate stations): {stats['districts_skipped_duplicate']}")
print(f"Districts without stations: {stats['districts_without_stations']}")
print(f"Districts with no matching params: {stats['districts_no_params']}")
print(f"Unique monitoring locations used: {stats['unique_locations_used']}")
print(f"Total records collected: {stats['total_records']}")
# Out:
# ======================================================================
# Starting India-wide Air Quality Data Collection
# (Using ONLY 1 UNIQUE location per district - no duplicates)
# ======================================================================
#
# ============================================================
# Processing: Andhra Pradesh
# ============================================================
#   📍 Visakhapatnam (17.6868, 83.2185)... ✓ 22567 records from 'GVM Corporation, Visakhapatnam - APPCB'
#   📍 Vijayawada (16.5062, 80.6480)... ✓ 24182 records from 'Secretariat, Amaravati - APPCB'
#   📍 Guntur (16.3067, 80.4365)... ⚠️ Station found but no matching parameters
#   📍 Tirupati (13.6288, 79.4192)... ✓ 25246 records from 'Tirumala, Tirupati - APPCB'
#   📍 Nellore (14.4426, 79.9865)... ✗ No monitoring stations found
#   📊 State total: 71995 records
#
# ============================================================
# Processing: Arunachal Pradesh
# ============================================================
#   📍 Itanagar (27.0844, 93.6053)... ✓ 22830 records from 'Naharlagun, Naharlagun - APSPCB'
#   📍 Naharlagun (27.1044, 93.6945)... ⏭️ Skipped (all 1 nearby stations already used)
#   📍 Pasighat (28.0670, 95.3269)... ✗ No monitoring stations found
#   📍 Tawang (27.5861, 91.8594)... ✗ No monitoring stations found
#   📍 Ziro (27.5450, 93.8260)... ✗ No monitoring stations found
#   📊 State total: 22830 records
#
# ============================================================
# Processing: Assam
# ============================================================
#   📍 Guwahati (26.1445, 91.7362)... ⚠️ Station found but no matching parameters
#   📍 Silchar (24.8333, 92.7789)... ✓ 25707 records from 'Tarapur, Silchar - PCBA'
#   📍 Dibrugarh (27.4728, 94.9120)... ✗ No monitoring stations found
#   📍 Jorhat (26.7509, 94.2037)... ✗ No monitoring stations found
#   📍 Tezpur (26.6528, 92.7926)... ✗ No monitoring stations found
#   📊 State total: 25707 records
#
# ============================================================
# Processing: Bihar
# ============================================================
#   📍 Patna (25.5941, 85.1376)... ✓ 19964 records from 'IGSC Planetarium Complex, Patna - BSPCB'
#   📍 Gaya (24.7914, 85.0002)... ⚠️ Station found but no matching parameters
#   📍 Muzaffarpur (26.1209, 85.3647)... ⚠️ Station found but no matching parameters
#   📍 Bhagalpur (25.2425, 86.9842)... ✓ 23546 records from 'Mayaganj, Bhagalpur - BSPCB'
#   📍 Darbhanga (26.1542, 85.8918)... ⚠️ Station found but no matching parameters
#   📊 State total: 43510 records
#
# ============================================================
# Processing: Chhattisgarh
# ============================================================
#   📍 Raipur (21.2514, 81.6296)... ✓ 22514 records from 'AIIMS, Raipur - CECB'
#   📍 Bhilai (21.2094, 81.3509)... ✓ 14617 records from 'Civic Center, Bhilai - Bhilai Steel Plant'
#   📍 Bilaspur (22.0796, 82.1391)... ✓ 22859 records from 'Mangala, Bilaspur - CECB'
#   📍 Korba (22.3595, 82.7501)... ✓ 21996 records from 'Rampur, Korba - CECB'
#   📍 Durg (21.1904, 81.2849)... ✓ 16961 records from 'Hathkhoj, Bhilai - CECB'
#   📊 State total: 98947 records
#
# ============================================================
# Processing: Goa
# ============================================================
#   📍 Panaji (15.4909, 73.8278)... ✗ No monitoring stations found
#   📍 Margao (15.2832, 73.9862)... ✗ No monitoring stations found
#   📍 Vasco da Gama (15.3959, 73.8154)... ✗ No monitoring stations found
#   📍 Mapusa (15.5916, 73.8127)... ✗ No monitoring stations found
#   📍 Ponda (15.4034, 74.0152)... ✗ No monitoring stations found
#   📊 State total: 0 records
#
# ============================================================
# Processing: Gujarat
# ============================================================
#   📍 Ahmedabad (23.0225, 72.5714)... ✓ 24037 records from 'Maninagar, Ahmedabad - GPCB'
#   📍 Surat (21.1702, 72.8311)... ✓ 21807 records from 'Science Center, Surat - SMC'
#   📍 Vadodara (22.3072, 73.1812)... ✓ 9609 records from 'GIDC, Nandesari - Nandesari Ind. Association'
#   📍 Rajkot (22.3039, 70.8022)... ✗ No monitoring stations found
#   📍 Gandhinagar (23.2156, 72.6369)... ✓ 23097 records from 'Sector-10, Gandhinagar - GPCB'
#   📊 State total: 78550 records
#
# ============================================================
# Processing: Haryana
# ============================================================
#   📍 Gurugram (28.4595, 77.0266)... ⚠️ Station found but no matching parameters
#   📍 Faridabad (28.4089, 77.3178)... ✓ 24895 records from 'R K Puram, Delhi - DPCC'
#   📍 Panipat (29.3909, 76.9635)... ✓ 18452 records from 'Sector-18, Panipat - HSPCB'
#   📍 Ambala (30.3782, 76.7767)... ✓ 19887 records from 'Patti Mehar, Ambala - HSPCB'
#   📍 Hisar (29.1492, 75.7217)...
# HTTP 500 - Internal Server Error
# NoneType: None
# ✗ Error fetching data
#   📊 State total: 63234 records
#
# ============================================================
# Processing: Himachal Pradesh
# ============================================================
#   📍 Shimla (31.1048, 77.1734)... ✗ No monitoring stations found
#   📍 Dharamshala (32.2190, 76.3234)... ✗ No monitoring stations found
#   📍 Manali (32.2396, 77.1887)... ✗ No monitoring stations found
#   📍 Kullu (31.9592, 77.1089)... ✗ No monitoring stations found
#   📍 Solan (30.9045, 77.0967)... ✗ No monitoring stations found
#   📊 State total: 0 records
#
# ============================================================
# Processing: Jharkhand
# ============================================================
#   📍 Ranchi (23.3441, 85.3096)... ✗ No monitoring stations found
#   📍 Jamshedpur (22.8046, 86.2029)... ✗ No monitoring stations found
#   📍 Dhanbad (23.7957, 86.4304)... ✓ 7478 records from 'Tata Stadium - Jorapokhar - JSPCB'
#   📍 Bokaro (23.6693, 86.1511)... ✗ No monitoring stations found
#   📍 Hazaribagh (23.9925, 85.3637)... ✗ No monitoring stations found
#   📊 State total: 7478 records
#
# ============================================================
# Processing: Karnataka
# ============================================================
#   📍 Bengaluru (12.9716, 77.5946)... ⚠️ Station found but no matching parameters
#   📍 Mysuru (12.2958, 76.6394)... ✗ No monitoring stations found
#   📍 Hubli (15.3647, 75.1240)... ⚠️ Station found but no matching parameters
#   📍 Mangaluru (12.9141, 74.8560)... ✓ 12078 records from 'Kadri, Mangalore - KSPCB'
#   📍 Belgaum (15.8497, 74.4977)... ✓ 6524 records from 'Ramteerth Nagar, Belgaum - KSPCB'
#   📊 State total: 18602 records
#
# ============================================================
# Processing: Kerala
# ============================================================
#   📍 Thiruvananthapuram (8.5241, 76.9366)... ✓ 19332 records from 'Plammoodu, Thiruvananthapuram - Kerala PCB'
#   📍 Kochi (9.9312, 76.2673)... ✓ 11060 records from 'Udyogamandal, Eloor - Kerala PCB'
#   📍 Kozhikode (11.2588, 75.7804)... ⚠️ Station found but no matching parameters
#   📍 Thrissur (10.5276, 76.2144)... ✓ 17631 records from 'Corporation Ground, Thrissur- Kerala PCB'
#   📍 Kannur (11.8745, 75.3704)... ✓ 23562 records from 'Thavakkara, Kannur - Kerala PCB'
#   📊 State total: 71585 records
#
# ============================================================
# Processing: Madhya Pradesh
# ============================================================
#   📍 Bhopal (23.2599, 77.4126)... ✓ 18976 records from 'Sector-D Industrial Area, Mandideep - MPPCB'
#   📍 Indore (22.7196, 75.8577)... ✓ 24198 records from 'Sector-2 Industrial Area, Pithampur - MPPCB'
#   📍 Jabalpur (23.1815, 79.9864)... ✓ 25015 records from 'Marhatal, Jabalpur - MPPCB'
#   📍 Gwalior (26.2183, 78.1828)... ✓ 24326 records from 'City Center, Gwalior - MPPCB'
#   📍 Ujjain (23.1765, 75.7885)... ⚠️ Station found but no matching parameters
#   📊 State total: 92515 records
#
# ============================================================
# Processing: Maharashtra
# ============================================================
#   📍 Mumbai (19.0760, 72.8777)... ⚠️ Station found but no matching parameters
#   📍 Pune (18.5204, 73.8567)... ⚠️ Station found but no matching parameters
#   📍 Nagpur (21.1458, 79.0882)... ✓ 22090 records from 'Opp GPO Civil Lines, Nagpur - MPCB'
#   📍 Nashik (19.9975, 73.7898)... ✓ 22383 records from 'Gangapur Road, Nashik - MPCB'
#   📍 Aurangabad (19.8762, 75.3433)... ✓ 19001 records from 'More Chowk Waluj, Aurangabad - MPCB'
#   📊 State total: 63474 records
#
# ============================================================
# Processing: Manipur
# ============================================================
#   📍 Imphal (24.8170, 93.9368)... ⚠️ Station found but no matching parameters
#   📍 Thoubal (24.6342, 94.0132)... ⚠️ Station found but no matching parameters
#   📍 Bishnupur (24.6270, 93.7610)... ⚠️ Station found but no matching parameters
#   📍 Churachandpur (24.3333, 93.6833)... ✗ No monitoring stations found
#   📍 Ukhrul (25.0492, 94.3616)... ✗ No monitoring stations found
#   📊 State total: 0 records
#
# ============================================================
# Processing: Meghalaya
# ============================================================
#   📍 Shillong (25.5788, 91.8933)... ✓ 25290 records from 'Lumpyngngad, Shillong - Meghalaya PCB'
#   📍 Tura (25.5144, 90.2003)... ✗ No monitoring stations found
#   📍 Jowai (25.4529, 92.2035)... ✗ No monitoring stations found
#   📍 Nongpoh (25.9042, 91.8806)... ✓ 16429 records from 'Central Academy for SFS, Byrnihat - PCBA'
#   📍 Williamnagar (25.4939, 90.6178)... ✗ No monitoring stations found
#   📊 State total: 41719 records
#
# ============================================================
# Processing: Mizoram
# ============================================================
#   📍 Aizawl (23.7271, 92.7176)... ✓ 14292 records from 'Sikulpuikawn, Aizawl - Mizoram PCB'
#   📍 Lunglei (22.8839, 92.7322)... ✗ No monitoring stations found
#   📍 Champhai (23.4567, 93.3281)... ✗ No monitoring stations found
#   📍 Serchhip (23.3067, 92.8506)... ✗ No monitoring stations found
#   📍 Kolasib (24.2239, 92.6789)... ✗ No monitoring stations found
#   📊 State total: 14292 records
#
# ============================================================
# Processing: Nagaland
# ============================================================
#   📍 Kohima (25.6751, 94.1086)... ✓ 24360 records from 'PWD Juction, Kohima - NPCB'
#   📍 Dimapur (25.9064, 93.7273)... ✗ No monitoring stations found
#   📍 Mokokchung (26.3167, 94.5167)... ✗ No monitoring stations found
#   📍 Tuensang (26.2667, 94.8333)... ✗ No monitoring stations found
#   📍 Wokha (26.1000, 94.2667)... ✗ No monitoring stations found
#   📊 State total: 24360 records
#
# ============================================================
# Processing: Odisha
# ============================================================
#   📍 Bhubaneswar (20.2961, 85.8245)... ✓ 24517 records from 'Lingraj Mandir, Bhubaneswar - OSPCB'
#   📍 Cuttack (20.4625, 85.8830)... ✓ 25127 records from 'CDA Area, Cuttack - OSPCB'
#   📍 Rourkela (22.2604, 84.8536)... ✓ 20162 records from 'Raghunathpali, Rourkela - OSPCB'
#   📍 Puri (19.8135, 85.8312)... ✗ No monitoring stations found
#   📍 Sambalpur (21.4669, 83.9756)... ✗ No monitoring stations found
#   📊 State total: 69806 records
#
# ============================================================
# Processing: Punjab
# ============================================================
#   📍 Ludhiana (30.9010, 75.8573)... ✓ 21676 records from 'Punjab Agricultural University, Ludhiana - PPCB'
#   📍 Amritsar (31.6340, 74.8723)... ✓ 23913 records from 'Golden Temple, Amritsar - PPCB'
#   📍 Jalandhar (31.3260, 75.5762)... ✓ 24541 records from 'Civil Line, Jalandhar - PPCB'
#   📍 Patiala (30.3398, 76.3869)... ✓ 24611 records from 'Model Town, Patiala - PPCB'
#   📍 Bathinda (30.2110, 74.9455)... ✓ 21120 records from 'Hardev Nagar, Bathinda - PPCB'
#   📊 State total: 115861 records
#
# ============================================================
# Processing: Rajasthan
# ============================================================
#   📍 Jaipur (26.9124, 75.7873)... ⚠️ Station found but no matching parameters
#   📍 Jodhpur (26.2389, 73.0243)... ⚠️ Station found but no matching parameters
#   📍 Udaipur (24.5854, 73.7125)... ✓ 19365 records from 'Ashok Nagar, Udaipur - RSPCB'
#   📍 Kota (25.2138, 75.8648)... ✓ 24826 records from 'Shrinath Puram, Kota - RSPCB'
#   📍 Ajmer (26.4499, 74.6399)... ✓ 24077 records from 'Civil Lines, Ajmer - RSPCB'
#   📊 State total: 68268 records
#
# ============================================================
# Processing: Sikkim
# ============================================================
#   📍 Gangtok (27.3389, 88.6065)... ⚠️ Station found but no matching parameters
#   📍 Namchi (27.1667, 88.3500)... ✗ No monitoring stations found
#   📍 Gyalshing (27.2833, 88.2500)... ✗ No monitoring stations found
#   📍 Mangan (27.5167, 88.5333)... ✓ 15030 records from 'Zero Point GICI, Gangtok - SSPCB'
#   📍 Rangpo (27.1833, 88.5167)... ⏭️ Skipped (all 2 nearby stations already used)
#   📊 State total: 15030 records
#
# ============================================================
# Processing: Tamil Nadu
# ============================================================
#   📍 Chennai (13.0827, 80.2707)... ⚠️ Station found but no matching parameters
#   📍 Coimbatore (11.0168, 76.9558)... ✓ 23914 records from 'SIDCO Kurichi, Coimbatore - TNPCB'
#   📍 Madurai (9.9252, 78.1198)... ✓ 2429 records from 'Uchapatti, Madurai - TNPCB'
#   📍 Tiruchirappalli (10.7905, 78.7047)... ✗ Error fetching data
#   📍 Salem (11.6643, 78.1460)... ✗ Error fetching data
#   📊 State total: 26343 records
#
# ============================================================
# Processing: Telangana
# ============================================================
#   📍 Hyderabad (17.3850, 78.4867)... ✗ Error fetching data
#   📍 Warangal (17.9784, 79.5941)... ✗ Error fetching data
#   📍 Nizamabad (18.6725, 78.0940)... ✗ Error fetching data
#   📍 Karimnagar (18.4386, 79.1288)... ✗ Error fetching data
#   📍 Khammam (17.2473, 80.1514)... ✗ Error fetching data
#   📊 State total: 0 records
#
# ============================================================
# Processing: Tripura
# ============================================================
#   📍 Agartala (23.8315, 91.2868)... ✗ Error fetching data
#   📍 Dharmanagar (24.3667, 92.1667)... ✗ Error fetching data
#   📍 Udaipur (23.5333, 91.4833)... ✗ Error fetching data
#   📍 Kailashahar (24.3333, 92.0167)... ✗ Error fetching data
#   📍 Belonia (23.2500, 91.4500)... ✗ Error fetching data
#   📊 State total: 0 records
#
# ============================================================
# Processing: Uttar Pradesh
# ============================================================
#   📍 Lucknow (26.8467, 80.9462)... ✗ Error fetching data
#   📍 Kanpur (26.4499, 80.3319)... ✗ Error fetching data
#   📍 Varanasi (25.3176, 82.9739)... ✗ Error fetching data
#   📍 Agra (27.1767, 78.0081)... ✗ Error fetching data
#   📍 Noida (28.5355, 77.3910)... ✗ Error fetching data
#   📊 State total: 0 records
#
# ============================================================
# Processing: Uttarakhand
# ============================================================
#   📍 Dehradun (30.3165, 78.0322)... ✗ Error fetching data
#   📍 Haridwar (29.9457, 78.1642)... ✗ Error fetching data
#   📍 Rishikesh (30.0869, 78.2676)... ✗ Error fetching data
#   📍 Nainital (29.3919, 79.4542)... ✗ Error fetching data
#   📍 Haldwani (29.2183, 79.5130)... ✗ Error fetching data
#   📊 State total: 0 records
#
# ============================================================
# Processing: West Bengal
# ============================================================
#   📍 Kolkata (22.5726, 88.3639)... ✗ Error fetching data
#   📍 Howrah (22.5958, 88.2636)... ✗ Error fetching data
#   📍 Durgapur (23.5204, 87.3119)... ✗ Error fetching data
#   📍 Siliguri (26.7271, 88.6393)... ✗ Error fetching data
#   📍 Asansol (23.6889, 86.9661)... ✗ Error fetching data
#   📊 State total: 0 records
#
# ============================================================
# Processing: Delhi
# ============================================================
#   📍 New Delhi (28.6139, 77.2090)... ✗ Error fetching data
#   📍 Dwarka (28.5921, 77.0460)... ✗ Error fetching data
#   📍 Rohini (28.7495, 77.0565)... ✗ Error fetching data
#   📍 Shahdara (28.6731, 77.2868)... ✗ Error fetching data
#   📍 Najafgarh (28.6092, 76.9798)... ✗ Error fetching data
#   📊 State total: 0 records
#
# ============================================================
# Processing: Chandigarh
# ============================================================
#   📍 Chandigarh Sector 17 (30.7412, 76.7684)... ✗ Error fetching data
#   📍 Chandigarh Sector 22 (30.7333, 76.7794)... ✗ Error fetching data
#   📍 Chandigarh Sector 35 (30.7233, 76.7580)... ✗ Error fetching data
#   📍 Chandigarh Sector 43 (30.7106, 76.7451)... ✗ Error fetching data
#   📍 Manimajra (30.7333, 76.8333)... ✗ Error fetching data
#   📊 State total: 0 records
#
# ============================================================
# Processing: Puducherry
# ============================================================
#   📍 Puducherry (11.9416, 79.8083)... ✗ Error fetching data
#   📍 Karaikal (10.9254, 79.8380)... ✗ Error fetching data
#   📍 Mahe (11.7036, 75.5360)... ✗ Error fetching data
#   📍 Yanam (16.7333, 82.2167)... ✗ Error fetching data
#   📍 Ozhukarai (11.9500, 79.7667)... ✗ Error fetching data
#   📊 State total: 0 records
#
# ============================================================
# Processing: Jammu and Kashmir
# ============================================================
#   📍 Srinagar (34.0837, 74.7973)... ✗ Error fetching data
#   📍 Jammu (32.7266, 74.8570)... ✗ Error fetching data
#   📍 Anantnag (33.7311, 75.1487)... ✗ Error fetching data
#   📍 Baramulla (34.2095, 74.3436)... ✗ Error fetching data
#   📍 Udhampur (32.9160, 75.1322)... ✗ Error fetching data
#   📊 State total: 0 records
#
# ============================================================
# Processing: Ladakh
# ============================================================
#   📍 Leh (34.1526, 77.5771)... ✗ Error fetching data
#   📍 Kargil (34.5539, 76.1349)... ✗ Error fetching data
#   📍 Diskit (34.5500, 77.5500)... ✗ Error fetching data
#   📍 Nyoma (33.2000, 78.6500)... ✗ Error fetching data
#   📍 Zanskar (33.7500, 76.8500)... ✗ Error fetching data
#   📊 State total: 0 records
#
# ======================================================================
# Data Collection Complete!
# ======================================================================
# States/UTs processed: 33
# Districts with data: 51
# Districts skipped (duplicate stations): 2
# Districts without stations: 93
# Districts with no matching params: 19
# Unique monitoring locations used: 51
# Total records collected: 1034106

# %%
# Cell 5: Build DataFrame and Save Data

# Create DataFrame
df = pd.DataFrame(all_india_data)

print(f"Total records in DataFrame: {len(df)}")

if len(df) > 0:
    # Display data preview
    print("\n" + "="*60)
    print("Data Preview:")
    print("="*60)
    print(df.head(10))
    
    # Summary statistics
    print("\n" + "="*60)
    print("Summary by State:")
    print("="*60)
    state_summary = df.groupby('state').agg({
        'district': 'nunique',
        'location_id': 'nunique',
        'value': 'count'
    }).rename(columns={
        'district': 'districts',
        'location_id': 'locations',
        'value': 'records'
    })
    print(state_summary)
    
    print("\n" + "="*60)
    print("Parameter Distribution:")
    print("="*60)
    print(df['parameter'].value_counts())
    
    print("\n" + "="*60)
    print("Data Summary by Parameter:")
    print("="*60)
    param_summary = df.groupby('parameter')['value'].agg(['count', 'mean', 'min', 'max'])
    print(param_summary)
    
    # Create output directory
    output_dir = "data/india_states"
    os.makedirs(output_dir, exist_ok=True)
    
    # Save complete dataset
    output_file = f"{output_dir}/india_all_states_aq_last30days.csv"
    df.to_csv(output_file, index=False)
    print(f"\n✅ Saved complete dataset to: {output_file}")
    
    # Save state-wise files
    print("\nSaving state-wise files...")
    for state in df['state'].unique():
        state_df = df[df['state'] == state]
        state_filename = state.lower().replace(' ', '_').replace('and', '').replace('__', '_')
        state_file = f"{output_dir}/{state_filename}_aq_last30days.csv"
        state_df.to_csv(state_file, index=False)
        print(f"   ✅ {state}: {len(state_df)} records -> {state_file}")
    
    print(f"\n🎉 All data saved to '{output_dir}' directory!")
    
else:
    print("\n❌ No data collected. This could mean:")
    print("   - No monitoring stations exist in the searched areas")
    print("   - No data available for the last 30 days")
    print("   - API rate limits or connectivity issues")
# Out:
# Total records in DataFrame: 1034106
#
# ============================================================
# Data Preview:
# ============================================================
#             state       district  location_id  \
# 0  Andhra Pradesh  Visakhapatnam         5628
# 1  Andhra Pradesh  Visakhapatnam         5628
# 2  Andhra Pradesh  Visakhapatnam         5628
# 3  Andhra Pradesh  Visakhapatnam         5628
# 4  Andhra Pradesh  Visakhapatnam         5628
# 5  Andhra Pradesh  Visakhapatnam         5628
# 6  Andhra Pradesh  Visakhapatnam         5628
# 7  Andhra Pradesh  Visakhapatnam         5628
# 8  Andhra Pradesh  Visakhapatnam         5628
# 9  Andhra Pradesh  Visakhapatnam         5628
#
#                             location_name  sensor_id parameter  \
# 0  GVM Corporation, Visakhapatnam - APPCB   12235460      pm25
# 1  GVM Corporation, Visakhapatnam - APPCB   12235460      pm25
# 2  GVM Corporation, Visakhapatnam - APPCB   12235460      pm25
# 3  GVM Corporation, Visakhapatnam - APPCB   12235460      pm25
# 4  GVM Corporation, Visakhapatnam - APPCB   12235460      pm25
# 5  GVM Corporation, Visakhapatnam - APPCB   12235460      pm25
# 6  GVM Corporation, Visakhapatnam - APPCB   12235460      pm25
# 7  GVM Corporation, Visakhapatnam - APPCB   12235460      pm25
# 8  GVM Corporation, Visakhapatnam - APPCB   12235460      pm25
# 9  GVM Corporation, Visakhapatnam - APPCB   12235460      pm25
#
#   parameter_original parameter_display  value   unit          datetime_utc  \
# 0               pm25             PM2.5  107.0  µg/m³  2025-11-24T13:00:00Z
# 1               pm25             PM2.5  107.0  µg/m³  2025-11-24T13:15:00Z
# 2               pm25             PM2.5  107.0  µg/m³  2025-11-24T13:30:00Z
# 3               pm25             PM2.5  107.0  µg/m³  2025-11-24T13:45:00Z
# 4               pm25             PM2.5  107.0  µg/m³  2025-11-24T14:00:00Z
# 5               pm25             PM2.5  107.0  µg/m³  2025-11-24T14:15:00Z
# 6               pm25             PM2.5  107.0  µg/m³  2025-11-24T14:30:00Z
# 7               pm25             PM2.5  107.0  µg/m³  2025-11-24T14:45:00Z
# 8               pm25             PM2.5   96.0  µg/m³  2025-11-24T15:00:00Z
# 9               pm25             PM2.5   96.0  µg/m³  2025-11-24T15:15:00Z
#
#               datetime_local   latitude  longitude
# 0  2025-11-24T18:30:00+05:30  17.722682  83.308197
# 1  2025-11-24T18:45:00+05:30  17.722682  83.308197
# 2  2025-11-24T19:00:00+05:30  17.722682  83.308197
# 3  2025-11-24T19:15:00+05:30  17.722682  83.308197
# 4  2025-11-24T19:30:00+05:30  17.722682  83.308197
# 5  2025-11-24T19:45:00+05:30  17.722682  83.308197
# 6  2025-11-24T20:00:00+05:30  17.722682  83.308197
# 7  2025-11-24T20:15:00+05:30  17.722682  83.308197
# 8  2025-11-24T20:30:00+05:30  17.722682  83.308197
# 9  2025-11-24T20:45:00+05:30  17.722682  83.308197
#
# ============================================================
# Summary by State:
# ============================================================
#                    districts  locations  records
# state
# Andhra Pradesh             3          3    71995
# Arunachal Pradesh          1          1    22830
# Assam                      1          1    25707
# Bihar                      2          2    43510
# Chhattisgarh               5          5    98947
# Gujarat                    4          4    78550
# Haryana                    3          3    63234
# Jharkhand                  1          1     7478
# Karnataka                  2          2    18602
# Kerala                     4          4    71585
# Madhya Pradesh             4          4    92515
# Maharashtra                3          3    63474
# Meghalaya                  2          2    41719
# Mizoram                    1          1    14292
# Nagaland                   1          1    24360
# Odisha                     3          3    69806
# Punjab                     5          5   115861
# Rajasthan                  3          3    68268
# Sikkim                     1          1    15030
# Tamil Nadu                 2          2    26343
#
# ============================================================
# Parameter Distribution:
# ============================================================
# parameter
# pm25              111015
# so2               110878
# no2               110789
# pm10              108931
# co                107658
# o3                101042
# humidity           98278
# wind_direction     97280
# temperature        94409
# wind_speed         93826
# Name: count, dtype: int64
#
# ============================================================
# Data Summary by Parameter:
# ============================================================
#                  count          mean      min           max
# parameter
# co              107658  8.776106e-01    -0.27  1.000000e+01
# humidity         98278  6.268170e+01   -29.00  1.302700e+02
# no2             110789  1.611798e+02   -60.80  1.727800e+04
# o3              101042  3.105483e+22  -708.70  2.667168e+27
# pm10            108931  2.683108e+02  -999.90  1.707400e+04
# pm25            111015  6.368070e+01 -9999.00  2.208910e+03
# so2             110878  1.491771e+01   -17.02  1.285200e+03
# temperature      94409  1.924230e+01   -55.00  8.941000e+01
# wind_direction   97280  1.671102e+02    -0.69  3.599900e+02
# wind_speed       93826  3.647240e+00    -0.45  1.354700e+02
#
# ✅ Saved complete dataset to: data/india_states/india_all_states_aq_last30days.csv
#
# Saving state-wise files...
#    ✅ Andhra Pradesh: 71995 records -> data/india_states/hra_pradesh_aq_last30days.csv
#    ✅ Arunachal Pradesh: 22830 records -> data/india_states/arunachal_pradesh_aq_last30days.csv
#    ✅ Assam: 25707 records -> data/india_states/assam_aq_last30days.csv
#    ✅ Bihar: 43510 records -> data/india_states/bihar_aq_last30days.csv
#    ✅ Chhattisgarh: 98947 records -> data/india_states/chhattisgarh_aq_last30days.csv
#    ✅ Gujarat: 78550 records -> data/india_states/gujarat_aq_last30days.csv
#    ✅ Haryana: 63234 records -> data/india_states/haryana_aq_last30days.csv
#    ✅ Jharkhand: 7478 records -> data/india_states/jharkh_aq_last30days.csv
#    ✅ Karnataka: 18602 records -> data/india_states/karnataka_aq_last30days.csv
#    ✅ Kerala: 71585 records -> data/india_states/kerala_aq_last30days.csv
#    ✅ Madhya Pradesh: 92515 records -> data/india_states/madhya_pradesh_aq_last30days.csv
#    ✅ Maharashtra: 63474 records -> data/india_states/maharashtra_aq_last30days.csv
#    ✅ Meghalaya: 41719 records -> data/india_states/meghalaya_aq_last30days.csv
#    ✅ Mizoram: 14292 records -> data/india_states/mizoram_aq_last30days.csv
#    ✅ Nagaland: 24360 records -> data/india_states/nagal_aq_last30days.csv
#    ✅ Odisha: 69806 records -> data/india_states/odisha_aq_last30days.csv
#    ✅ Punjab: 115861 records -> data/india_states/punjab_aq_last30days.csv
#    ✅ Rajasthan: 68268 records -> data/india_states/rajasthan_aq_last30days.csv
#    ✅ Sikkim: 15030 records -> data/india_states/sikkim_aq_last30days.csv
#    ✅ Tamil Nadu: 26343 records -> data/india_states/tamil_nadu_aq_last30days.csv
#
# 🎉 All data saved to 'data/india_states' directory!

# %%
# Cell 6: Generate Summary Report

if len(df) > 0:
    print("="*70)
    print("INDIA AIR QUALITY DATA COLLECTION - FINAL REPORT")
    print("="*70)
    print(f"\n📅 Data Period: {date_from.strftime('%Y-%m-%d')} to {date_to.strftime('%Y-%m-%d')}")
    print(f"📊 Total Records: {len(df):,}")
    print(f"🗺️  States/UTs with data: {df['state'].nunique()}")
    print(f"📍 Districts with data: {df['district'].nunique()}")
    print(f"🏭 Monitoring Locations: {df['location_id'].nunique()}")
    
    print("\n" + "-"*50)
    print("Parameters Collected:")
    print("-"*50)
    for param in df['parameter'].unique():
        param_data = df[df['parameter'] == param]
        print(f"  • {param.upper()}: {len(param_data):,} measurements")
    
    print("\n" + "-"*50)
    print("Top 10 States by Data Volume:")
    print("-"*50)
    top_states = df.groupby('state').size().sort_values(ascending=False).head(10)
    for i, (state, count) in enumerate(top_states.items(), 1):
        print(f"  {i:2}. {state}: {count:,} records")
    
    print("\n" + "-"*50)
    print("Output Files:")
    print("-"*50)
    print(f"  📁 Main file: data/india_states/india_all_states_aq_last30days.csv")
    print(f"  📁 State files: data/india_states/[state_name]_aq_last30days.csv")
    
    print("\n" + "="*70)
    print("✅ Data collection completed successfully!")
    print("="*70)
else:
    print("No data to generate report.")
# Out:
# ======================================================================
# INDIA AIR QUALITY DATA COLLECTION - FINAL REPORT
# ======================================================================
#
# 📅 Data Period: 2025-11-24 to 2025-12-24
# 📊 Total Records: 1,034,106
# 🗺️  States/UTs with data: 20
# 📍 Districts with data: 51
# 🏭 Monitoring Locations: 51
#
# --------------------------------------------------
# Parameters Collected:
# --------------------------------------------------
#   • PM25: 111,015 measurements
#   • O3: 101,042 measurements
#   • CO: 107,658 measurements
#   • PM10: 108,931 measurements
#   • HUMIDITY: 98,278 measurements
#   • TEMPERATURE: 94,409 measurements
#   • SO2: 110,878 measurements
#   • NO2: 110,789 measurements
#   • WIND_SPEED: 93,826 measurements
#   • WIND_DIRECTION: 97,280 measurements
#
# --------------------------------------------------
# Top 10 States by Data Volume:
# --------------------------------------------------
#    1. Punjab: 115,861 records
#    2. Chhattisgarh: 98,947 records
#    3. Madhya Pradesh: 92,515 records
#    4. Gujarat: 78,550 records
#    5. Andhra Pradesh: 71,995 records
#    6. Kerala: 71,585 records
#    7. Odisha: 69,806 records
#    8. Rajasthan: 68,268 records
#    9. Maharashtra: 63,474 records
#   10. Haryana: 63,234 records
#
# --------------------------------------------------
# Output Files:
# --------------------------------------------------
#   📁 Main file: data/india_states/india_all_states_aq_last30days.csv
#   📁 State files: data/india_states/[state_name]_aq_last30days.csv
#
# ======================================================================
# ✅ Data collection completed successfully!
# ======================================================================

# %%
# Cell 7: Load the Complete Combined Dataset (ALL RECORDS)

import pandas as pd
import os

# Path to the main combined data file
data_dir = "data/india_states"
main_file = f"{data_dir}/india_all_states_aq_last30days.csv"

print("="*70)
print("LOADING COMPLETE INDIA AIR QUALITY DATASET")
print("="*70)

# Load the main combined file which contains ALL records
if os.path.exists(main_file):
    combined_df = pd.read_csv(main_file)
    print(f"\n✅ Loaded: {main_file}")
    print(f"\n📊 Dataset Statistics:")
    print(f"   Total records: {len(combined_df):,}")
    print(f"   States/UTs: {combined_df['state'].nunique()}")
    print(f"   Districts: {combined_df['district'].nunique()}")
    print(f"   Unique Locations: {combined_df['location_id'].nunique()}")
    print(f"   Parameters: {combined_df['parameter'].unique().tolist()}")
    
    print("\n" + "-"*50)
    print("Records per State:")
    print("-"*50)
    state_counts = combined_df.groupby('state').size().sort_values(ascending=False)
    for state, count in state_counts.items():
        print(f"   {state}: {count:,} records")
    
    print(f"\n   TOTAL: {state_counts.sum():,} records")
    
    print("\n" + "-"*50)
    print("Sample Data (before transformation):")
    print("-"*50)
    print(combined_df.head())
else:
    print(f"❌ File not found: {main_file}")
    combined_df = pd.DataFrame()
# Out:
# ======================================================================
# LOADING COMPLETE INDIA AIR QUALITY DATASET
# ======================================================================
#
# ✅ Loaded: data/india_states/india_all_states_aq_last30days.csv
#
# 📊 Dataset Statistics:
#    Total records: 1,034,106
#    States/UTs: 20
#    Districts: 51
#    Unique Locations: 51
#    Parameters: ['pm25', 'o3', 'co', 'pm10', 'humidity', 'temperature', 'so2', 'no2', 'wind_speed', 'wind_direction']
#
# --------------------------------------------------
# Records per State:
# --------------------------------------------------
#    Punjab: 115,861 records
#    Chhattisgarh: 98,947 records
#    Madhya Pradesh: 92,515 records
#    Gujarat: 78,550 records
#    Andhra Pradesh: 71,995 records
#    Kerala: 71,585 records
#    Odisha: 69,806 records
#    Rajasthan: 68,268 records
#    Maharashtra: 63,474 records
#    Haryana: 63,234 records
#    Bihar: 43,510 records
#    Meghalaya: 41,719 records
#    Tamil Nadu: 26,343 records
#    Assam: 25,707 records
#    Nagaland: 24,360 records
#    Arunachal Pradesh: 22,830 records
#    Karnataka: 18,602 records
#    Sikkim: 15,030 records
#    Mizoram: 14,292 records
#    Jharkhand: 7,478 records
#
#    TOTAL: 1,034,106 records
#
# --------------------------------------------------
# Sample Data (before transformation):
# --------------------------------------------------
#             state       district  location_id  \
# 0  Andhra Pradesh  Visakhapatnam         5628
# 1  Andhra Pradesh  Visakhapatnam         5628
# 2  Andhra Pradesh  Visakhapatnam         5628
# 3  Andhra Pradesh  Visakhapatnam         5628
# 4  Andhra Pradesh  Visakhapatnam         5628
#
#                             location_name  sensor_id parameter  \
# 0  GVM Corporation, Visakhapatnam - APPCB   12235460      pm25
# 1  GVM Corporation, Visakhapatnam - APPCB   12235460      pm25
# 2  GVM Corporation, Visakhapatnam - APPCB   12235460      pm25
# 3  GVM Corporation, Visakhapatnam - APPCB   12235460      pm25
# 4  GVM Corporation, Visakhapatnam - APPCB   12235460      pm25
#
#   parameter_original parameter_display  value   unit          datetime_utc  \
# 0               pm25             PM2.5  107.0  µg/m³  2025-11-24T13:00:00Z
# 1               pm25             PM2.5  107.0  µg/m³  2025-11-24T13:15:00Z
# 2               pm25             PM2.5  107.0  µg/m³  2025-11-24T13:30:00Z
# 3               pm25             PM2.5  107.0  µg/m³  2025-11-24T13:45:00Z
# 4               pm25             PM2.5  107.0  µg/m³  2025-11-24T14:00:00Z
#
#               datetime_local   latitude  longitude
# 0  2025-11-24T18:30:00+05:30  17.722682  83.308197
# 1  2025-11-24T18:45:00+05:30  17.722682  83.308197
# 2  2025-11-24T19:00:00+05:30  17.722682  83.308197
# 3  2025-11-24T19:15:00+05:30  17.722682  83.308197
# 4  2025-11-24T19:30:00+05:30  17.722682  83.308197

# %%
# Cell 8: Transform Data - Pivot Parameters into Feature Columns (ALL RECORDS)

if len(combined_df) > 0:
    print("="*70)
    print("TRANSFORMING DATA: PIVOTING PARAMETERS INTO FEATURE COLUMNS")
    print("="*70)
    print(f"\nInput records: {len(combined_df):,}")
    
    # Define the index columns (grouping columns)
    index_cols = [
        'state', 
        'district', 
        'location_id', 
        'location_name', 
        'datetime_utc', 
        'datetime_local', 
        'latitude', 
        'longitude'
    ]
    
    # Check which columns exist in the data
    available_cols = [col for col in index_cols if col in combined_df.columns]
    print(f"Available index columns: {available_cols}")
    
    # Pivot the dataframe: parameters become columns, values become the data
    # Using 'first' instead of 'mean' to preserve all unique combinations
    transformed_df = combined_df.pivot_table(
        index=available_cols,
        columns='parameter',
        values='value',
        aggfunc='first'  # Take first value if duplicates exist
    ).reset_index()
    
    # Flatten column names (remove multi-index)
    transformed_df.columns.name = None
    
    # Get the parameter columns that were created
    param_columns = [col for col in transformed_df.columns if col not in available_cols]
    
    print(f"\n✅ Transformation complete!")
    print(f"\n📊 Transformation Results:")
    print(f"   Original records: {len(combined_df):,}")
    print(f"   Transformed rows: {len(transformed_df):,}")
    print(f"   Total columns: {len(transformed_df.columns)}")
    print(f"\n📋 Index columns: {available_cols}")
    print(f"📋 Parameter feature columns: {param_columns}")
    
    # Verify no data loss
    print("\n" + "-"*50)
    print("Data Preservation Check:")
    print("-"*50)
    for param in param_columns:
        original_count = combined_df[combined_df['parameter'] == param]['value'].notna().sum()
        transformed_count = transformed_df[param].notna().sum()
        print(f"   {param}: Original={original_count:,}, Transformed={transformed_count:,}")
    
    print("\n" + "-"*50)
    print("Transformed Data Preview:")
    print("-"*50)
    print(transformed_df.head(10))
else:
    print("❌ No data to transform!")
# Out:
# ======================================================================
# TRANSFORMING DATA: PIVOTING PARAMETERS INTO FEATURE COLUMNS
# ======================================================================
#
# Input records: 1,034,106
# Available index columns: ['state', 'district', 'location_id', 'location_name', 'datetime_utc', 'datetime_local', 'latitude', 'longitude']
#
# ✅ Transformation complete!
#
# 📊 Transformation Results:
#    Original records: 1,034,106
#    Transformed rows: 113,878
#    Total columns: 18
#
# 📋 Index columns: ['state', 'district', 'location_id', 'location_name', 'datetime_utc', 'datetime_local', 'latitude', 'longitude']
# 📋 Parameter feature columns: ['co', 'humidity', 'no2', 'o3', 'pm10', 'pm25', 'so2', 'temperature', 'wind_direction', 'wind_speed']
#
# --------------------------------------------------
# Data Preservation Check:
# --------------------------------------------------
#    co: Original=107,658, Transformed=107,658
#    humidity: Original=98,278, Transformed=98,278
#    no2: Original=110,789, Transformed=110,789
#    o3: Original=101,042, Transformed=101,042
#    pm10: Original=108,931, Transformed=108,931
#    pm25: Original=111,015, Transformed=111,015
#    so2: Original=110,878, Transformed=110,878
#    temperature: Original=94,409, Transformed=94,409
#    wind_direction: Original=97,280, Transformed=97,280
#    wind_speed: Original=93,826, Transformed=93,826
#
# --------------------------------------------------
# Transformed Data Preview:
# --------------------------------------------------
#             state  district  location_id               location_name  \
# 0  Andhra Pradesh  Tirupati         5649  Tirumala, Tirupati - APPCB
# 1  Andhra Pradesh  Tirupati         5649  Tirumala, Tirupati - APPCB
# 2  Andhra Pradesh  Tirupati         5649  Tirumala, Tirupati - APPCB
# 3  Andhra Pradesh  Tirupati         5649  Tirumala, Tirupati - APPCB
# 4  Andhra Pradesh  Tirupati         5649  Tirumala, Tirupati - APPCB
# 5  Andhra Pradesh  Tirupati         5649  Tirumala, Tirupati - APPCB
# 6  Andhra Pradesh  Tirupati         5649  Tirumala, Tirupati - APPCB
# 7  Andhra Pradesh  Tirupati         5649  Tirumala, Tirupati - APPCB
# 8  Andhra Pradesh  Tirupati         5649  Tirumala, Tirupati - APPCB
# 9  Andhra Pradesh  Tirupati         5649  Tirumala, Tirupati - APPCB
#
#            datetime_utc             datetime_local  latitude  longitude    co  \
# 0  2025-11-24T13:00:00Z  2025-11-24T18:30:00+05:30     13.67      79.35  0.56
# 1  2025-11-24T13:15:00Z  2025-11-24T18:45:00+05:30     13.67      79.35  0.54
# 2  2025-11-24T13:30:00Z  2025-11-24T19:00:00+05:30     13.67      79.35  0.58
# 3  2025-11-24T13:45:00Z  2025-11-24T19:15:00+05:30     13.67      79.35  0.57
# 4  2025-11-24T14:00:00Z  2025-11-24T19:30:00+05:30     13.67      79.35  0.54
# 5  2025-11-24T14:15:00Z  2025-11-24T19:45:00+05:30     13.67      79.35  0.55
# 6  2025-11-24T14:30:00Z  2025-11-24T20:00:00+05:30     13.67      79.35  0.54
# 7  2025-11-24T14:45:00Z  2025-11-24T20:15:00+05:30     13.67      79.35  0.55
# 8  2025-11-24T15:00:00Z  2025-11-24T20:30:00+05:30     13.67      79.35  0.52
# 9  2025-11-24T15:15:00Z  2025-11-24T20:45:00+05:30     13.67      79.35  0.54
#
#    humidity   no2   o3  pm10  pm25  so2  temperature  wind_direction  \
# 0      89.0  10.2  6.4  57.0  53.0  5.2         21.3           352.0
# 1      89.0  10.7  6.5  57.0  53.0  5.1         21.3           353.0
# 2      89.0  10.2  9.6  57.0  53.0  5.3         21.4           353.0
# 3      89.0  10.8  8.4  57.0  53.0  5.3         21.4           354.0
# 4      89.0  10.1  0.0  54.0  45.0  5.2         21.3           350.0
# 5      89.0  10.4  0.0  54.0  45.0  5.2         21.3           349.0
# 6      89.0  11.7  8.1  54.0  45.0  5.2         21.3           343.0
# 7      89.0  11.8  4.9  54.0  45.0  5.2         21.2           354.0
# 8      89.0  10.1  6.7  52.0  53.0  5.1         21.2           355.0
# 9      89.0  10.0  6.1  52.0  53.0  5.1         21.2           349.0
#
#    wind_speed
# 0         1.1
# 1         1.3
# 2         1.0
# 3         1.0
# 4         0.9
# 5         1.1
# 6         0.9
# 7         1.2
# 8         1.0
# 9         1.0

# %%
# Cell 9: Data Quality Check and Statistics

if 'transformed_df' in dir() and len(transformed_df) > 0:
    print("="*70)
    print("DATA QUALITY REPORT")
    print("="*70)
    
    # Missing values analysis
    print("\n📊 Missing Values per Parameter Column:")
    print("-"*50)
    param_columns = ['pm25', 'pm10', 'no2', 'co', 'so2', 'o3', 'temperature', 'humidity', 'wind_speed', 'wind_direction']
    existing_params = [col for col in param_columns if col in transformed_df.columns]
    
    for col in existing_params:
        missing = transformed_df[col].isna().sum()
        total = len(transformed_df)
        pct = (missing / total) * 100
        present = total - missing
        print(f"  {col:20s}: {present:,} values ({100-pct:.1f}% coverage), {missing:,} missing ({pct:.1f}%)")
    
    # Statistics for each parameter
    print("\n" + "="*70)
    print("PARAMETER STATISTICS:")
    print("="*70)
    
    stats_data = []
    for col in existing_params:
        if col in transformed_df.columns:
            stats_data.append({
                'Parameter': col,
                'Count': transformed_df[col].notna().sum(),
                'Mean': transformed_df[col].mean(),
                'Std': transformed_df[col].std(),
                'Min': transformed_df[col].min(),
                'Max': transformed_df[col].max()
            })
    
    stats_df = pd.DataFrame(stats_data)
    print(stats_df.to_string(index=False))
    
    # Coverage by state
    print("\n" + "="*70)
    print("DATA COVERAGE BY STATE:")
    print("="*70)
    state_coverage = transformed_df.groupby('state').agg({
        'district': 'nunique',
        'location_id': 'nunique',
        'datetime_utc': 'count'
    }).rename(columns={
        'district': 'districts',
        'location_id': 'locations',
        'datetime_utc': 'records'
    }).sort_values('records', ascending=False)
    
    print(state_coverage.head(15))
else:
    print("No transformed data available!")
# Out:
# ======================================================================
# DATA QUALITY REPORT
# ======================================================================
#
# 📊 Missing Values per Parameter Column:
# --------------------------------------------------
#   pm25                : 111,015 values (97.5% coverage), 2,863 missing (2.5%)
#   pm10                : 108,931 values (95.7% coverage), 4,947 missing (4.3%)
#   no2                 : 110,789 values (97.3% coverage), 3,089 missing (2.7%)
#   co                  : 107,658 values (94.5% coverage), 6,220 missing (5.5%)
#   so2                 : 110,878 values (97.4% coverage), 3,000 missing (2.6%)
#   o3                  : 101,042 values (88.7% coverage), 12,836 missing (11.3%)
#   temperature         : 94,409 values (82.9% coverage), 19,469 missing (17.1%)
#   humidity            : 98,278 values (86.3% coverage), 15,600 missing (13.7%)
#   wind_speed          : 93,826 values (82.4% coverage), 20,052 missing (17.6%)
#   wind_direction      : 97,280 values (85.4% coverage), 16,598 missing (14.6%)
#
# ======================================================================
# PARAMETER STATISTICS:
# ======================================================================
#      Parameter  Count         Mean          Std      Min          Max
#           pm25 111015 6.368070e+01 1.375911e+02 -9999.00 2.208910e+03
#           pm10 108931 2.683108e+02 1.538655e+03  -999.90 1.707400e+04
#            no2 110789 1.611798e+02 1.536863e+03   -60.80 1.727800e+04
#             co 107658 8.776106e-01 7.912797e-01    -0.27 1.000000e+01
#            so2 110878 1.491771e+01 2.167755e+01   -17.02 1.285200e+03
#             o3 101042 3.105483e+22 8.520357e+24  -708.70 2.667168e+27
#    temperature  94409 1.924230e+01 8.759236e+00   -55.00 8.941000e+01
#       humidity  98278 6.268170e+01 2.556105e+01   -29.00 1.302700e+02
#     wind_speed  93826 3.647240e+00 1.649133e+01    -0.45 1.354700e+02
# wind_direction  97280 1.671102e+02 1.002559e+02    -0.69 3.599900e+02
#
# ======================================================================
# DATA COVERAGE BY STATE:
# ======================================================================
#                 districts  locations  records
# state
# Punjab                  5          5    12109
# Chhattisgarh            5          5    11162
# Madhya Pradesh          4          4     9677
# Gujarat                 4          4     9093
# Kerala                  4          4     7422
# Andhra Pradesh          3          3     7295
# Rajasthan               3          3     7249
# Odisha                  3          3     7112
# Haryana                 3          3     7003
# Maharashtra             3          3     6357
# Meghalaya               2          2     4739
# Bihar                   2          2     4723
# Tamil Nadu              2          2     4359
# Karnataka               2          2     3457
# Assam                   1          1     2580

# %%
# Cell 10: Save Final Transformed Dataset (COMPLETE)

if 'transformed_df' in dir() and len(transformed_df) > 0:
    # Create output directory for processed data
    processed_dir = "data/processed"
    os.makedirs(processed_dir, exist_ok=True)
    
    # Define column order for the final output
    index_cols = ['state', 'district', 'location_id', 'location_name', 
                  'datetime_utc', 'datetime_local', 'latitude', 'longitude']
    
    # Parameter columns in desired order
    param_order = ['pm25', 'pm10', 'no2', 'co', 'so2', 'o3', 
                   'temperature', 'humidity', 'wind_speed', 'wind_direction']
    
    # Get existing parameter columns in order
    existing_params = [col for col in param_order if col in transformed_df.columns]
    
    # Get available index columns
    available_index = [col for col in index_cols if col in transformed_df.columns]
    
    # Final column order
    final_columns = available_index + existing_params
    
    # Reorder columns
    final_df = transformed_df[[col for col in final_columns if col in transformed_df.columns]].copy()
    
    # Sort by state, district, location, and datetime
    sort_cols = [col for col in ['state', 'district', 'location_name', 'datetime_utc'] if col in final_df.columns]
    final_df = final_df.sort_values(sort_cols)
    
    # Save the COMPLETE transformed dataset
    output_file = f"{processed_dir}/india_aq_transformed_last30days.csv"
    final_df.to_csv(output_file, index=False)
    
    print("="*70)
    print("FINAL TRANSFORMED DATASET SAVED SUCCESSFULLY!")
    print("="*70)
    print(f"\n📁 Output file: {output_file}")
    print(f"📊 Total rows: {len(final_df):,}")
    print(f"📋 Total columns: {len(final_df.columns)}")
    
    print("\n" + "-"*50)
    print("Final Column Structure:")
    print("-"*50)
    for i, col in enumerate(final_df.columns, 1):
        dtype = final_df[col].dtype
        non_null = final_df[col].notna().sum()
        print(f"  {i:2}. {col:20s} ({dtype}) - {non_null:,} values")
    
    print("\n" + "-"*50)
    print("Records per State in Final Dataset:")
    print("-"*50)
    state_counts = final_df.groupby('state').size().sort_values(ascending=False)
    total = 0
    for state, count in state_counts.items():
        print(f"   {state}: {count:,} rows")
        total += count
    print(f"\n   TOTAL ROWS: {total:,}")
    
    print("\n" + "-"*50)
    print("Final Data Preview:")
    print("-"*50)
    print(final_df.head(10))
    
    # Also save state-wise transformed files
    print("\n" + "-"*50)
    print("Saving state-wise transformed files...")
    print("-"*50)
    
    for state in final_df['state'].unique():
        state_df = final_df[final_df['state'] == state]
        state_filename = state.lower().replace(' ', '_').replace('and', '').replace('__', '_').strip('_')
        state_file = f"{processed_dir}/{state_filename}_aq_transformed.csv"
        state_df.to_csv(state_file, index=False)
        print(f"  ✅ {state}: {len(state_df):,} rows -> {state_file}")
    
    print(f"\n🎉 All transformed data saved to '{processed_dir}' directory!")
    print(f"🎉 TOTAL RECORDS PRESERVED: {len(final_df):,}")
else:
    print("❌ No transformed data to save!")
# Out:
# ======================================================================
# FINAL TRANSFORMED DATASET SAVED SUCCESSFULLY!
# ======================================================================
#
# 📁 Output file: data/processed/india_aq_transformed_last30days.csv
# 📊 Total rows: 113,878
# 📋 Total columns: 18
#
# --------------------------------------------------
# Final Column Structure:
# --------------------------------------------------
#    1. state                (object) - 113,878 values
#    2. district             (object) - 113,878 values
#    3. location_id          (int64) - 113,878 values
#    4. location_name        (object) - 113,878 values
#    5. datetime_utc         (object) - 113,878 values
#    6. datetime_local       (object) - 113,878 values
#    7. latitude             (float64) - 113,878 values
#    8. longitude            (float64) - 113,878 values
#    9. pm25                 (float64) - 111,015 values
#   10. pm10                 (float64) - 108,931 values
#   11. no2                  (float64) - 110,789 values
#   12. co                   (float64) - 107,658 values
#   13. so2                  (float64) - 110,878 values
#   14. o3                   (float64) - 101,042 values
#   15. temperature          (float64) - 94,409 values
#   16. humidity             (float64) - 98,278 values
#   17. wind_speed           (float64) - 93,826 values
#   18. wind_direction       (float64) - 97,280 values
#
# --------------------------------------------------
# Records per State in Final Dataset:
# --------------------------------------------------
#    Punjab: 12,109 rows
#    Chhattisgarh: 11,162 rows
#    Madhya Pradesh: 9,677 rows
#    Gujarat: 9,093 rows
#    Kerala: 7,422 rows
#    Andhra Pradesh: 7,295 rows
#    Rajasthan: 7,249 rows
#    Odisha: 7,112 rows
#    Haryana: 7,003 rows
#    Maharashtra: 6,357 rows
#    Meghalaya: 4,739 rows
#    Bihar: 4,723 rows
#    Tamil Nadu: 4,359 rows
#    Karnataka: 3,457 rows
#    Assam: 2,580 rows
#    Nagaland: 2,436 rows
#    Mizoram: 2,382 rows
#    Arunachal Pradesh: 2,283 rows
#    Sikkim: 1,503 rows
#    Jharkhand: 937 rows
#
#    TOTAL ROWS: 113,878
#
# --------------------------------------------------
# Final Data Preview:
# --------------------------------------------------
#             state  district  location_id               location_name  \
# 0  Andhra Pradesh  Tirupati         5649  Tirumala, Tirupati - APPCB
# 1  Andhra Pradesh  Tirupati         5649  Tirumala, Tirupati - APPCB
# 2  Andhra Pradesh  Tirupati         5649  Tirumala, Tirupati - APPCB
# 3  Andhra Pradesh  Tirupati         5649  Tirumala, Tirupati - APPCB
# 4  Andhra Pradesh  Tirupati         5649  Tirumala, Tirupati - APPCB
# 5  Andhra Pradesh  Tirupati         5649  Tirumala, Tirupati - APPCB
# 6  Andhra Pradesh  Tirupati         5649  Tirumala, Tirupati - APPCB
# 7  Andhra Pradesh  Tirupati         5649  Tirumala, Tirupati - APPCB
# 8  Andhra Pradesh  Tirupati         5649  Tirumala, Tirupati - APPCB
# 9  Andhra Pradesh  Tirupati         5649  Tirumala, Tirupati - APPCB
#
#            datetime_utc             datetime_local  latitude  longitude  pm25  \
# 0  2025-11-24T13:00:00Z  2025-11-24T18:30:00+05:30     13.67      79.35  53.0
# 1  2025-11-24T13:15:00Z  2025-11-24T18:45:00+05:30     13.67      79.35  53.0
# 2  2025-11-24T13:30:00Z  2025-11-24T19:00:00+05:30     13.67      79.35  53.0
# 3  2025-11-24T13:45:00Z  2025-11-24T19:15:00+05:30     13.67      79.35  53.0
# 4  2025-11-24T14:00:00Z  2025-11-24T19:30:00+05:30     13.67      79.35  45.0
# 5  2025-11-24T14:15:00Z  2025-11-24T19:45:00+05:30     13.67      79.35  45.0
# 6  2025-11-24T14:30:00Z  2025-11-24T20:00:00+05:30     13.67      79.35  45.0
# 7  2025-11-24T14:45:00Z  2025-11-24T20:15:00+05:30     13.67      79.35  45.0
# 8  2025-11-24T15:00:00Z  2025-11-24T20:30:00+05:30     13.67      79.35  53.0
# 9  2025-11-24T15:15:00Z  2025-11-24T20:45:00+05:30     13.67      79.35  53.0
#
#    pm10   no2    co  so2   o3  temperature  humidity  wind_speed  \
# 0  57.0  10.2  0.56  5.2  6.4         21.3      89.0         1.1
# 1  57.0  10.7  0.54  5.1  6.5         21.3      89.0         1.3
# 2  57.0  10.2  0.58  5.3  9.6         21.4      89.0         1.0
# 3  57.0  10.8  0.57  5.3  8.4         21.4      89.0         1.0
# 4  54.0  10.1  0.54  5.2  0.0         21.3      89.0         0.9
# 5  54.0  10.4  0.55  5.2  0.0         21.3      89.0         1.1
# 6  54.0  11.7  0.54  5.2  8.1         21.3      89.0         0.9
# 7  54.0  11.8  0.55  5.2  4.9         21.2      89.0         1.2
# 8  52.0  10.1  0.52  5.1  6.7         21.2      89.0         1.0
# 9  52.0  10.0  0.54  5.1  6.1         21.2      89.0         1.0
#
#    wind_direction
# 0           352.0
# 1           353.0
# 2           353.0
# 3           354.0
# 4           350.0
# 5           349.0
# 6           343.0
# 7           354.0
# 8           355.0
# 9           349.0
#
# --------------------------------------------------
# Saving state-wise transformed files...
# --------------------------------------------------
#   ✅ Andhra Pradesh: 7,295 rows -> data/processed/hra_pradesh_aq_transformed.csv
#   ✅ Arunachal Pradesh: 2,283 rows -> data/processed/arunachal_pradesh_aq_transformed.csv
#   ✅ Assam: 2,580 rows -> data/processed/assam_aq_transformed.csv
#   ✅ Bihar: 4,723 rows -> data/processed/bihar_aq_transformed.csv
#   ✅ Chhattisgarh: 11,162 rows -> data/processed/chhattisgarh_aq_transformed.csv
#   ✅ Gujarat: 9,093 rows -> data/processed/gujarat_aq_transformed.csv
#   ✅ Haryana: 7,003 rows -> data/processed/haryana_aq_transformed.csv
#   ✅ Jharkhand: 937 rows -> data/processed/jharkh_aq_transformed.csv
#   ✅ Karnataka: 3,457 rows -> data/processed/karnataka_aq_transformed.csv
#   ✅ Kerala: 7,422 rows -> data/processed/kerala_aq_transformed.csv
#   ✅ Madhya Pradesh: 9,677 rows -> data/processed/madhya_pradesh_aq_transformed.csv
#   ✅ Maharashtra: 6,357 rows -> data/processed/maharashtra_aq_transformed.csv
#   ✅ Meghalaya: 4,739 rows -> data/processed/meghalaya_aq_transformed.csv
#   ✅ Mizoram: 2,382 rows -> data/processed/mizoram_aq_transformed.csv
#   ✅ Nagaland: 2,436 rows -> data/processed/nagal_aq_transformed.csv
#   ✅ Odisha: 7,112 rows -> data/processed/odisha_aq_transformed.csv
#   ✅ Punjab: 12,109 rows -> data/processed/punjab_aq_transformed.csv
#   ✅ Rajasthan: 7,249 rows -> data/processed/rajasthan_aq_transformed.csv
#   ✅ Sikkim: 1,503 rows -> data/processed/sikkim_aq_transformed.csv
#   ✅ Tamil Nadu: 4,359 rows -> data/processed/tamil_nadu_aq_transformed.csv
#
# 🎉 All transformed data saved to 'data/processed' directory!
# 🎉 TOTAL RECORDS PRESERVED: 113,878
