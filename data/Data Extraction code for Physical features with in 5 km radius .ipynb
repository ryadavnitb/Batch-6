# %%
# OpenStreetMap Feature Extraction for Air Quality Analysis
# This script extracts nearby physical features (roads, industrial zones, dumps, agricultural fields)
# from OpenStreetMap using OSMnx library in small batches with error handling

import pandas as pd
import numpy as np
import osmnx as ox
import geopandas as gpd
from shapely.geometry import Point, box
import warnings
import time
from typing import Dict, List, Tuple
import sys

warnings.filterwarnings('ignore')

# ============================================================================
# CONFIGURATION
# ============================================================================

BATCH_SIZE = 5
SEARCH_RADIUS = 5000  # meters = 5KM
OUTPUT_FILE = "Air_Quality_with_OSM_Features_5KM.xlsx"
INPUT_FILE = "Air Quality Dataset 2021-2023.xlsx"

# ============================================================================
# FEATURE EXTRACTION FUNCTIONS
# ============================================================================

def extract_roads(lat: float, lon: float, radius: int) -> Dict:
    """Extract road features from OSM"""
    try:
        roads = ox.features_from_point(
            (lat, lon),
            tags={'highway': True},
            dist=radius
        )
        
        if len(roads) > 0:
            road_names = [roads.index.get_level_values(0).unique()[i] 
                         for i in range(min(5, len(roads.index.get_level_values(0).unique())))]
            return {
                'count': len(roads),
                'examples': ', '.join(str(r)[:40] for r in road_names),
                'status': 'success'
            }
        return {'count': 0, 'examples': '', 'status': 'success'}
    except Exception as e:
        return {'count': 0, 'examples': f"Error: {str(e)[:30]}", 'status': 'failed'}

def extract_industrial_zones(lat: float, lon: float, radius: int) -> Dict:
    """Extract industrial facilities from OSM"""
    try:
        tags = {'industrial': True, 'landuse': 'industrial'}
        industrial = ox.features_from_point((lat, lon), tags=tags, dist=radius)
        
        if len(industrial) > 0:
            ind_names = industrial.index.get_level_values(0).unique()[:5]
            return {
                'count': len(industrial),
                'examples': ', '.join(str(i)[:35] for i in ind_names),
                'status': 'success'
            }
        return {'count': 0, 'examples': '', 'status': 'success'}
    except Exception as e:
        return {'count': 0, 'examples': f"Error: {str(e)[:30]}", 'status': 'failed'}

def extract_dump_sites(lat: float, lon: float, radius: int) -> Dict:
    """Extract waste management and dump sites from OSM"""
    try:
        tags = {'waste': True}
        dumps = ox.features_from_point((lat, lon), tags=tags, dist=radius)
        
        if len(dumps) > 0:
            dump_names = dumps.index.get_level_values(0).unique()[:5]
            return {
                'count': len(dumps),
                'examples': ', '.join(str(d)[:35] for d in dump_names),
                'status': 'success'
            }
        return {'count': 0, 'examples': '', 'status': 'success'}
    except Exception as e:
        return {'count': 0, 'examples': f"Error: {str(e)[:30]}", 'status': 'failed'}

def extract_agricultural_fields(lat: float, lon: float, radius: int) -> Dict:
    """Extract agricultural areas from OSM"""
    try:
        tags = {'landuse': ['farmland', 'farm', 'agricultural', 'grass', 'meadow']}
        agriculture = ox.features_from_point((lat, lon), tags=tags, dist=radius)
        
        if len(agriculture) > 0:
            agr_names = agriculture.index.get_level_values(0).unique()[:5]
            return {
                'count': len(agriculture),
                'examples': ', '.join(str(a)[:35] for a in agr_names),
                'status': 'success'
            }
        return {'count': 0, 'examples': '', 'status': 'success'}
    except Exception as e:
        return {'count': 0, 'examples': f"Error: {str(e)[:30]}", 'status': 'failed'}

def extract_all_features(lat: float, lon: float, radius: int) -> Dict:
    """Extract all features for a location"""
    features = {
        'roads': extract_roads(lat, lon, radius),
        'industrial': extract_industrial_zones(lat, lon, radius),
        'dumps': extract_dump_sites(lat, lon, radius),
        'agriculture': extract_agricultural_fields(lat, lon, radius)
    }
    return features

# ============================================================================
# MAIN PROCESSING
# ============================================================================

def main():
    print(f"\n{'='*80}")
    print("OSM FEATURE EXTRACTION FOR AIR QUALITY ANALYSIS")
    print(f"{'='*80}\n")
    
    # Load dataset
    print(f"Loading dataset from {INPUT_FILE}...")
    df = pd.read_excel(INPUT_FILE, sheet_name=0)
    print(f"✓ Loaded {len(df)} records\n")
    
    # Get unique locations
    unique_locations = df[['Latitude', 'Longitude', 'Location', 'State / Union Territory',
                           'City / town / village']].drop_duplicates(
                           subset=['Latitude', 'Longitude']).reset_index(drop=True)
    
    print(f"Unique locations to process: {len(unique_locations)}")
    print(f"Processing parameters:")
    print(f"  - Batch size: {BATCH_SIZE}")
    print(f"  - Search radius: {SEARCH_RADIUS}m")
    print(f"\n{'='*80}\n")
    
    # Initialize results
    features_data = []
    total_batches = (len(unique_locations) - 1) // BATCH_SIZE + 1
    
    # Process in batches
    for batch_num in range(0, len(unique_locations), BATCH_SIZE):
        batch = unique_locations.iloc[batch_num:batch_num + BATCH_SIZE]
        batch_idx = (batch_num // BATCH_SIZE) + 1
        
        print(f"Batch {batch_idx}/{total_batches}:")
        print(f"Processing locations {batch_num + 1} to {min(batch_num + BATCH_SIZE, len(unique_locations))}\n")
        
        for idx, row in batch.iterrows():
            lat = row['Latitude']
            lon = row['Longitude']
            location_name = row['Location']
            city = row['City / town / village']
            state = row['State / Union Territory']
            
            try:
                # Extract features
                print(f"  Querying {city}, {state} ({lat:.4f}, {lon:.4f})...", end='', flush=True)
                features = extract_all_features(lat, lon, SEARCH_RADIUS)
                
                # Compile record
                record = {
                    'Location': location_name,
                    'City': city,
                    'State': state,
                    'Latitude': lat,
                    'Longitude': lon,
                    'Roads_count': features['roads']['count'],
                    'Roads_examples': features['roads']['examples'],
                    'Industrial_zones_count': features['industrial']['count'],
                    'Industrial_examples': features['industrial']['examples'],
                    'Dump_sites_count': features['dumps']['count'],
                    'Dump_examples': features['dumps']['examples'],
                    'Agricultural_fields_count': features['agriculture']['count'],
                    'Agricultural_examples': features['agriculture']['examples'],
                    'Query_status': 'Success'
                }
                
                features_data.append(record)
                
                print(f" ✓ Roads:{features['roads']['count']} | "
                      f"Industrial:{features['industrial']['count']} | "
                      f"Dumps:{features['dumps']['count']} | "
                      f"Agriculture:{features['agriculture']['count']}")
                
            except Exception as e:
                print(f" ✗ Error: {str(e)[:50]}")
                record = {
                    'Location': location_name,
                    'City': city,
                    'State': state,
                    'Latitude': lat,
                    'Longitude': lon,
                    'Roads_count': 0,
                    'Roads_examples': '',
                    'Industrial_zones_count': 0,
                    'Industrial_examples': '',
                    'Dump_sites_count': 0,
                    'Dump_examples': '',
                    'Agricultural_fields_count': 0,
                    'Agricultural_examples': '',
                    'Query_status': f'Failed: {str(e)[:40]}'
                }
                features_data.append(record)
            
            # Small delay between queries to avoid rate limiting
            time.sleep(0.5)
        
        print(f"\nBatch completed. Waiting before next batch...\n")
        time.sleep(2)
    
    # Create features dataframe
    features_df = pd.DataFrame(features_data)
    
    # Print summary statistics
    print(f"\n{'='*80}")
    print("EXTRACTION SUMMARY")
    print(f"{'='*80}\n")
    
    print(f"Total locations processed: {len(features_df)}")
    successful = (features_df['Query_status'] == 'Success').sum()
    print(f"Successful queries: {successful}/{len(features_df)}")
    
    print(f"\n{'Feature Statistics':^80}")
    print(f"{'-'*80}")
    print(f"{'Feature':<20} {'Total':<12} {'Mean':<12} {'Max':<12}")
    print(f"{'-'*80}")
    print(f"{'Roads':<20} {features_df['Roads_count'].sum():<12.0f} "
          f"{features_df['Roads_count'].mean():<12.1f} {features_df['Roads_count'].max():<12.0f}")
    print(f"{'Industrial':<20} {features_df['Industrial_zones_count'].sum():<12.0f} "
          f"{features_df['Industrial_zones_count'].mean():<12.1f} "
          f"{features_df['Industrial_zones_count'].max():<12.0f}")
    print(f"{'Dump Sites':<20} {features_df['Dump_sites_count'].sum():<12.0f} "
          f"{features_df['Dump_sites_count'].mean():<12.1f} {features_df['Dump_sites_count'].max():<12.0f}")
    print(f"{'Agriculture':<20} {features_df['Agricultural_fields_count'].sum():<12.0f} "
          f"{features_df['Agricultural_fields_count'].mean():<12.1f} "
          f"{features_df['Agricultural_fields_count'].max():<12.0f}")
    print(f"{'-'*80}\n")
    
    # Merge with original data
    print("Merging extracted features with original air quality data...")
    
    # Merge on latitude and longitude
    merged_df = df.merge(
        features_df[['Latitude', 'Longitude', 'Roads_count', 'Industrial_zones_count',
                     'Dump_sites_count', 'Agricultural_fields_count', 'Query_status']],
        on=['Latitude', 'Longitude'],
        how='left'
    )
    
    # Fill NaN values for unmatched records (should be minimal)
    merged_df['Roads_count'].fillna(0, inplace=True)
    merged_df['Industrial_zones_count'].fillna(0, inplace=True)
    merged_df['Dump_sites_count'].fillna(0, inplace=True)
    merged_df['Agricultural_fields_count'].fillna(0, inplace=True)
    merged_df['Query_status'].fillna('Not processed', inplace=True)
    
    # Create additional derived features
    merged_df['Urban_density_score'] = (merged_df['Roads_count'] / merged_df['Roads_count'].max()).round(2)
    merged_df['Industrial_presence'] = (merged_df['Industrial_zones_count'] > 0).astype(int)
    merged_df['Pollution_source_risk'] = (
        (merged_df['Industrial_zones_count'] * 0.4 + 
         merged_df['Dump_sites_count'] * 0.3 + 
         merged_df['Roads_count'] * 0.3) / 100
    ).round(2)
    merged_df['Green_area_ratio'] = (
        merged_df['Agricultural_fields_count'] / 
        (merged_df['Roads_count'] + merged_df['Agricultural_fields_count'])
    ).round(2)
    
    # Save to Excel
    print(f"\nSaving merged data to {OUTPUT_FILE}...")
    with pd.ExcelWriter(OUTPUT_FILE, engine='openpyxl') as writer:
        merged_df.to_excel(writer, sheet_name='All Data', index=False)
        features_df.to_excel(writer, sheet_name='OSM Features', index=False)
        
        # Summary statistics sheet
        summary_stats = pd.DataFrame({
            'Metric': ['Total Records', 'Unique Locations', 'Successful Queries',
                      'Mean Roads', 'Mean Industrial', 'Mean Dumps', 'Mean Agriculture',
                      'Max Roads', 'Max Industrial', 'Max Dumps', 'Max Agriculture'],
            'Value': [len(merged_df), len(features_df), successful,
                     f"{features_df['Roads_count'].mean():.1f}",
                     f"{features_df['Industrial_zones_count'].mean():.1f}",
                     f"{features_df['Dump_sites_count'].mean():.1f}",
                     f"{features_df['Agricultural_fields_count'].mean():.1f}",
                     features_df['Roads_count'].max(),
                     features_df['Industrial_zones_count'].max(),
                     features_df['Dump_sites_count'].max(),
                     features_df['Agricultural_fields_count'].max()]
        })
        summary_stats.to_excel(writer, sheet_name='Summary', index=False)
    
    print(f"✓ Successfully saved to {OUTPUT_FILE}\n")
    
    # Display sample results
    print(f"{'Sample Results (First 15 locations):':^80}")
    print(merged_df[['City / town / village', 'State / Union Territory', 'Roads_count',
                     'Industrial_zones_count', 'Dump_sites_count', 'Agricultural_fields_count',
                     'Pollution_source_risk', 'Green_area_ratio']].head(15))
    
    print(f"\n{'='*80}")
    print("✓ Processing Complete!")
    print(f"{'='*80}\n")
    
    return merged_df, features_df

if __name__ == "__main__":
    merged_df, features_df = main()
# Out:
# ================================================================================
# OSM FEATURE EXTRACTION FOR AIR QUALITY ANALYSIS
# ================================================================================
#
# Loading dataset from Air Quality Dataset 2021-2023.xlsx...
# ✓ Loaded 1068 records
#
# Unique locations to process: 544
# Processing parameters:
#   - Batch size: 5
#   - Search radius: 5000m
#
# ================================================================================
#
# Batch 1/109:
# Processing locations 1 to 5
#
#   Querying Amaravati, Andhra Pradesh (16.4942, 80.5106)... ✓ Roads:2332 | Industrial:0 | Dumps:0 | Agriculture:89
#   Querying Anatapur, Andhra Pradesh (14.6824, 77.6017)... ✓ Roads:5915 | Industrial:3 | Dumps:0 | Agriculture:2
#   Querying Chittor, Andhra Pradesh (13.2162, 79.1051)... ✓ Roads:1986 | Industrial:4 | Dumps:0 | Agriculture:9
#   Querying Eluru, Andhra Pradesh (16.7104, 81.1154)... ✓ Roads:4515 | Industrial:2 | Dumps:0 | Agriculture:1
#   Querying Guntur, Andhra Pradesh (16.2915, 80.4542)... ✓ Roads:7442 | Industrial:4 | Dumps:0 | Agriculture:37
#
# Batch completed. Waiting before next batch...
#
# Batch 2/109:
# Processing locations 6 to 10
#
#   Querying Kadapa, Andhra Pradesh (14.4753, 78.8217)... ✓ Roads:3546 | Industrial:5 | Dumps:0 | Agriculture:0
#   Querying Kakinada, Andhra Pradesh (16.9437, 82.2351)... ✓ Roads:4702 | Industrial:12 | Dumps:0 | Agriculture:1
#   Querying Kurnool, Andhra Pradesh (15.8309, 78.0425)... ✓ Roads:4566 | Industrial:13 | Dumps:0 | Agriculture:13
#   Querying Nellore, Andhra Pradesh (14.4494, 79.9874)... ✓ Roads:5208 | Industrial:6 | Dumps:0 | Agriculture:8
#   Querying Ongole, Andhra Pradesh (15.5059, 80.0499)... ✓ Roads:3448 | Industrial:1 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 3/109:
# Processing locations 11 to 15
#
#   Querying Rajahmundry, Andhra Pradesh (17.0050, 81.7805)... ✓ Roads:4724 | Industrial:7 | Dumps:0 | Agriculture:4
#   Querying Srikakulam, Andhra Pradesh (18.2949, 83.8939)... ✓ Roads:2642 | Industrial:5 | Dumps:0 | Agriculture:28
#   Querying Tirupati, Andhra Pradesh (13.6316, 79.4232)... ✓ Roads:6026 | Industrial:3 | Dumps:0 | Agriculture:33
#   Querying Vijayawada, Andhra Pradesh (16.5115, 80.6160)... ✓ Roads:8423 | Industrial:14 | Dumps:0 | Agriculture:77
#   Querying Visakhapatnam, Andhra Pradesh (17.6936, 83.2921)... ✓ Roads:5988 | Industrial:45 | Dumps:0 | Agriculture:30
#
# Batch completed. Waiting before next batch...
#
# Batch 4/109:
# Processing locations 16 to 20
#
#   Querying Vizianagaram, Andhra Pradesh (18.1141, 83.4114)... ✓ Roads:4533 | Industrial:5 | Dumps:0 | Agriculture:10
#   Querying Itanagar, Arunachal Pradesh (27.0980, 93.6237)... ✓ Roads:918 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Naharlagun, Arunachal Pradesh (27.1309, 93.7097)... ✓ Roads:1265 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Bongaigaon, Assam (26.4800, 90.5580)... ✓ Roads:1469 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Daranga, Assam (26.7851, 91.5145)... ✓ Roads:206 | Industrial:2 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 5/109:
# Processing locations 21 to 25
#
#   Querying Dibrugarh, Assam (27.4845, 94.9019)... ✓ Roads:2336 | Industrial:5 | Dumps:0 | Agriculture:25
#   Querying Golaghat, Assam (26.5108, 93.9744)... ✓ Roads:238 | Industrial:4 | Dumps:0 | Agriculture:1
#   Querying Guwahati, Assam (26.1806, 91.7539)... ✓ Roads:4948 | Industrial:6 | Dumps:0 | Agriculture:14
#   Querying Magherita, Assam (27.2864, 95.6702)... ✓ Roads:89 | Industrial:7 | Dumps:0 | Agriculture:0
#   Querying Nagaon, Assam (26.3314, 92.7525)... ✓ Roads:373 | Industrial:1 | Dumps:0 | Agriculture:16
#
# Batch completed. Waiting before next batch...
#
# Batch 6/109:
# Processing locations 26 to 30
#
#   Querying Nalbari, Assam (26.3534, 91.3984)... ✓ Roads:518 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying North Lakhimpur, Assam (27.2544, 94.1120)... ✓ Roads:366 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Silcher, Assam (24.8333, 92.7789)... ✓ Roads:2365 | Industrial:8 | Dumps:0 | Agriculture:0
#   Querying Sivasagar, Assam (26.9835, 94.6394)... ✓ Roads:594 | Industrial:0 | Dumps:0 | Agriculture:3
#   Querying Tezpur, Assam (26.6170, 92.7650)... ✓ Roads:1054 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 7/109:
# Processing locations 31 to 35
#
#   Querying Tinsukia, Assam (27.4880, 95.3602)... ✓ Roads:2468 | Industrial:5 | Dumps:0 | Agriculture:6
#   Querying Gaya, Bihar (24.6794, 85.0116)... ✓ Roads:2047 | Industrial:4 | Dumps:0 | Agriculture:47
#   Querying Hajipur, Bihar (25.6906, 85.2090)... ✓ Roads:3679 | Industrial:12 | Dumps:0 | Agriculture:0
#   Querying Muzaffarpur, Bihar (26.1483, 85.3316)... ✓ Roads:2976 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Patna, Bihar (25.6093, 85.1235)... ✓ Roads:10449 | Industrial:9 | Dumps:0 | Agriculture:57
#
# Batch completed. Waiting before next batch...
#
# Batch 8/109:
# Processing locations 36 to 40
#
#   Querying Chandigarh, Chandigarh (UT) (30.7333, 76.7794)... ✓ Roads:11423 | Industrial:9 | Dumps:4 | Agriculture:15
#   Querying Bilaspur, Chattisgarh (22.1638, 82.1366)... ✓ Roads:1265 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Durg-Bhillainagar, Chattisgarh (21.1888, 81.2849)... ✓ Roads:6095 | Industrial:0 | Dumps:0 | Agriculture:2
#   Querying Korba, Chattisgarh (22.5198, 82.6350)... ✓ Roads:191 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Raigarh, Chattisgarh (22.2362, 83.3530)... ✓ Roads:4 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 9/109:
# Processing locations 41 to 45
#
#   Querying Raipur, Chattisgarh (21.2381, 81.6337)... ✓ Roads:10619 | Industrial:7 | Dumps:0 | Agriculture:13
#   Querying Daman, Dadara & Nagar Haveli and Daman & Diu (UT) (20.4283, 72.8397)... ✓ Roads:737 | Industrial:20 | Dumps:0 | Agriculture:1
#   Querying Delhi, Delhi (UT) (28.6139, 77.2090)... ✓ Roads:19052 | Industrial:11 | Dumps:142 | Agriculture:271
#   Querying Amona, Goa (15.5354, 73.9838)... ✓ Roads:2065 | Industrial:32 | Dumps:0 | Agriculture:86
#   Querying Assanora, Goa (15.5891, 73.8103)... ✓ Roads:4463 | Industrial:106 | Dumps:2 | Agriculture:193
#
# Batch completed. Waiting before next batch...
#
# Batch 10/109:
# Processing locations 46 to 50
#
#   Querying Bicholim, Goa (15.5558, 73.9773)... ✓ Roads:1990 | Industrial:24 | Dumps:0 | Agriculture:75
#   Querying Codli, Goa (15.3567, 74.1238)... ✓ Roads:184 | Industrial:4 | Dumps:0 | Agriculture:2
#   Querying Cuncolim, Goa (15.1801, 73.9979)... ✓ Roads:1033 | Industrial:5 | Dumps:0 | Agriculture:7
#   Querying Honda, Goa (15.5431, 74.0586)... ✓ Roads:1496 | Industrial:17 | Dumps:0 | Agriculture:20
#   Querying Kundaim, Goa (15.4597, 73.9613)... ✓ Roads:1311 | Industrial:20 | Dumps:0 | Agriculture:83
#
# Batch completed. Waiting before next batch...
#
# Batch 11/109:
# Processing locations 51 to 55
#
#   Querying Mapusa, Goa (15.5909, 73.8102)... ✓ Roads:4460 | Industrial:110 | Dumps:2 | Agriculture:186
#   Querying Margao, Goa (15.2729, 73.9583)... ✓ Roads:3907 | Industrial:9 | Dumps:0 | Agriculture:68
#   Querying Panaji, Goa (15.4990, 73.8282)... ✓ Roads:3898 | Industrial:45 | Dumps:3 | Agriculture:146
#   Querying Ponda, Goa (15.3979, 74.0080)... ✓ Roads:1360 | Industrial:12 | Dumps:0 | Agriculture:60
#   Querying Sanguem, Goa (15.2283, 74.1513)... ✓ Roads:833 | Industrial:17 | Dumps:0 | Agriculture:21
#
# Batch completed. Waiting before next batch...
#
# Batch 12/109:
# Processing locations 56 to 60
#
#   Querying Tilamol, Goa (15.2806, 74.0943)... ✓ Roads:699 | Industrial:12 | Dumps:0 | Agriculture:9
#   Querying Tuem, Goa (15.6666, 73.7957)... ✓ Roads:1451 | Industrial:32 | Dumps:0 | Agriculture:83
#   Querying Usgao-Pale, Goa (15.4892, 74.0703)... ✓ Roads:1035 | Industrial:18 | Dumps:0 | Agriculture:0
#   Querying Vasco, Goa (15.3984, 73.8129)... ✓ Roads:1320 | Industrial:15 | Dumps:0 | Agriculture:3
#   Querying Ahmedabad, Gujarat (23.0215, 72.5801)... ✓ Roads:13544 | Industrial:44 | Dumps:0 | Agriculture:33
#
# Batch completed. Waiting before next batch...
#
# Batch 13/109:
# Processing locations 61 to 65
#
#   Querying Ankleshwar, Gujarat (21.6293, 72.9945)... ✓ Roads:2314 | Industrial:4 | Dumps:0 | Agriculture:0
#   Querying Gandhinagar, Gujarat (23.2233, 72.6492)... ✓ Roads:7619 | Industrial:19 | Dumps:1 | Agriculture:37
#   Querying Jamnagar, Gujarat (22.4732, 70.0552)... ✓ Roads:6885 | Industrial:8 | Dumps:0 | Agriculture:2
#   Querying Nandesari, Gujarat (22.4178, 73.0949)... ✓ Roads:2732 | Industrial:23 | Dumps:0 | Agriculture:1
#   Querying Navarangpur, Gujarat (19.2310, 82.5482)... ✓ Roads:80 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 14/109:
# Processing locations 66 to 70
#
#   Querying Rajkot, Gujarat (22.3053, 70.8028)... ✓ Roads:12984 | Industrial:3 | Dumps:0 | Agriculture:3
#   Querying Surat, Gujarat (21.2095, 72.8317)... ✓ Roads:18600 | Industrial:35 | Dumps:0 | Agriculture:14
#   Querying Saraspur, Gujara (23.0475, 72.6036)... ✓ Roads:13562 | Industrial:48 | Dumps:0 | Agriculture:40
#   Querying Vadodara, Gujarat (22.2973, 73.1943)... ✓ Roads:18299 | Industrial:8 | Dumps:0 | Agriculture:15
#   Querying Vapi, Gujarat (20.3735, 72.9084)... ✓ Roads:1174 | Industrial:30 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 15/109:
# Processing locations 71 to 75
#
#   Querying Vatva, Gujarat (22.9590, 72.6298)... ✓ Roads:8418 | Industrial:19 | Dumps:0 | Agriculture:0
#   Querying Ambala, Haryana (30.3844, 76.7704)... ✓ Roads:5571 | Industrial:5 | Dumps:0 | Agriculture:9
#   Querying Bahadurgarh, Haryana (28.6610, 76.8347)... ✓ Roads:804 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Ballabgarh, Haryana (28.2941, 77.3592)... ✓ Roads:4129 | Industrial:11 | Dumps:0 | Agriculture:3
#   Querying Bhiwani, Haryana (28.7932, 76.1391)... ✓ Roads:4663 | Industrial:5 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 16/109:
# Processing locations 76 to 80
#
#   Querying Charkhi Dadri, Haryana (28.5920, 76.2720)... ✓ Roads:398 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Dharuhera, Haryana (28.2055, 76.7953)... ✓ Roads:2693 | Industrial:13 | Dumps:0 | Agriculture:1
#   Querying Faridabad, Haryana (28.4031, 77.3106)... ✓ Roads:10478 | Industrial:33 | Dumps:0 | Agriculture:4
#   Querying Fatehabad, Haryana (29.5359, 75.5753)... ✓ Roads:1045 | Industrial:0 | Dumps:0 | Agriculture:32
#   Querying Gurgaon, Haryana (28.4646, 77.0299)... ✓ Roads:16356 | Industrial:14 | Dumps:0 | Agriculture:33
#
# Batch completed. Waiting before next batch...
#
# Batch 17/109:
# Processing locations 81 to 85
#
#   Querying Hissar, Haryana (29.8292, 76.4723)... ✓ Roads:1826 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Jind, Haryana (29.3152, 76.3141)... ✓ Roads:3886 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Kaithal, Haryana (29.7997, 76.3990)... ✓ Roads:4070 | Industrial:7 | Dumps:0 | Agriculture:0
#   Querying Karnal, Haryana (29.7256, 76.9107)... ✓ Roads:1808 | Industrial:1 | Dumps:0 | Agriculture:1
#   Querying Kurukshetra, Haryana (29.9694, 76.8483)... ✓ Roads:5088 | Industrial:7 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 18/109:
# Processing locations 86 to 90
#
#   Querying Mandikhera, Haryana (27.8971, 76.9922)... ✓ Roads:16 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Manesar, Haryana (28.3247, 76.9264)... ✓ Roads:2967 | Industrial:21 | Dumps:0 | Agriculture:59
#   Querying Narnaul, Haryana (28.0438, 76.1062)... ✓ Roads:660 | Industrial:3 | Dumps:0 | Agriculture:1
#   Querying Palwal, Haryana (28.0599, 77.3223)... ✓ Roads:1488 | Industrial:2 | Dumps:0 | Agriculture:13
#   Querying Panchukula Urban Estate, Haryana (30.6942, 76.8606)... ✓ Roads:8521 | Industrial:5 | Dumps:0 | Agriculture:11
#
# Batch completed. Waiting before next batch...
#
# Batch 19/109:
# Processing locations 91 to 95
#
#   Querying Panipat, Haryana (29.3913, 76.9772)... ✓ Roads:8137 | Industrial:26 | Dumps:0 | Agriculture:0
#   Querying Rohtak, Haryana (28.9011, 76.5802)... ✓ Roads:7309 | Industrial:1 | Dumps:0 | Agriculture:2
#   Querying Sirsa, Haryana (29.6063, 74.9037)... ✓ Roads:980 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Sonepat, Haryana (28.9920, 77.0343)... ✓ Roads:6442 | Industrial:8 | Dumps:0 | Agriculture:0
#   Querying Yamuna Nagar, Haryana (30.1389, 77.3011)... ✓ Roads:6810 | Industrial:36 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 20/109:
# Processing locations 96 to 100
#
#   Querying Baddi, Himachal Pradesh (30.9763, 76.7674)... ✓ Roads:661 | Industrial:66 | Dumps:0 | Agriculture:0
#   Querying Damtal, Himachal Pradesh (32.2539, 75.6722)... ✓ Roads:3751 | Industrial:7 | Dumps:0 | Agriculture:0
#   Querying Dharamshala, Himachal Pradesh (32.2143, 76.3197)... ✓ Roads:1951 | Industrial:7 | Dumps:7 | Agriculture:118
#   Querying Kala Amb, Himachal Pradesh (32.0131, 76.6688)... ✓ Roads:515 | Industrial:0 | Dumps:0 | Agriculture:17
#   Querying Manali, Himachal Pradesh (32.2455, 77.1873)... ✓ Roads:1159 | Industrial:0 | Dumps:0 | Agriculture:3
#
# Batch completed. Waiting before next batch...
#
# Batch 21/109:
# Processing locations 101 to 105
#
#   Querying Nalagarh, Himachal Pradesh (31.1060, 76.6567)... ✓ Roads:112 | Industrial:15 | Dumps:0 | Agriculture:1
#   Querying Parwanoo, Himachal Pradesh (30.8379, 76.9602)... ✓ Roads:763 | Industrial:7 | Dumps:0 | Agriculture:0
#   Querying Poanta Sahib, Himachal Pradesh (30.4366, 77.6247)... ✓ Roads:987 | Industrial:11 | Dumps:0 | Agriculture:0
#   Querying Shimla, Himachal Pradesh (31.1042, 77.1710)... ✓ Roads:753 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Sunder Nagar, Himachal Pradesh (31.5163, 76.8840)... ✓ Roads:220 | Industrial:1 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 22/109:
# Processing locations 106 to 110
#
#   Querying Una, Himachal Pradesh (31.5835, 76.2351)... ✓ Roads:115 | Industrial:0 | Dumps:0 | Agriculture:5
#   Querying Jammu, Jammu & Kashmir (UT) (33.7782, 76.5762)... ✓ Roads:0 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Pulwama (K), Jammu & Kashmir (UT) (33.8747, 74.8998)... ✓ Roads:575 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Srinagar (K), Jammu & Kashmir (UT) (34.0837, 74.7973)... ✓ Roads:8218 | Industrial:7 | Dumps:0 | Agriculture:52
#   Querying Barajamda, Jharkhand (22.1641, 85.4078)... ✓ Roads:115 | Industrial:6 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 23/109:
# Processing locations 111 to 115
#
#   Querying Dhanbad, Jharkhand (23.7953, 86.4310)... ✓ Roads:4566 | Industrial:4 | Dumps:0 | Agriculture:1
#   Querying Jamshedpur, Jharkhand (22.8015, 86.2030)... ✓ Roads:8732 | Industrial:18 | Dumps:0 | Agriculture:2
#   Querying Jharia, Jharkhand (23.7408, 86.4146)... ✓ Roads:2543 | Industrial:6 | Dumps:0 | Agriculture:0
#   Querying Jorapokhar, Jharkhand (23.7167, 86.4110)... ✓ Roads:2171 | Industrial:5 | Dumps:0 | Agriculture:0
#   Querying Ranchi, Jharkhand (23.3701, 85.3250)... ✓ Roads:10515 | Industrial:3 | Dumps:0 | Agriculture:24
#
# Batch completed. Waiting before next batch...
#
# Batch 24/109:
# Processing locations 116 to 120
#
#   Querying Saraikela, Jharkhand (22.7464, 85.9169)... ✓ Roads:180 | Industrial:6 | Dumps:0 | Agriculture:0
#   Querying Sindri, Jharkhand (23.6752, 86.4896)... ✓ Roads:1307 | Industrial:4 | Dumps:0 | Agriculture:0
#   Querying Bagalkote, Karnataka (16.2904, 75.5916)... ✓ Roads:335 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Bangalore, Karnataka (12.9768, 77.5901)... ✓ Roads:35892 | Industrial:112 | Dumps:40 | Agriculture:178
#   Querying Belgaum, Karnataka (15.8573, 74.5069)... ✓ Roads:5643 | Industrial:16 | Dumps:0 | Agriculture:6
#
# Batch completed. Waiting before next batch...
#
# Batch 25/109:
# Processing locations 121 to 125
#
#   Querying Bidar, Karnataka (18.0207, 77.2487)... ✓ Roads:130 | Industrial:1 | Dumps:0 | Agriculture:1
#   Querying Bijapur / Vijayapura, Karnataka (16.8333, 75.7176)... ✓ Roads:6362 | Industrial:3 | Dumps:0 | Agriculture:23
#   Querying Chamarajanagar, Karnataka (11.9544, 77.1069)... ✓ Roads:31 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Chikkaballapur, Karnataka (13.0994, 77.3887)... ✓ Roads:5755 | Industrial:50 | Dumps:0 | Agriculture:0
#   Querying Chikkamagaluru, Karnataka (13.4059, 75.6388)... ✓ Roads:281 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 26/109:
# Processing locations 126 to 130
#
#   Querying Chitradurga, Karnataka (14.3049, 76.5297)... ✓ Roads:32 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Devanagere, Karnataka (14.4644, 75.9218)... ✓ Roads:5438 | Industrial:12 | Dumps:0 | Agriculture:4
#   Querying Gadag, Karnataka (15.4167, 75.6816)... ✓ Roads:1898 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Gulbarga / Kalaburgi, Karnataka (17.3297, 76.8343)... ✓ Roads:9742 | Industrial:5 | Dumps:0 | Agriculture:7
#   Querying Hassan, Karnataka (13.0302, 76.1745)... ✓ Roads:1892 | Industrial:4 | Dumps:0 | Agriculture:27
#
# Batch completed. Waiting before next batch...
#
# Batch 27/109:
# Processing locations 131 to 135
#
#   Querying Hubli-Dharwad, Karnataka (15.3428, 75.1695)... ✓ Roads:5200 | Industrial:3 | Dumps:0 | Agriculture:3
#   Querying Kolar, Karnataka (13.1805, 78.2669)... ✓ Roads:436 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Koppal, Karnataka (15.5748, 76.3118)... ✓ Roads:39 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Madikeri, Karnataka (12.4215, 75.7388)... ✓ Roads:564 | Industrial:1 | Dumps:0 | Agriculture:6
#   Querying Mandya, Karnataka (12.6369, 76.7275)... ✓ Roads:434 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 28/109:
# Processing locations 136 to 140
#
#   Querying Mangalore, Karnataka (12.8698, 74.8430)... ✓ Roads:4397 | Industrial:16 | Dumps:0 | Agriculture:20
#   Querying Mysore, Karnataka (12.3052, 76.6554)... ✓ Roads:12798 | Industrial:12 | Dumps:0 | Agriculture:57
#   Querying Raichur, Karnataka (16.0547, 76.9004)... ✓ Roads:82 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Ramanagara, Karnataka (12.7200, 77.3184)... ✓ Roads:1177 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Shimaga / Shivamogga, Karnataka (13.9299, 75.5681)... ✓ Roads:6151 | Industrial:3 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 29/109:
# Processing locations 141 to 145
#
#   Querying Tumkuru, Karnataka (13.3422, 77.1010)... ✓ Roads:6397 | Industrial:10 | Dumps:0 | Agriculture:5
#   Querying Udupi, Karnataka (13.5270, 74.8732)... ✓ Roads:887 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Yadgir, Karnataka (16.5744, 76.9254)... ✓ Roads:61 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Alappuzha, Kerala (9.5007, 76.4124)... ✓ Roads:658 | Industrial:1 | Dumps:0 | Agriculture:10
#   Querying Eloor, Kerala (10.0670, 76.2989)... ✓ Roads:6532 | Industrial:35 | Dumps:0 | Agriculture:68
#
# Batch completed. Waiting before next batch...
#
# Batch 30/109:
# Processing locations 146 to 150
#
#   Querying Ernakulam, Kerala (9.9837, 76.2740)... ✓ Roads:10521 | Industrial:47 | Dumps:3 | Agriculture:31
#   Querying Kannur, Kerala (11.8764, 75.3738)... ✓ Roads:4709 | Industrial:7 | Dumps:0 | Agriculture:5
#   Querying Kochi, Kerala (9.9679, 76.2444)... ✓ Roads:4969 | Industrial:42 | Dumps:1 | Agriculture:11
#   Querying Kollam, Kerala (8.8871, 76.5907)... ✓ Roads:11952 | Industrial:18 | Dumps:0 | Agriculture:11
#   Querying Kottayam, Kerala (9.6287, 76.6455)... ✓ Roads:934 | Industrial:4 | Dumps:0 | Agriculture:24
#
# Batch completed. Waiting before next batch...
#
# Batch 31/109:
# Processing locations 151 to 155
#
#   Querying Kozhikode, Kerala (11.2451, 75.7755)... ✓ Roads:3838 | Industrial:19 | Dumps:0 | Agriculture:8
#   Querying Mallappuram, Kerala (11.0730, 76.0740)... ✓ Roads:2151 | Industrial:9 | Dumps:0 | Agriculture:45
#   Querying Palakkad, Kerala (10.7874, 76.4742)... ✓ Roads:607 | Industrial:1 | Dumps:0 | Agriculture:71
#   Querying Pathanamthitta, Kerala (9.2781, 76.9737)... ✓ Roads:160 | Industrial:0 | Dumps:0 | Agriculture:3
#   Querying Thiruvanantapuram, Kerala (8.5441, 76.9366)... ✓ Roads:12356 | Industrial:13 | Dumps:14 | Agriculture:93
#
# Batch completed. Waiting before next batch...
#
# Batch 32/109:
# Processing locations 156 to 160
#
#   Querying Thrissur, Kerala (10.5270, 76.2146)... ✓ Roads:9836 | Industrial:19 | Dumps:0 | Agriculture:147
#   Querying Wayanad, Kerala (11.7151, 76.1271)... ✓ Roads:855 | Industrial:2 | Dumps:0 | Agriculture:288
#   Querying Amlai, Madhya Pradesh (23.1733, 81.5917)... ✓ Roads:736 | Industrial:3 | Dumps:0 | Agriculture:7
#   Querying Bhopal, Madhya Pradesh (23.2585, 77.4020)... ✓ Roads:12494 | Industrial:9 | Dumps:0 | Agriculture:86
#   Querying Chindwara, Madhya Pradesh (22.0004, 78.8972)... ✓ Roads:286 | Industrial:2 | Dumps:0 | Agriculture:2
#
# Batch completed. Waiting before next batch...
#
# Batch 33/109:
# Processing locations 161 to 165
#
#   Querying Damoh, Madhya Pradesh (23.7981, 79.5419)... ✓ Roads:453 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Dewas, Madhya Pradesh (22.8057, 76.2940)... ✓ Roads:117 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Gwalior, Madhya Pradesh (26.2037, 78.1574)... ✓ Roads:9075 | Industrial:8 | Dumps:0 | Agriculture:1
#   Querying Indore, Madhya Pradesh (22.7204, 75.8682)... ✓ Roads:17142 | Industrial:29 | Dumps:6 | Agriculture:15
#   Querying Jabalpur, Madhya Pradesh (23.1702, 79.9325)... ✓ Roads:7526 | Industrial:7 | Dumps:0 | Agriculture:6
#
# Batch completed. Waiting before next batch...
#
# Batch 34/109:
# Processing locations 166 to 170
#
#   Querying Katni, Madhya Pradesh (23.7176, 80.2610)... ✓ Roads:30 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Maihar, Madhya Pradesh (24.2604, 80.7593)... ✓ Roads:266 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Mandideep, Madhya Pradesh (23.0938, 77.5114)... ✓ Roads:1749 | Industrial:15 | Dumps:0 | Agriculture:3
#   Querying Nagda, Madhya Pradesh (23.4579, 75.4191)... ✓ Roads:610 | Industrial:2 | Dumps:0 | Agriculture:1
#   Querying Pithampur, Madhya Pradesh (22.6106, 75.6790)... ✓ Roads:930 | Industrial:7 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 35/109:
# Processing locations 171 to 175
#
#   Querying Ratlam, Madhya Pradesh (23.5022, 74.9552)... ✓ Roads:218 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Rewa, Madhya Pradesh (24.7561, 81.3811)... ✓ Roads:19 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Sagar, Madhya Pradesh (23.8083, 78.7583)... ✓ Roads:3786 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Satna, Madhya Pradesh (24.6954, 80.7770)... ✓ Roads:398 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Singrauli, Madhya Pradesh (24.2431, 82.3828)... ✓ Roads:95 | Industrial:1 | Dumps:0 | Agriculture:7
#
# Batch completed. Waiting before next batch...
#
# Batch 36/109:
# Processing locations 176 to 180
#
#   Querying Ujjain, Madhya Pradesh (23.1885, 75.7717)... ✓ Roads:5741 | Industrial:11 | Dumps:0 | Agriculture:0
#   Querying Akola, Maharashtra (20.7618, 77.1921)... ✓ Roads:450 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Ambernath, Maharashtra (19.2016, 73.2005)... ✓ Roads:4007 | Industrial:23 | Dumps:0 | Agriculture:2
#   Querying Amravati, Maharashtra (21.1545, 77.6443)... ✓ Roads:114 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Aurangabad, Maharashtra (19.8773, 75.3390)... ✓ Roads:12649 | Industrial:35 | Dumps:0 | Agriculture:11
#
# Batch completed. Waiting before next batch...
#
# Batch 37/109:
# Processing locations 181 to 185
#
#   Querying Badlapur, Maharashtra (19.1666, 73.2389)... ✓ Roads:2240 | Industrial:14 | Dumps:0 | Agriculture:1
#   Querying Bhiwandi, Maharashtra (19.3026, 73.0588)... ✓ Roads:2927 | Industrial:36 | Dumps:0 | Agriculture:5
#   Querying Chandrapur, Maharashtra (20.0968, 79.5045)... ✓ Roads:39 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Dombivali / Kalyan, Maharashtra (19.2569, 73.1329)... ✓ Roads:5153 | Industrial:41 | Dumps:0 | Agriculture:7
#   Querying Jalgaon, Maharashtra (20.8429, 75.5261)... ✓ Roads:24 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 38/109:
# Processing locations 186 to 190
#
#   Querying Jalna, Maharashtra (19.9188, 75.8709)... ✓ Roads:575 | Industrial:7 | Dumps:0 | Agriculture:3
#   Querying Kolhapur, Maharashtra (16.7028, 74.2405)... ✓ Roads:7252 | Industrial:15 | Dumps:0 | Agriculture:10
#   Querying Latur, Maharashtra (18.3553, 76.7549)... ✓ Roads:256 | Industrial:1 | Dumps:0 | Agriculture:3
#   Querying Mumbai, Maharashtra (19.0550, 72.8692)... ✓ Roads:12631 | Industrial:96 | Dumps:3 | Agriculture:188
#   Querying Nagpur, Maharashtra (21.1498, 79.0821)... ✓ Roads:13746 | Industrial:22 | Dumps:0 | Agriculture:35
#
# Batch completed. Waiting before next batch...
#
# Batch 39/109:
# Processing locations 191 to 195
#
#   Querying Nanded, Maharashtra (19.0940, 77.4832)... ✓ Roads:549 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Nashik, Maharashtra (20.0112, 73.7902)... ✓ Roads:8289 | Industrial:8 | Dumps:0 | Agriculture:60
#   Querying Navi Mumbai, Maharashtra (19.0308, 73.0199)... ✓ Roads:6082 | Industrial:48 | Dumps:0 | Agriculture:157
#   Querying Pimpri-Chinchwad, Maharashtra (18.6279, 73.8010)... ✓ Roads:14538 | Industrial:31 | Dumps:5 | Agriculture:28
#   Querying Pune, Maharashtra (18.5214, 73.8545)... ✓ Roads:17991 | Industrial:18 | Dumps:1 | Agriculture:133
#
# Batch completed. Waiting before next batch...
#
# Batch 40/109:
# Processing locations 196 to 200
#
#   Querying Roha, Maharashtra (18.4466, 73.1239)... ✓ Roads:139 | Industrial:4 | Dumps:0 | Agriculture:1
#   Querying Sangli, Maharashtra (17.1727, 74.5868)... ✓ Roads:68 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Solapur, Maharashtra (17.8499, 75.2763)... ✓ Roads:136 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Thane, Maharashtra (19.1943, 72.9702)... ✓ Roads:9073 | Industrial:151 | Dumps:0 | Agriculture:130
#   Querying Ulhas Nagar, Maharashtra (19.0642, 72.8848)... ✓ Roads:12676 | Industrial:111 | Dumps:2 | Agriculture:166
#
# Batch completed. Waiting before next batch...
#
# Batch 41/109:
# Processing locations 201 to 205
#
#   Querying Vasai virar, Maharashtra (19.4210, 72.8197)... ✓ Roads:4040 | Industrial:9 | Dumps:0 | Agriculture:3
#   Querying Imphal, Manipur (24.7991, 93.9364)... ✓ Roads:4511 | Industrial:3 | Dumps:0 | Agriculture:0
#   Querying Byraihat, Meghalaya (25.9045, 91.8695)... ✓ Roads:10 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Dawki, Meghalaya (25.1856, 92.0216)... ✓ Roads:557 | Industrial:5 | Dumps:0 | Agriculture:1
#   Querying Khlihriat, Meghalaya (25.3570, 92.3534)... ✓ Roads:43 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 42/109:
# Processing locations 206 to 210
#
#   Querying Nongstoin, Meghalaya (25.5726, 91.2541)... ✓ Roads:118 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Shillong, Meghalaya (25.5760, 91.8828)... ✓ Roads:4703 | Industrial:2 | Dumps:0 | Agriculture:57
#   Querying Tura, Meghalaya (25.5126, 90.2172)... ✓ Roads:52 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Umaim, Meghalaya (25.6710, 91.8991)... ✓ Roads:599 | Industrial:1 | Dumps:0 | Agriculture:11
#   Querying Aizwal, Mizoram (23.8389, 92.6243)... ✓ Roads:239 | Industrial:0 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 43/109:
# Processing locations 211 to 215
#
#   Querying Champhai, Mizoram (23.6317, 93.3493)... ✓ Roads:121 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Khatla, Mizoram (23.7191, 92.7142)... ✓ Roads:1627 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Kolasib, Mizoram (24.2313, 92.6766)... ✓ Roads:100 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Lawngtlai, Mizoram (22.3913, 92.7397)... ✓ Roads:7 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Lunglei, Mizoram (22.9520, 92.6339)... ✓ Roads:22 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 44/109:
# Processing locations 216 to 220
#
#   Querying Lengpui, Mizoram (23.8407, 92.6211)... ✓ Roads:235 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Mamit, Mizoram (23.7564, 92.4515)... ✓ Roads:24 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Saiha, Mizoram (22.4880, 92.9813)... ✓ Roads:338 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Serchhip, Mizoram (23.3053, 92.8455)... ✓ Roads:146 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Dimapur, Nagaland (25.9041, 93.7178)... ✓ Roads:3563 | Industrial:6 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 45/109:
# Processing locations 221 to 225
#
#   Querying Kohima, Nagaland (25.6619, 94.1019)... ✓ Roads:744 | Industrial:1 | Dumps:0 | Agriculture:1
#   Querying Angul, Odisha (21.1025, 84.9537)... ✓ Roads:42 | Industrial:3 | Dumps:0 | Agriculture:0
#   Querying Balasore, Odisha (21.5006, 86.9199)... ✓ Roads:993 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Berhampur, Odisha (21.4931, 86.6327)... ✓ Roads:104 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Bhubaneshwar, Odisha (20.2603, 85.8395)... ✓ Roads:9080 | Industrial:4 | Dumps:1 | Agriculture:19
#
# Batch completed. Waiting before next batch...
#
# Batch 46/109:
# Processing locations 226 to 230
#
#   Querying Bonaigarh, Odisha (21.7474, 84.3569)... ✓ Roads:242 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Brajrajnagar, Odisha (21.8499, 83.9255)... ✓ Roads:180 | Industrial:3 | Dumps:0 | Agriculture:0
#   Querying Cuttack, Odisha (20.4686, 85.8792)... ✓ Roads:3313 | Industrial:3 | Dumps:0 | Agriculture:3
#   Querying Jharsuguda, Odisha (21.8019, 83.9714)... ✓ Roads:454 | Industrial:5 | Dumps:0 | Agriculture:0
#   Querying Kalinga Nagar, Odisha (20.2680, 85.7623)... ✓ Roads:6507 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 47/109:
# Processing locations 231 to 235
#
#   Querying Konark, Odisha (19.9074, 86.1420)... ✓ Roads:456 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Paradeep, Odisha (20.2797, 86.6123)... ✓ Roads:824 | Industrial:20 | Dumps:0 | Agriculture:15
#   Querying Puri, Odisha (19.8076, 85.8253)... ✓ Roads:2504 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Rajgangpur, Odisha (22.1861, 84.5835)... ✓ Roads:94 | Industrial:3 | Dumps:0 | Agriculture:0
#   Querying Rayagada, Odisha (19.4427, 83.5873)... ✓ Roads:45 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 48/109:
# Processing locations 236 to 240
#
#   Querying Rourkela, Odisha (22.2309, 84.8679)... ✓ Roads:3791 | Industrial:8 | Dumps:0 | Agriculture:9
#   Querying Sambalpur, Odisha (21.5571, 84.1529)... ✓ Roads:544 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Talcher, Odisha (20.9322, 85.2006)... ✓ Roads:219 | Industrial:5 | Dumps:0 | Agriculture:0
#   Querying Karaikal, Pondicherry (UT) (10.9167, 79.8333)... ✓ Roads:2024 | Industrial:1 | Dumps:0 | Agriculture:57
#   Querying Pondicherry, Pondicherry (UT) (11.9416, 79.8083)... ✓ Roads:8460 | Industrial:40 | Dumps:0 | Agriculture:76
#
# Batch completed. Waiting before next batch...
#
# Batch 49/109:
# Processing locations 241 to 245
#
#   Querying Aligarh (Jagraon), Punjab (30.7994, 75.4945)... ✓ Roads:922 | Industrial:3 | Dumps:0 | Agriculture:0
#   Querying Amritsar, Punjab (31.6340, 74.8723)... ✓ Roads:11683 | Industrial:36 | Dumps:0 | Agriculture:17
#   Querying Aspal Khurd (Tapa), Punjab (30.4078, 75.6212)... ✓ Roads:1233 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Bara Pind (Goraya), Punjab (31.1150, 75.8134)... ✓ Roads:1982 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Batala, Punjab (31.8193, 75.2000)... ✓ Roads:3825 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 50/109:
# Processing locations 246 to 250
#
#   Querying Bhatinda, Punjab (30.2068, 74.9464)... ✓ Roads:4053 | Industrial:15 | Dumps:0 | Agriculture:18
#   Querying Binjon (Garshankar), Punjab (30.5683, 74.9704)... ✓ Roads:788 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Bishanpura (Payal), Punjab (30.3097, 75.8893)... ✓ Roads:645 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Changal (Sangrur), Punjab (30.2855, 75.7927)... ✓ Roads:717 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Chowkimann (Jagraon), Punjab (30.7802, 75.9984)... ✓ Roads:2021 | Industrial:12 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 51/109:
# Processing locations 251 to 255
#
#   Querying Dera Baba Nanak, Punjab (32.0318, 75.0285)... ✓ Roads:894 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Dera Bassi, Punjab (30.5882, 76.8439)... ✓ Roads:2224 | Industrial:25 | Dumps:0 | Agriculture:2
#   Querying Fatehpur (Samana), Punjab (30.1810, 76.2291)... ✓ Roads:1151 | Industrial:19 | Dumps:0 | Agriculture:6
#   Querying Gobindgarh Mandi Gobindgarh, Punjab (30.6693, 76.2975)... ✓ Roads:1941 | Industrial:51 | Dumps:0 | Agriculture:0
#   Querying Guru Ki Dhab (Kotkapura), Punjab (30.5413, 74.8190)... ✓ Roads:453 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 52/109:
# Processing locations 256 to 260
#
#   Querying Jaito Sarja (Batala), Punjab (31.7467, 75.1974)... ✓ Roads:1506 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Jalandhar, Punjab (31.2922, 75.5679)... ✓ Roads:10158 | Industrial:3 | Dumps:0 | Agriculture:1
#   Querying Khanna, Punjab (30.7006, 76.2221)... ✓ Roads:3412 | Industrial:21 | Dumps:0 | Agriculture:5
#   Querying Kharaori (Sirhind), Punjab (30.2512, 75.7748)... ✓ Roads:220 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Kotladoom (Ajnala), Punjab (30.2793, 75.8409)... ✓ Roads:765 | Industrial:1 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 53/109:
# Processing locations 261 to 265
#
#   Querying Lakho ke Behram (Ferozpur), Punjab (30.4520, 74.9655)... ✓ Roads:184 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Ludhiana, Punjab (30.9090, 75.8516)... ✓ Roads:15857 | Industrial:31 | Dumps:0 | Agriculture:3
#   Querying Mrar Kalan (Muktsar), Punjab (30.4825, 75.8073)... ✓ Roads:1058 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Mukandpur (Nawashahar), Punjab (31.1591, 76.0341)... ✓ Roads:340 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Mureedke (Batala), Punjab (31.5167, 74.2500)... ✓ Roads:7810 | Industrial:1 | Dumps:0 | Agriculture:7
#
# Batch completed. Waiting before next batch...
#
# Batch 54/109:
# Processing locations 266 to 270
#
#   Querying Naudhrani (Malerkotla), Punjab (30.4024, 75.6542)... ✓ Roads:1541 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Naya Nangal, Punjab (31.3799, 76.3600)... ✓ Roads:1551 | Industrial:6 | Dumps:0 | Agriculture:0
#   Querying Patiala, Punjab (30.2093, 76.3397)... ✓ Roads:848 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Peer Mohammad (Jalalabad), Punjab (30.4769, 74.7752)... ✓ Roads:111 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Poohli (Bhatinda), Punjab (30.2946, 75.0831)... ✓ Roads:122 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 55/109:
# Processing locations 271 to 275
#
#   Querying Qila Bharian (Sangrur), Punjab (30.4582, 75.6189)... ✓ Roads:1311 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Rakhra (Patiala), Punjab (30.3730, 76.2573)... ✓ Roads:730 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Rohila (Samrala), Punjab (30.4384, 75.5852)... ✓ Roads:1322 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Rupnagar, Punjab (31.0917, 76.5290)... ✓ Roads:1257 | Industrial:1 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 56/109:
# Processing locations 276 to 280
#
#   Querying Tirathpur (Amritsar I), Punjab (30.4227, 75.6129)... ✓ Roads:1479 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Ajmer, Rajasthan (26.4691, 74.6390)... ✓ Roads:9455 | Industrial:1 | Dumps:0 | Agriculture:1
#   Querying Alwar, Rajasthan (27.4140, 76.6170)... ✓ Roads:1835 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Bharatpur, Rajasthan (27.0247, 77.2920)... ✓ Roads:76 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Bhiwadi, Rajasthan (28.2039, 76.8374)... ✓ Roads:2693 | Industrial:20 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 57/109:
# Processing locations 281 to 285
#
#   Querying Chittorgargh, Rajasthan (24.8890, 74.6260)... ✓ Roads:3196 | Industrial:10 | Dumps:0 | Agriculture:1
#   Querying Jaipur, Rajasthan (26.9155, 75.8190)... ✓ Roads:12643 | Industrial:4 | Dumps:0 | Agriculture:101
#   Querying Jodhpur, Rajasthan (26.2968, 73.0351)... ✓ Roads:10883 | Industrial:4 | Dumps:0 | Agriculture:21
#   Querying Kota, Rajasthan (25.1737, 75.8574)... ✓ Roads:10136 | Industrial:27 | Dumps:0 | Agriculture:16
#   Querying Pali, Rajasthan (25.4552, 73.4194)... ✓ Roads:72 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 58/109:
# Processing locations 286 to 290
#
#   Querying Udaipur, Rajasthan (24.5787, 73.6863)... ✓ Roads:6717 | Industrial:2 | Dumps:0 | Agriculture:45
#   Querying Chungthang, Sikkim (27.8133, 88.5200)... ✓ Roads:78 | Industrial:0 | Dumps:0 | Agriculture:12
#   Querying Gangtok, Sikkim (27.3290, 88.6123)... ✓ Roads:859 | Industrial:0 | Dumps:0 | Agriculture:58
#   Querying Mangan, Sikkim (27.7503, 88.5212)... ✓ Roads:35 | Industrial:0 | Dumps:0 | Agriculture:4
#   Querying Namchi, Sikkim (27.3031, 88.3786)... ✓ Roads:635 | Industrial:0 | Dumps:0 | Agriculture:21
#
# Batch completed. Waiting before next batch...
#
# Batch 59/109:
# Processing locations 291 to 295
#
#   Querying Pelling, Sikkim (27.3004, 88.2357)... ✓ Roads:463 | Industrial:0 | Dumps:0 | Agriculture:49
#   Querying Rangpo, Sikkim (27.1744, 88.5303)... ✓ Roads:262 | Industrial:20 | Dumps:0 | Agriculture:0
#   Querying Ravangla, Sikkim (27.3051, 88.3645)... ✓ Roads:563 | Industrial:0 | Dumps:0 | Agriculture:17
#   Querying Singtam, Sikkim (27.2320, 88.4971)... ✓ Roads:390 | Industrial:7 | Dumps:0 | Agriculture:9
#   Querying Chennai, Tamilnadu (13.0837, 80.2702)... ✓ Roads:13725 | Industrial:78 | Dumps:0 | Agriculture:46
#
# Batch completed. Waiting before next batch...
#
# Batch 60/109:
# Processing locations 296 to 300
#
#   Querying Coimbatore, Tamilnadu (11.0018, 76.9628)... ✓ Roads:11519 | Industrial:19 | Dumps:0 | Agriculture:48
#   Querying Cuddalore, Tamilnadu (11.5202, 79.3396)... ✓ Roads:1349 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Dharmapuri, Tamilnadu (12.1456, 78.1132)... ✓ Roads:1145 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Gummidipoondi, Tamilnadu (13.4309, 80.0821)... ✓ Roads:786 | Industrial:25 | Dumps:0 | Agriculture:0
#   Querying Madurai, Tamilnadu (9.9261, 78.1141)... ✓ Roads:11123 | Industrial:11 | Dumps:0 | Agriculture:29
#
# Batch completed. Waiting before next batch...
#
# Batch 61/109:
# Processing locations 301 to 305
#
#   Querying Mettur, Tamilnadu (11.7928, 77.8649)... ✓ Roads:1270 | Industrial:11 | Dumps:0 | Agriculture:0
#   Querying Nagarcoil, Tamilnadu (8.1782, 77.4326)... ✓ Roads:4679 | Industrial:8 | Dumps:0 | Agriculture:79
#   Querying Perambalur, Tamilnadu (11.2903, 78.9300)... ✓ Roads:568 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Salem, Tamilnadu (11.6470, 78.2107)... ✓ Roads:3025 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Sivagangai, Tamilnadu (9.9651, 78.7204)... ✓ Roads:254 | Industrial:1 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 62/109:
# Processing locations 306 to 310
#
#   Querying Trichy, Tamilnadu (10.8071, 78.6881)... ✓ Roads:8001 | Industrial:17 | Dumps:0 | Agriculture:31
#   Querying Theni, Tamilnadu (9.8693, 77.4223)... ✓ Roads:550 | Industrial:0 | Dumps:0 | Agriculture:2
#   Querying Tiruvannamalai, Tamilnadu (12.4289, 78.9992)... ✓ Roads:331 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Tiruvarur, Tamilnadu (10.8621, 79.4790)... ✓ Roads:761 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Villupuram, Tamilnadu (11.9960, 79.7674)... ✓ Roads:2259 | Industrial:13 | Dumps:1 | Agriculture:8
#
# Batch completed. Waiting before next batch...
#
# Batch 63/109:
# Processing locations 311 to 315
#
#   Querying Tuticorin / Thoothukudi, Tamilnadu (8.8274, 78.1294)... ✓ Roads:3531 | Industrial:13 | Dumps:0 | Agriculture:2
#   Querying Adilabad, Telangana (19.6759, 78.5340)... ✓ Roads:0 | Industrial:3 | Dumps:0 | Agriculture:2
#   Querying Hyderabad, Telangana (17.3850, 78.4867)... ✓ Roads:23081 | Industrial:11 | Dumps:1 | Agriculture:57
#   Querying Karimnagar, Telangana (18.4348, 79.1328)... ✓ Roads:5876 | Industrial:4 | Dumps:0 | Agriculture:4
#   Querying Khammam, Telangana (17.2465, 80.1500)... ✓ Roads:5676 | Industrial:5 | Dumps:0 | Agriculture:10
#
# Batch completed. Waiting before next batch...
#
# Batch 64/109:
# Processing locations 316 to 320
#
#   Querying Kothur, Telangana (17.1486, 78.2887)... ✓ Roads:2393 | Industrial:1 | Dumps:0 | Agriculture:42
#   Querying Nalgonda, Telangana (16.8580, 79.2175)... ✓ Roads:80 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Nizamabad, Telangana (18.6733, 78.0978)... ✓ Roads:6059 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Patencheru, Telangana (17.5310, 78.2645)... ✓ Roads:6915 | Industrial:9 | Dumps:0 | Agriculture:32
#   Querying Ramagundum, Telangana (18.7596, 79.4740)... ✓ Roads:2428 | Industrial:3 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 65/109:
# Processing locations 321 to 325
#
#   Querying Sangareddy, Telangana (17.8684, 77.8227)... ✓ Roads:100 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Warangal, Telangana (17.9821, 79.5971)... ✓ Roads:8637 | Industrial:1 | Dumps:0 | Agriculture:68
#   Querying Agartala, Tripura (23.8312, 91.2824)... ✓ Roads:6539 | Industrial:6 | Dumps:0 | Agriculture:46
#   Querying Agra, Uttar Pradesh (27.1753, 78.0098)... ✓ Roads:12160 | Industrial:5 | Dumps:0 | Agriculture:112
#   Querying Aligarh, Uttar Pradesh (27.8761, 78.1358)... ✓ Roads:6216 | Industrial:2 | Dumps:0 | Agriculture:4
#
# Batch completed. Waiting before next batch...
#
# Batch 66/109:
# Processing locations 326 to 330
#
#   Querying Allahabad, Uttar Pradesh (25.4381, 81.8338)... ✓ Roads:9233 | Industrial:7 | Dumps:0 | Agriculture:28
#   Querying Anpara, Uttar Pradesh (24.2055, 82.7715)... ✓ Roads:426 | Industrial:15 | Dumps:0 | Agriculture:0
#   Querying Ayodhya, Uttar Pradesh (26.7991, 82.2052)... ✓ Roads:2589 | Industrial:0 | Dumps:0 | Agriculture:32
#   Querying Bagpat, Uttar Pradesh (28.9673, 77.6648)... ✓ Roads:6509 | Industrial:22 | Dumps:2 | Agriculture:9
#   Querying Bareily, Uttar Pradesh (28.3670, 79.4304)... ✓ Roads:7034 | Industrial:11 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 67/109:
# Processing locations 331 to 335
#
#   Querying Bulandshahr, Uttar Pradesh (28.3874, 77.9744)... ✓ Roads:1114 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Firozabad, Uttar Pradesh (27.1942, 78.4605)... ✓ Roads:1325 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Gajroula, Uttar Pradesh (28.8446, 78.2396)... ✓ Roads:261 | Industrial:4 | Dumps:0 | Agriculture:0
#   Querying Ghaziabad, Uttar Pradesh (28.7750, 77.4587)... ✓ Roads:2637 | Industrial:74 | Dumps:0 | Agriculture:8
#   Querying Gorakhpur, Uttar Pradesh (26.6678, 83.3642)... ✓ Roads:2006 | Industrial:0 | Dumps:0 | Agriculture:0
#  ✓ Roads:4794 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Unnao, Uttar Pradesh (26.5673, 80.6198)... ✓ Roads:289 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Varanasi, Uttar Pradesh (25.3356, 83.0076)... ✓ Roads:9763 | Industrial:10 | Dumps:0 | Agriculture:61
#   Querying Dehradun, Uttarakhand (30.3256, 78.0437)... ✓ Roads:10064 | Industrial:0 | Dumps:0 | Agriculture:11
#
# Batch completed. Waiting before next batch...
#
# Batch 71/109:
# Processing locations 351 to 355
#
#   Querying Haldwani, Uttarakhand (29.2145, 79.5279)... ✓ Roads:8855 | Industrial:7 | Dumps:0 | Agriculture:281
#   Querying Haridwar, Uttarakhand (29.9384, 78.1453)... ✓ Roads:3800 | Industrial:1 | Dumps:0 | Agriculture:9
#   Querying Kashipur, Uttarakhand (29.2118, 78.9617)... ✓ Roads:5773 | Industrial:15 | Dumps:0 | Agriculture:4
#   Querying Rishikesh, Uttarakhand (30.1087, 78.2916)... ✓ Roads:2434 | Industrial:5 | Dumps:0 | Agriculture:0
#   Querying Rudrapur, Uttarakhand (28.9707, 79.3973)... ✓ Roads:5700 | Industrial:22 | Dumps:0 | Agriculture:32
#
# Batch completed. Waiting before next batch...
#
# Batch 72/109:
# Processing locations 356 to 360
#
#   Querying Alipurduar, West Bengal (26.4852, 89.5247)... ✓ Roads:499 | Industrial:12 | Dumps:0 | Agriculture:2
#   Querying Amtala, West Bengal (22.3669, 88.2777)... ✓ Roads:2038 | Industrial:3 | Dumps:0 | Agriculture:0
#   Querying Asansol, West Bengal (23.6871, 86.9747)... ✓ Roads:5036 | Industrial:3 | Dumps:0 | Agriculture:2
#   Querying Baharampur, West Bengal (24.1045, 88.2511)... ✓ Roads:2597 | Industrial:0 | Dumps:0 | Agriculture:93
#   Querying Balurghat, West Bengal (25.2234, 88.7781)... ✓ Roads:1738 | Industrial:4 | Dumps:0 | Agriculture:9
#
# Batch completed. Waiting before next batch...
#
# Batch 73/109:
# Processing locations 361 to 365
#
#   Querying Bankura, West Bengal (23.1324, 87.2082)... ✓ Roads:742 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Barasat, West Bengal (22.7191, 88.4826)... ✓ Roads:7732 | Industrial:2 | Dumps:0 | Agriculture:11
#   Querying Bardhaman, West Bengal (23.2496, 87.8682)... ✓ Roads:5082 | Industrial:21 | Dumps:0 | Agriculture:6
#   Querying Barrckpore, West Bengal (26.2303, 81.2330)... ✓ Roads:3823 | Industrial:4 | Dumps:0 | Agriculture:0
#   Querying Baruipur, West Bengal (22.3607, 88.4323)... ✓ Roads:2839 | Industrial:3 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 74/109:
# Processing locations 366 to 370
#
#   Querying Bolpur, West Bengal (23.6612, 87.6962)... ✓ Roads:2476 | Industrial:0 | Dumps:0 | Agriculture:2
#   Querying Chinsura, West Bengal (22.9024, 88.3893)... ✓ Roads:8835 | Industrial:16 | Dumps:0 | Agriculture:4
#   Querying Coochbihar, West Bengal (26.3257, 89.4511)... ✓ Roads:1310 | Industrial:27 | Dumps:0 | Agriculture:5
#   Querying Dankuni, West Bengal (22.6821, 88.2907)... ✓ Roads:6494 | Industrial:11 | Dumps:0 | Agriculture:0
#   Querying Darjeeling, West Bengal (27.0378, 88.2632)... ✓ Roads:1386 | Industrial:0 | Dumps:0 | Agriculture:2723
#
# Batch completed. Waiting before next batch...
#
# Batch 75/109:
# Processing locations 371 to 375
#
#   Querying Durgapur, West Bengal (23.5350, 87.3380)... ✓ Roads:4859 | Industrial:19 | Dumps:0 | Agriculture:3
#   Querying Ghatal, West Bengal (22.6823, 87.6992)... ✓ Roads:58 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Haldia, West Bengal (22.0281, 88.0633)... ✓ Roads:1227 | Industrial:25 | Dumps:0 | Agriculture:16
#   Querying Howrah, West Bengal (22.5736, 88.3251)... ✓ Roads:13038 | Industrial:88 | Dumps:1 | Agriculture:7
#   Querying Jalpaiguri, West Bengal (26.6263, 88.7334)... ✓ Roads:885 | Industrial:0 | Dumps:0 | Agriculture:5
#
# Batch completed. Waiting before next batch...
#
# Batch 76/109:
# Processing locations 376 to 380
#
#   Querying Jhargram, West Bengal (22.4539, 86.9949)... ✓ Roads:402 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Kalimpong, West Bengal (27.0703, 88.4724)... ✓ Roads:484 | Industrial:1 | Dumps:0 | Agriculture:2
#   Querying Kalyani, West Bengal (22.9750, 88.4346)... ✓ Roads:5616 | Industrial:18 | Dumps:0 | Agriculture:9
#   Querying Kharagpur, West Bengal (22.3431, 87.3013)... ✓ Roads:3580 | Industrial:11 | Dumps:0 | Agriculture:0
#   Querying Kolkata, West Bengal (22.5726, 88.3639)... ✓ Roads:16772 | Industrial:188 | Dumps:1 | Agriculture:28
#
# Batch completed. Waiting before next batch...
#
# Batch 77/109:
# Processing locations 381 to 385
#
#   Querying Krishnanagar, West Bengal (23.4058, 88.4959)... ✓ Roads:1188 | Industrial:1 | Dumps:0 | Agriculture:5
#   Querying Madhyamgram, West Bengal (22.6948, 88.4530)... ✓ Roads:10425 | Industrial:0 | Dumps:0 | Agriculture:36
#   Querying Malda, West Bengal (25.0057, 88.1398)... ✓ Roads:2676 | Industrial:24 | Dumps:0 | Agriculture:20
#   Querying Medinipur, West Bengal (22.4207, 87.3270)... ✓ Roads:3236 | Industrial:3 | Dumps:0 | Agriculture:25
#   Querying Purulia, West Bengal (23.2021, 86.3229)... ✓ Roads:55 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 78/109:
# Processing locations 386 to 390
#
#   Querying Raigunj, West Bengal (25.6167, 88.1167)... ✓ Roads:2130 | Industrial:1 | Dumps:0 | Agriculture:1
# ...
#   Querying Tirupur, Tamilnadu (11.1672, 77.3473)... ✓ Roads:4550 | Industrial:9 | Dumps:0 | Agriculture:0
#   Querying Tuticorin, Tamilnadu (8.8053, 78.1453)... ✓ Roads:3592 | Industrial:11 | Dumps:0 | Agriculture:2
#   Querying Vellore, Tamilnadu (12.9022, 79.0611)... ✓ Roads:1170 | Industrial:1 | Dumps:0 | Agriculture:15
#   Querying Hyderabad, Telangana (17.3606, 78.4741)... ✓ Roads:23455 | Industrial:8 | Dumps:1 | Agriculture:39
#
# Batch completed. Waiting before next batch...
#
# Batch 92/109:
# Processing locations 456 to 460
#
#   Querying Baghpat, Uttar Pradesh (29.0375, 77.3063)... ✓ Roads:277 | Industrial:0 | Dumps:0 | Agriculture:3
#   Querying Bareilly, Uttar Pradesh (28.4582, 79.4047)... ✓ Roads:855 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Hatras, Uttar Pradesh (27.5958, 78.0524)... ✓ Roads:2877 | Industrial:4 | Dumps:0 | Agriculture:0
#   Querying Vrindavan, Uttar Pradesh (27.5754, 77.6938)... ✓ Roads:2763 | Industrial:7 | Dumps:0 | Agriculture:1
#   Querying Asansol+Raniganj, West Bengal (23.6739, 86.9524)... ✓ Roads:4886 | Industrial:3 | Dumps:0 | Agriculture:2
#
# Batch completed. Waiting before next batch...
#
# Batch 93/109:
# Processing locations 461 to 465
#
#   Querying Barrckpore, West Bengal (22.7665, 88.3709)... ✓ Roads:12995 | Industrial:166 | Dumps:0 | Agriculture:15
#   Querying Birpara, West Bengal (26.7113, 89.1390)... ✓ Roads:182 | Industrial:21 | Dumps:0 | Agriculture:6
#   Querying Jaigaon, West Bengal (26.8549, 89.3767)... ✓ Roads:924 | Industrial:2 | Dumps:0 | Agriculture:4
#   Querying Makhrapara /Alipurduar, West Bengal (26.3133, 89.4871)... ✓ Roads:1069 | Industrial:27 | Dumps:0 | Agriculture:5
#   Querying Uttarpara, West Bengal (22.6670, 88.3411)... ✓ Roads:11184 | Industrial:24 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 94/109:
# Processing locations 466 to 470
#
#   Querying Port Blair, Andaman & Nicobar (UT) (11.6234, 92.7265)... ✓ Roads:1705 | Industrial:0 | Dumps:0 | Agriculture:8
#   Querying Anantapur, Andhra Pradesh (14.7242, 77.4307)... ✓ Roads:350 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Chittoor, Andhra Pradesh (13.2026, 79.0032)... ✓ Roads:287 | Industrial:3 | Dumps:0 | Agriculture:6
#   Querying Rajahmundry/ Rajamahendravaram, Andhra Pradesh (16.9966, 81.7726)... ✓ Roads:5039 | Industrial:9 | Dumps:0 | Agriculture:3
#   Querying Silcher, Assam (24.8330, 92.7789)... ✓ Roads:0 | Industrial:8 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 95/109:
# Processing locations 471 to 475
#
#   Querying Chhal, Chattisgarh (22.0966, 83.1119)... ✓ Roads:16 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Kunjemura, Chattisgarh (21.9587, 83.6635)... ✓ Roads:2 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Milupara, Chattisgarh (21.9041, 83.6582)... ✓ Roads:10 | Industrial:0 | Dumps:0 | Agriculture:2
#   Querying Tumidh, Chattisgarh (21.7612, 83.4108)... ✓ Roads:626 | Industrial:5 | Dumps:0 | Agriculture:0
#   Querying Sonipat, Haryana (28.9954, 77.0234)... ✓ Roads:6062 | Industrial:5 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 96/109:
# Processing locations 476 to 480
#
#   Querying Vashisht, Himachal Pradesh (32.2669, 77.1876)... ✓ Roads:1160 | Industrial:0 | Dumps:0 | Agriculture:5
#   Querying Ramban (J), Jammu & Kashmir (UT) (33.2346, 75.2376)... ✓ Roads:83 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Ahmednagar, Maharashtra (19.1628, 74.8580)... ✓ Roads:62 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Amravati, Maharashtra (20.9320, 77.7523)... ✓ Roads:8176 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Aurangabad, Maharashtra (19.8758, 75.3393)... ✓ Roads:12631 | Industrial:35 | Dumps:0 | Agriculture:11
#
# Batch completed. Waiting before next batch...
#
#  ✓ Roads:2310 | Industrial:16 | Dumps:0 | Agriculture:1
#   Querying Belapur, Maharashtra (19.0222, 73.0390)... ✓ Roads:6434 | Industrial:42 | Dumps:0 | Agriculture:199
#   Querying Bhiwandi, Maharashtra (19.2967, 73.0631)... ✓ Roads:3184 | Industrial:44 | Dumps:0 | Agriculture:5
#   Querying Boisar, Maharashtra (19.8036, 72.7559)... ✓ Roads:688 | Industrial:5 | Dumps:0 | Agriculture:0
#   Querying Chandrapur, Maharashtra (19.9500, 79.3000)... ✓ Roads:4060 | Industrial:5 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 98/109:
# Processing locations 486 to 490
#
#   Querying Dhule, Maharashtra (20.9013, 74.7774)... ✓ Roads:5722 | Industrial:4 | Dumps:0 | Agriculture:3
#   Querying Dombivali / Kalyan, Maharashtra (19.2183, 73.0864)... ✓ Roads:5106 | Industrial:37 | Dumps:0 | Agriculture:12
#   Querying Jalgaon, Maharashtra (21.0107, 75.5684)... ✓ Roads:4220 | Industrial:2 | Dumps:0 | Agriculture:3
#   Querying Jalna, Maharashtra (19.8410, 75.8866)... ✓ Roads:3313 | Industrial:10 | Dumps:0 | Agriculture:17
#   Querying Kolhapur, Maharashtra (16.7050, 74.2433)... ✓ Roads:6990 | Industrial:17 | Dumps:0 | Agriculture:10
#
# Batch completed. Waiting before next batch...
#
# Batch 99/109:
# Processing locations 491 to 495
#
#   Querying Latur, Maharashtra (18.4000, 76.5833)... ✓ Roads:6447 | Industrial:4 | Dumps:0 | Agriculture:45
#   Querying Mahad, Maharashtra (18.0833, 73.4167)... ✓ Roads:179 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Malegao, Maharashtra (20.5537, 74.5288)... ✓ Roads:4651 | Industrial:4 | Dumps:0 | Agriculture:8
#   Querying Mira Bhayander, Maharashtra (19.2952, 72.8544)... ✓ Roads:3425 | Industrial:50 | Dumps:1 | Agriculture:79
#   Querying Mumbai, Maharashtra (19.0760, 72.8777)... ✓ Roads:13581 | Industrial:117 | Dumps:2 | Agriculture:169
#
# Batch completed. Waiting before next batch...
#
# Batch 100/109:
# Processing locations 496 to 500
#
#   Querying Nagpur, Maharashtra (21.1458, 79.0882)... ✓ Roads:14648 | Industrial:23 | Dumps:0 | Agriculture:35
#   Querying Nanded, Maharashtra (19.1383, 77.3210)... ✓ Roads:5123 | Industrial:16 | Dumps:0 | Agriculture:1
#   Querying Nashik, Maharashtra (19.9975, 73.7898)... ✓ Roads:9062 | Industrial:9 | Dumps:0 | Agriculture:63
#   Querying Navi Mumbai, Maharashtra (19.0330, 73.0297)... ✓ Roads:6901 | Industrial:51 | Dumps:0 | Agriculture:158
#   Querying Parbhani, Maharashtra (19.2700, 76.7600)... ✓ Roads:3638 | Industrial:1 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 101/109:
# Processing locations 501 to 505
#
#   Querying Pimpri Chinchwad, Maharashtra (18.6279, 73.8007)... ✓ Roads:14515 | Industrial:31 | Dumps:5 | Agriculture:28
#   Querying Pune, Maharashtra (18.5204, 73.8567)... ✓ Roads:18059 | Industrial:19 | Dumps:1 | Agriculture:132
#   Querying Roha, Maharashtra (18.4408, 73.1190)... ✓ Roads:138 | Industrial:4 | Dumps:0 | Agriculture:1
#   Querying Sangli, Maharashtra (16.8524, 74.5815)... ✓ Roads:0 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Solapur, Maharashtra (17.6599, 75.9064)... ✓ Roads:0 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 102/109:
# Processing locations 506 to 510
#
#   Querying Tarapur, Maharashtra (19.8667, 72.7000)... ✓ Roads:283 | Industrial:1 | Dumps:0 | Agriculture:2
#   Querying Thane, Maharashtra (19.2183, 72.9781)... ✓ Roads:8273 | Industrial:69 | Dumps:0 | Agriculture:179
#   Querying Ulhas Nagar, Maharashtra (19.2167, 73.1500)... ✓ Roads:0 | Industrial:39 | Dumps:0 | Agriculture:9
#   Querying Vasai virar, Maharashtra (19.3850, 72.8295)... ✓ Roads:0 | Industrial:14 | Dumps:0 | Agriculture:2
#   Querying Imphal, Manipur (24.8170, 93.9368)... ✓ Roads:4182 | Industrial:3 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 103/109:
# Processing locations 511 to 515
#
#   Querying Dawki, Meghalaya (25.2029, 92.0344)... ✓ Roads:394 | Industrial:5 | Dumps:0 | Agriculture:0
#   Querying Nongstoin, Meghalaya (25.5170, 91.2666)... ✓ Roads:165 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Shillong, Meghalaya (25.5788, 91.8933)... ✓ Roads:4812 | Industrial:2 | Dumps:0 | Agriculture:66
#   Querying Tura, Meghalaya (25.5142, 90.2026)... ✓ Roads:52 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Umsning, Meghalaya (25.8227, 91.8694)... ✓ Roads:4 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 104/109:
# Processing locations 516 to 520
#
#   Querying Aizwal, Mizoram (23.7271, 92.7176)... ✓ Roads:1656 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Champhai, Mizoram (23.4560, 93.3291)... ✓ Roads:392 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Kolasib, Mizoram (24.2240, 92.6787)... ✓ Roads:95 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Lawngtlai, Mizoram (22.5411, 92.8926)... ✓ Roads:191 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Lunglei, Mizoram (22.8660, 92.7330)... ✓ Roads:333 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 105/109:
# Processing locations 521 to 525
#
#   Querying Mamit, Mizoram (23.9292, 92.4900)... ✓ Roads:59 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Siaha, Mizoram (22.4837, 92.9745)... ✓ Roads:328 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Serchhip, Mizoram (23.2980, 92.8460)... ✓ Roads:140 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Dimapur, Nagaland (25.9091, 93.7260)... ✓ Roads:3672 | Industrial:6 | Dumps:0 | Agriculture:0
#   Querying Kohima, Nagaland (25.6747, 94.1100)... ✓ Roads:785 | Industrial:1 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 106/109:
# Processing locations 526 to 530
#
#   Querying Angul, Odisha (20.8410, 85.0970)... ✓ Roads:353 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Balasore, Odisha (21.4942, 86.9316)... ✓ Roads:971 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Baripada, Odisha (21.9407, 86.7198)... ✓ Roads:729 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Bhubaneshwar, Odisha (20.2961, 85.8245)... ✓ Roads:8823 | Industrial:6 | Dumps:1 | Agriculture:17
#   Querying Bileipada, Odisha (22.0900, 85.3300)... ✓ Roads:265 | Industrial:13 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 107/109:
# Processing locations 531 to 535
#
#   Querying Brajrajnagar, Odisha (21.8200, 83.9200)... ✓ Roads:184 | Industrial:5 | Dumps:0 | Agriculture:0
#   Querying Cuttack, Odisha (20.4625, 85.8828)... ✓ Roads:3169 | Industrial:3 | Dumps:0 | Agriculture:4
#   Querying Jharsuguda, Odisha (21.8553, 84.0060)... ✓ Roads:627 | Industrial:9 | Dumps:0 | Agriculture:0
#   Querying Keonjhar, Odisha (21.6333, 85.5833)... ✓ Roads:254 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Konark, Odisha (19.8974, 86.1140)... ✓ Roads:527 | Industrial:0 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 108/109:
# Processing locations 536 to 540
#
#   Querying Nayagarh, Odisha (20.1280, 85.0961)... ✓ Roads:440 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Paradeep, Odisha (20.3167, 86.6167)... ✓ Roads:520 | Industrial:14 | Dumps:0 | Agriculture:8
#   Querying Puri, Odisha (19.8135, 85.8312)... ✓ Roads:2536 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Rairangpur, Odisha (22.2780, 86.1847)... ✓ Roads:127 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Rourkela, Odisha (22.2604, 84.8536)... ✓ Roads:3406 | Industrial:8 | Dumps:0 | Agriculture:5
#
# Batch completed. Waiting before next batch...
#
# Batch 109/109:
# Processing locations 541 to 544
#
#   Querying Sambalpur, Odisha (21.4700, 83.9701)... ✓ Roads:3664 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Suakati, Odisha (21.6367, 85.5775)... ✓ Roads:247 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Talcher, Odisha (20.9483, 85.2332)... ✓ Roads:152 | Industrial:3 | Dumps:0 | Agriculture:0
#   Querying Tensa, Odisha (21.8728, 85.1713)... ✓ Roads:85 | Industrial:1 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
#
# ================================================================================
# EXTRACTION SUMMARY
# ================================================================================
#
# Total locations processed: 544
# Successful queries: 544/544
#
#                                Feature Statistics
# --------------------------------------------------------------------------------
# Feature              Total        Mean         Max
# --------------------------------------------------------------------------------
# Roads                1909545      3510.2       35892
# Industrial           5754         10.6         188
# Dump Sites           275          0.5          142
# Agriculture          11654        21.4         2723
# --------------------------------------------------------------------------------
#
# Merging extracted features with original air quality data...
#
# Saving merged data to Air_Quality_with_OSM_Features_5KM.xlsx...
# ✓ Successfully saved to Air_Quality_with_OSM_Features_5KM.xlsx
#
#                       Sample Results (First 15 locations):
#    City / town / village State / Union Territory  Roads_count  \
# 0              Amaravati          Andhra Pradesh         2332
# 1               Anatapur          Andhra Pradesh         5915
# 2                Chittor          Andhra Pradesh         1986
# 3                  Eluru          Andhra Pradesh         4515
# 4                 Guntur          Andhra Pradesh         7442
# 5                 Kadapa          Andhra Pradesh         3546
# 6               Kakinada          Andhra Pradesh         4702
# 7                Kurnool          Andhra Pradesh         4566
# 8                Nellore          Andhra Pradesh         5208
# 9                 Ongole          Andhra Pradesh         3448
# 10           Rajahmundry          Andhra Pradesh         4724
# 11            Srikakulam          Andhra Pradesh         2642
# 12              Tirupati          Andhra Pradesh         6026
# 13            Vijayawada          Andhra Pradesh         8423
# 14         Visakhapatnam          Andhra Pradesh         5988
#
#     Industrial_zones_count  Dump_sites_count  Agricultural_fields_count  \
# 0                        0                 0                         89
# 1                        3                 0                          2
# 2                        4                 0                          9
# 3                        2                 0                          1
# 4                        4                 0                         37
# 5                        5                 0                          0
# 6                       12                 0                          1
# 7                       13                 0                         13
# 8                        6                 0                          8
# 9                        1                 0                          0
# 10                       7                 0                          4
# 11                       5                 0                         28
# 12                       3                 0                         33
# 13                      14                 0                         77
# 14                      45                 0                         30
#
#     Pollution_source_risk  Green_area_ratio
# 0                    7.00              0.04
# 1                   17.76              0.00
# 2                    5.97              0.00
# 3                   13.55              0.00
# 4                   22.34              0.00
# 5                   10.66              0.00
# 6                   14.15              0.00
# 7                   13.75              0.00
# 8                   15.65              0.00
# 9                   10.35              0.00
# 10                  14.20              0.00
# 11                   7.95              0.01
# 12                  18.09              0.01
# 13                  25.32              0.01
# 14                  18.14              0.00
#
# ================================================================================
# ✓ Processing Complete!
# ================================================================================

# %%
import pandas as pd
import geopandas as gpd
import osmnx as ox
from shapely.geometry import Point
import time

SEARCH_RADIUS = 5000  # 5 km
INPUT_FILE = "Air_Quality_with_OSM_Features_5KM.xlsx"  # your merged file [file:2]

# 1) Load main data and unique points
df = pd.read_excel(INPUT_FILE, sheet_name="All Data")
unique_locs = df[["Latitude", "Longitude"]].drop_duplicates().reset_index(drop=True)  # [file:2]

# 2) Empty GeoDataFrames for each feature type (WGS84)
roads_gdf   = gpd.GeoDataFrame(columns=["osm_id", "geometry"], crs="EPSG:4326")
inds_gdf    = gpd.GeoDataFrame(columns=["osm_id", "geometry"], crs="EPSG:4326")
dumps_gdf   = gpd.GeoDataFrame(columns=["osm_id", "geometry"], crs="EPSG:4326")

def append_features(gdf_base, features):
    """Append unique geometries from an OSMnx features GeoDataFrame into gdf_base."""
    if features is None or features.empty:
        return gdf_base
    tmp = features.reset_index()
    osm_ids = tmp["osmid"] if "osmid" in tmp.columns else tmp[tmp.columns[0]]
    out = gpd.GeoDataFrame(
        {
            "osm_id": osm_ids,
            "geometry": tmp["geometry"]
        },
        crs=features.crs
    )
    # drop duplicates by osm_id to avoid many repeats from overlapping buffers
    out = out.drop_duplicates(subset="osm_id")
    return pd.concat([gdf_base, out], ignore_index=True)

for i, row in unique_locs.iterrows():
    lat, lon = row["Latitude"], row["Longitude"]
    print(f"{i+1}/{len(unique_locs)}: ({lat:.4f}, {lon:.4f})")

    # Roads
    try:
        roads = ox.features_from_point((lat, lon), tags={"highway": True}, dist=SEARCH_RADIUS)
        roads_gdf = append_features(roads_gdf, roads)
    except Exception as e:
        print("  Roads error:", e)

    # Industrial zones
    try:
        ind = ox.features_from_point((lat, lon), tags={"industrial": True, "landuse": "industrial"}, dist=SEARCH_RADIUS)
        inds_gdf = append_features(inds_gdf, ind)
    except Exception as e:
        print("  Industrial error:", e)

    # Dumps/waste
    try:
        dumps = ox.features_from_point((lat, lon), tags={"waste": True}, dist=SEARCH_RADIUS)
        dumps_gdf = append_features(dumps_gdf, dumps)
    except Exception as e:
        print("  Dumps error:", e)

    time.sleep(0.5)

# 3) Drop remaining duplicate geometries by osm_id once
roads_gdf = roads_gdf.drop_duplicates(subset="osm_id").reset_index(drop=True)
inds_gdf  = inds_gdf.drop_duplicates(subset="osm_id").reset_index(drop=True)
dumps_gdf = dumps_gdf.drop_duplicates(subset="osm_id").reset_index(drop=True)

# 4) Reproject to metric CRS (EPSG:3857) for distance calculations
roads_gdf_m = roads_gdf.to_crs(3857)
inds_gdf_m  = inds_gdf.to_crs(3857)
dumps_gdf_m = dumps_gdf.to_crs(3857)

# 5) Save to disk for reuse
roads_gdf_m.to_file("osm_roads_5km.gpkg", layer="roads", driver="GPKG")
inds_gdf_m.to_file("osm_industries_5km.gpkg", layer="industries", driver="GPKG")
dumps_gdf_m.to_file("osm_dumps_5km.gpkg", layer="dumps", driver="GPKG")
# Out:
# 1/544: (16.4942, 80.5106)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 2/544: (14.6824, 77.6017)
#   Dumps error: No matching features. Check query location, tags, and log.
# 3/544: (13.2162, 79.1051)
#   Dumps error: No matching features. Check query location, tags, and log.
# 4/544: (16.7104, 81.1154)
#   Dumps error: No matching features. Check query location, tags, and log.
# 5/544: (16.2915, 80.4542)
#   Dumps error: No matching features. Check query location, tags, and log.
# 6/544: (14.4753, 78.8217)
#   Dumps error: No matching features. Check query location, tags, and log.
# 7/544: (16.9437, 82.2351)
#   Dumps error: No matching features. Check query location, tags, and log.
# 8/544: (15.8309, 78.0425)
#   Dumps error: No matching features. Check query location, tags, and log.
# 9/544: (14.4494, 79.9874)
#   Dumps error: No matching features. Check query location, tags, and log.
# 10/544: (15.5059, 80.0499)
#   Dumps error: No matching features. Check query location, tags, and log.
# 11/544: (17.0050, 81.7805)
#   Dumps error: No matching features. Check query location, tags, and log.
# 12/544: (18.2949, 83.8939)
#   Dumps error: No matching features. Check query location, tags, and log.
# 13/544: (13.6316, 79.4232)
#   Dumps error: No matching features. Check query location, tags, and log.
# 14/544: (16.5115, 80.6160)
#   Dumps error: No matching features. Check query location, tags, and log.
# 15/544: (17.6936, 83.2921)
#   Dumps error: No matching features. Check query location, tags, and log.
# 16/544: (18.1141, 83.4114)
#   Dumps error: No matching features. Check query location, tags, and log.
# 17/544: (27.0980, 93.6237)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 18/544: (27.1309, 93.7097)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 19/544: (26.4800, 90.5580)
#   Dumps error: No matching features. Check query location, tags, and log.
# 20/544: (26.7851, 91.5145)
#   Dumps error: No matching features. Check query location, tags, and log.
# 21/544: (27.4845, 94.9019)
#   Dumps error: No matching features. Check query location, tags, and log.
# 22/544: (26.5108, 93.9744)
#   Dumps error: No matching features. Check query location, tags, and log.
# 23/544: (26.1806, 91.7539)
#   Dumps error: No matching features. Check query location, tags, and log.
# 24/544: (27.2864, 95.6702)
#   Dumps error: No matching features. Check query location, tags, and log.
# 25/544: (26.3314, 92.7525)
#   Dumps error: No matching features. Check query location, tags, and log.
# 26/544: (26.3534, 91.3984)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 27/544: (27.2544, 94.1120)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 28/544: (24.8333, 92.7789)
#   Dumps error: No matching features. Check query location, tags, and log.
# 29/544: (26.9835, 94.6394)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 30/544: (26.6170, 92.7650)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 31/544: (27.4880, 95.3602)
#   Dumps error: No matching features. Check query location, tags, and log.
# 32/544: (24.6794, 85.0116)
#   Dumps error: No matching features. Check query location, tags, and log.
# 33/544: (25.6906, 85.2090)
#   Dumps error: No matching features. Check query location, tags, and log.
# 34/544: (26.1483, 85.3316)
#   Dumps error: No matching features. Check query location, tags, and log.
# 35/544: (25.6093, 85.1235)
#   Dumps error: No matching features. Check query location, tags, and log.
# 36/544: (30.7333, 76.7794)
# 37/544: (22.1638, 82.1366)
#   Dumps error: No matching features. Check query location, tags, and log.
# 38/544: (21.1888, 81.2849)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 39/544: (22.5198, 82.6350)
#   Dumps error: No matching features. Check query location, tags, and log.
# 40/544: (22.2362, 83.3530)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 41/544: (21.2381, 81.6337)
#   Dumps error: No matching features. Check query location, tags, and log.
# 42/544: (20.4283, 72.8397)
#   Dumps error: No matching features. Check query location, tags, and log.
# 43/544: (28.6139, 77.2090)
# 44/544: (15.5354, 73.9838)
#   Dumps error: No matching features. Check query location, tags, and log.
# 45/544: (15.5891, 73.8103)
# 46/544: (15.5558, 73.9773)
#   Dumps error: No matching features. Check query location, tags, and log.
# 47/544: (15.3567, 74.1238)
#   Dumps error: No matching features. Check query location, tags, and log.
# 48/544: (15.1801, 73.9979)
#   Dumps error: No matching features. Check query location, tags, and log.
# 49/544: (15.5431, 74.0586)
#   Dumps error: No matching features. Check query location, tags, and log.
# 50/544: (15.4597, 73.9613)
#   Dumps error: No matching features. Check query location, tags, and log.
# 51/544: (15.5909, 73.8102)
# 52/544: (15.2729, 73.9583)
#   Dumps error: No matching features. Check query location, tags, and log.
# 53/544: (15.4990, 73.8282)
# 54/544: (15.3979, 74.0080)
#   Dumps error: No matching features. Check query location, tags, and log.
# 55/544: (15.2283, 74.1513)
#   Dumps error: No matching features. Check query location, tags, and log.
# 56/544: (15.2806, 74.0943)
#   Dumps error: No matching features. Check query location, tags, and log.
# 57/544: (15.6666, 73.7957)
#   Dumps error: No matching features. Check query location, tags, and log.
# 58/544: (15.4892, 74.0703)
#   Dumps error: No matching features. Check query location, tags, and log.
# 59/544: (15.3984, 73.8129)
#   Dumps error: No matching features. Check query location, tags, and log.
# 60/544: (23.0215, 72.5801)
#   Dumps error: No matching features. Check query location, tags, and log.
# 61/544: (21.6293, 72.9945)
#   Dumps error: No matching features. Check query location, tags, and log.
# 62/544: (23.2233, 72.6492)
# 63/544: (22.4732, 70.0552)
#   Dumps error: No matching features. Check query location, tags, and log.
# 64/544: (22.4178, 73.0949)
#   Dumps error: No matching features. Check query location, tags, and log.
# 65/544: (19.2310, 82.5482)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 66/544: (22.3053, 70.8028)
#   Dumps error: No matching features. Check query location, tags, and log.
# 67/544: (21.2095, 72.8317)
#   Dumps error: No matching features. Check query location, tags, and log.
# 68/544: (23.0475, 72.6036)
#   Dumps error: No matching features. Check query location, tags, and log.
# 69/544: (22.2973, 73.1943)
#   Dumps error: No matching features. Check query location, tags, and log.
# 70/544: (20.3735, 72.9084)
#   Dumps error: No matching features. Check query location, tags, and log.
# 71/544: (22.9590, 72.6298)
#   Dumps error: No matching features. Check query location, tags, and log.
# 72/544: (30.3844, 76.7704)
#   Dumps error: No matching features. Check query location, tags, and log.
# 73/544: (28.6610, 76.8347)
#   Dumps error: No matching features. Check query location, tags, and log.
# 74/544: (28.2941, 77.3592)
#   Dumps error: No matching features. Check query location, tags, and log.
# 75/544: (28.7932, 76.1391)
#   Dumps error: No matching features. Check query location, tags, and log.
# 76/544: (28.5920, 76.2720)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 77/544: (28.2055, 76.7953)
#   Dumps error: No matching features. Check query location, tags, and log.
# 78/544: (28.4031, 77.3106)
#   Dumps error: No matching features. Check query location, tags, and log.
# 79/544: (29.5359, 75.5753)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 80/544: (28.4646, 77.0299)
#   Dumps error: No matching features. Check query location, tags, and log.
# 81/544: (29.8292, 76.4723)
#   Dumps error: No matching features. Check query location, tags, and log.
# 82/544: (29.3152, 76.3141)
#   Dumps error: No matching features. Check query location, tags, and log.
# 83/544: (29.7997, 76.3990)
#   Dumps error: No matching features. Check query location, tags, and log.
# 84/544: (29.7256, 76.9107)
#   Dumps error: No matching features. Check query location, tags, and log.
# 85/544: (29.9694, 76.8483)
#   Dumps error: No matching features. Check query location, tags, and log.
# 86/544: (27.8971, 76.9922)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 87/544: (28.3247, 76.9264)
#   Dumps error: No matching features. Check query location, tags, and log.
# 88/544: (28.0438, 76.1062)
#   Dumps error: No matching features. Check query location, tags, and log.
# 89/544: (28.0599, 77.3223)
#   Dumps error: No matching features. Check query location, tags, and log.
# 90/544: (30.6942, 76.8606)
#   Dumps error: No matching features. Check query location, tags, and log.
# 91/544: (29.3913, 76.9772)
#   Dumps error: No matching features. Check query location, tags, and log.
# 92/544: (28.9011, 76.5802)
#   Dumps error: No matching features. Check query location, tags, and log.
# 93/544: (29.6063, 74.9037)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 94/544: (28.9920, 77.0343)
#   Dumps error: No matching features. Check query location, tags, and log.
# 95/544: (30.1389, 77.3011)
#   Dumps error: No matching features. Check query location, tags, and log.
# 96/544: (30.9763, 76.7674)
#   Dumps error: No matching features. Check query location, tags, and log.
# 97/544: (32.2539, 75.6722)
#   Dumps error: No matching features. Check query location, tags, and log.
# 98/544: (32.2143, 76.3197)
# 99/544: (32.0131, 76.6688)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 100/544: (32.2455, 77.1873)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 101/544: (31.1060, 76.6567)
#   Dumps error: No matching features. Check query location, tags, and log.
# 102/544: (30.8379, 76.9602)
#   Dumps error: No matching features. Check query location, tags, and log.
# 103/544: (30.4366, 77.6247)
#   Dumps error: No matching features. Check query location, tags, and log.
# 104/544: (31.1042, 77.1710)
#   Dumps error: No matching features. Check query location, tags, and log.
# 105/544: (31.5163, 76.8840)
#   Dumps error: No matching features. Check query location, tags, and log.
# 106/544: (31.5835, 76.2351)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 107/544: (33.7782, 76.5762)
#   Roads error: No matching features. Check query location, tags, and log.
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 108/544: (33.8747, 74.8998)
#   Dumps error: No matching features. Check query location, tags, and log.
# 109/544: (34.0837, 74.7973)
#   Dumps error: No matching features. Check query location, tags, and log.
# 110/544: (22.1641, 85.4078)
#   Dumps error: No matching features. Check query location, tags, and log.
# 111/544: (23.7953, 86.4310)
#   Dumps error: No matching features. Check query location, tags, and log.
# 112/544: (22.8015, 86.2030)
#   Dumps error: No matching features. Check query location, tags, and log.
# 113/544: (23.7408, 86.4146)
#   Dumps error: No matching features. Check query location, tags, and log.
# 114/544: (23.7167, 86.4110)
#   Dumps error: No matching features. Check query location, tags, and log.
# 115/544: (23.3701, 85.3250)
#   Dumps error: No matching features. Check query location, tags, and log.
# 116/544: (22.7464, 85.9169)
#   Dumps error: No matching features. Check query location, tags, and log.
# 117/544: (23.6752, 86.4896)
#   Dumps error: No matching features. Check query location, tags, and log.
# 118/544: (16.2904, 75.5916)
#   Dumps error: No matching features. Check query location, tags, and log.
# 119/544: (12.9768, 77.5901)
# 120/544: (15.8573, 74.5069)
#   Dumps error: No matching features. Check query location, tags, and log.
# 121/544: (18.0207, 77.2487)
#   Dumps error: No matching features. Check query location, tags, and log.
# 122/544: (16.8333, 75.7176)
#   Dumps error: No matching features. Check query location, tags, and log.
# 123/544: (11.9544, 77.1069)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 124/544: (13.0994, 77.3887)
#   Dumps error: No matching features. Check query location, tags, and log.
# 125/544: (13.4059, 75.6388)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 126/544: (14.3049, 76.5297)
#   Dumps error: No matching features. Check query location, tags, and log.
# 127/544: (14.4644, 75.9218)
#   Dumps error: No matching features. Check query location, tags, and log.
# 128/544: (15.4167, 75.6816)
#   Dumps error: No matching features. Check query location, tags, and log.
# 129/544: (17.3297, 76.8343)
#   Dumps error: No matching features. Check query location, tags, and log.
# 130/544: (13.0302, 76.1745)
#   Dumps error: No matching features. Check query location, tags, and log.
# 131/544: (15.3428, 75.1695)
#   Dumps error: No matching features. Check query location, tags, and log.
# 132/544: (13.1805, 78.2669)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 133/544: (15.5748, 76.3118)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 134/544: (12.4215, 75.7388)
#   Dumps error: No matching features. Check query location, tags, and log.
# 135/544: (12.6369, 76.7275)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 136/544: (12.8698, 74.8430)
#   Dumps error: No matching features. Check query location, tags, and log.
# 137/544: (12.3052, 76.6554)
#   Dumps error: No matching features. Check query location, tags, and log.
# 138/544: (16.0547, 76.9004)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 139/544: (12.7200, 77.3184)
#   Dumps error: No matching features. Check query location, tags, and log.
# 140/544: (13.9299, 75.5681)
#   Dumps error: No matching features. Check query location, tags, and log.
# 141/544: (13.3422, 77.1010)
#   Dumps error: No matching features. Check query location, tags, and log.
# 142/544: (13.5270, 74.8732)
#   Dumps error: No matching features. Check query location, tags, and log.
# 143/544: (16.5744, 76.9254)
#   Dumps error: No matching features. Check query location, tags, and log.
# 144/544: (9.5007, 76.4124)
#   Dumps error: No matching features. Check query location, tags, and log.
# 145/544: (10.0670, 76.2989)
#   Dumps error: No matching features. Check query location, tags, and log.
# 146/544: (9.9837, 76.2740)
# 147/544: (11.8764, 75.3738)
#   Dumps error: No matching features. Check query location, tags, and log.
# 148/544: (9.9679, 76.2444)
# 149/544: (8.8871, 76.5907)
#   Dumps error: No matching features. Check query location, tags, and log.
# 150/544: (9.6287, 76.6455)
#   Dumps error: No matching features. Check query location, tags, and log.
# 151/544: (11.2451, 75.7755)
#   Dumps error: No matching features. Check query location, tags, and log.
# 152/544: (11.0730, 76.0740)
#   Dumps error: No matching features. Check query location, tags, and log.
# 153/544: (10.7874, 76.4742)
#   Dumps error: No matching features. Check query location, tags, and log.
# 154/544: (9.2781, 76.9737)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 155/544: (8.5441, 76.9366)
# 156/544: (10.5270, 76.2146)
#   Dumps error: No matching features. Check query location, tags, and log.
# 157/544: (11.7151, 76.1271)
#   Dumps error: No matching features. Check query location, tags, and log.
# 158/544: (23.1733, 81.5917)
#   Dumps error: No matching features. Check query location, tags, and log.
# 159/544: (23.2585, 77.4020)
#   Dumps error: No matching features. Check query location, tags, and log.
# 160/544: (22.0004, 78.8972)
#   Dumps error: No matching features. Check query location, tags, and log.
# 161/544: (23.7981, 79.5419)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 162/544: (22.8057, 76.2940)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 163/544: (26.2037, 78.1574)
#   Dumps error: No matching features. Check query location, tags, and log.
# 164/544: (22.7204, 75.8682)
# 165/544: (23.1702, 79.9325)
#   Dumps error: No matching features. Check query location, tags, and log.
# 166/544: (23.7176, 80.2610)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 167/544: (24.2604, 80.7593)
#   Dumps error: No matching features. Check query location, tags, and log.
# 168/544: (23.0938, 77.5114)
#   Dumps error: No matching features. Check query location, tags, and log.
# 169/544: (23.4579, 75.4191)
#   Dumps error: No matching features. Check query location, tags, and log.
# 170/544: (22.6106, 75.6790)
#   Dumps error: No matching features. Check query location, tags, and log.
# 171/544: (23.5022, 74.9552)
#   Dumps error: No matching features. Check query location, tags, and log.
# 172/544: (24.7561, 81.3811)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 173/544: (23.8083, 78.7583)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 174/544: (24.6954, 80.7770)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 175/544: (24.2431, 82.3828)
#   Dumps error: No matching features. Check query location, tags, and log.
# 176/544: (23.1885, 75.7717)
#   Dumps error: No matching features. Check query location, tags, and log.
# 177/544: (20.7618, 77.1921)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 178/544: (19.2016, 73.2005)
#   Dumps error: No matching features. Check query location, tags, and log.
# 179/544: (21.1545, 77.6443)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 180/544: (19.8773, 75.3390)
#   Dumps error: No matching features. Check query location, tags, and log.
# 181/544: (19.1666, 73.2389)
#   Dumps error: No matching features. Check query location, tags, and log.
# 182/544: (19.3026, 73.0588)
#   Dumps error: No matching features. Check query location, tags, and log.
# 183/544: (20.0968, 79.5045)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 184/544: (19.2569, 73.1329)
#   Dumps error: No matching features. Check query location, tags, and log.
# 185/544: (20.8429, 75.5261)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 186/544: (19.9188, 75.8709)
#   Dumps error: No matching features. Check query location, tags, and log.
# 187/544: (16.7028, 74.2405)
#   Dumps error: No matching features. Check query location, tags, and log.
# 188/544: (18.3553, 76.7549)
#   Dumps error: No matching features. Check query location, tags, and log.
# 189/544: (19.0550, 72.8692)
# 190/544: (21.1498, 79.0821)
#   Dumps error: No matching features. Check query location, tags, and log.
# 191/544: (19.0940, 77.4832)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 192/544: (20.0112, 73.7902)
#   Dumps error: No matching features. Check query location, tags, and log.
# 193/544: (19.0308, 73.0199)
#   Dumps error: No matching features. Check query location, tags, and log.
# 194/544: (18.6279, 73.8010)
# 195/544: (18.5214, 73.8545)
# 196/544: (18.4466, 73.1239)
#   Dumps error: No matching features. Check query location, tags, and log.
# 197/544: (17.1727, 74.5868)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 198/544: (17.8499, 75.2763)
#   Dumps error: No matching features. Check query location, tags, and log.
# 199/544: (19.1943, 72.9702)
#   Dumps error: No matching features. Check query location, tags, and log.
# 200/544: (19.0642, 72.8848)
# 201/544: (19.4210, 72.8197)
#   Dumps error: No matching features. Check query location, tags, and log.
# 202/544: (24.7991, 93.9364)
#   Dumps error: No matching features. Check query location, tags, and log.
# 203/544: (25.9045, 91.8695)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 204/544: (25.1856, 92.0216)
#   Dumps error: No matching features. Check query location, tags, and log.
# 205/544: (25.3570, 92.3534)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 206/544: (25.5726, 91.2541)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 207/544: (25.5760, 91.8828)
#   Dumps error: No matching features. Check query location, tags, and log.
# 208/544: (25.5126, 90.2172)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 209/544: (25.6710, 91.8991)
#   Dumps error: No matching features. Check query location, tags, and log.
# 210/544: (23.8389, 92.6243)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 211/544: (23.6317, 93.3493)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 212/544: (23.7191, 92.7142)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 213/544: (24.2313, 92.6766)
#   Dumps error: No matching features. Check query location, tags, and log.
# 214/544: (22.3913, 92.7397)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 215/544: (22.9520, 92.6339)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 216/544: (23.8407, 92.6211)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 217/544: (23.7564, 92.4515)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 218/544: (22.4880, 92.9813)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 219/544: (23.3053, 92.8455)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 220/544: (25.9041, 93.7178)
#   Dumps error: No matching features. Check query location, tags, and log.
# 221/544: (25.6619, 94.1019)
#   Dumps error: No matching features. Check query location, tags, and log.
# 222/544: (21.1025, 84.9537)
#   Dumps error: No matching features. Check query location, tags, and log.
# 223/544: (21.5006, 86.9199)
#   Dumps error: No matching features. Check query location, tags, and log.
# 224/544: (21.4931, 86.6327)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 225/544: (20.2603, 85.8395)
# 226/544: (21.7474, 84.3569)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 227/544: (21.8499, 83.9255)
#   Dumps error: No matching features. Check query location, tags, and log.
# 228/544: (20.4686, 85.8792)
#   Dumps error: No matching features. Check query location, tags, and log.
# 229/544: (21.8019, 83.9714)
#   Dumps error: No matching features. Check query location, tags, and log.
# 230/544: (20.2680, 85.7623)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 231/544: (19.9074, 86.1420)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 232/544: (20.2797, 86.6123)
#   Dumps error: No matching features. Check query location, tags, and log.
# 233/544: (19.8076, 85.8253)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 234/544: (22.1861, 84.5835)
#   Dumps error: No matching features. Check query location, tags, and log.
# 235/544: (19.4427, 83.5873)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 236/544: (22.2309, 84.8679)
#   Dumps error: No matching features. Check query location, tags, and log.
# 237/544: (21.5571, 84.1529)
#   Dumps error: No matching features. Check query location, tags, and log.
# 238/544: (20.9322, 85.2006)
#   Dumps error: No matching features. Check query location, tags, and log.
# 239/544: (10.9167, 79.8333)
#   Dumps error: No matching features. Check query location, tags, and log.
# 240/544: (11.9416, 79.8083)
#   Dumps error: No matching features. Check query location, tags, and log.
# 241/544: (30.7994, 75.4945)
#   Dumps error: No matching features. Check query location, tags, and log.
# 242/544: (31.6340, 74.8723)
#   Dumps error: No matching features. Check query location, tags, and log.
# 243/544: (30.4078, 75.6212)
#   Dumps error: No matching features. Check query location, tags, and log.
# 244/544: (31.1150, 75.8134)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 245/544: (31.8193, 75.2000)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 246/544: (30.2068, 74.9464)
#   Dumps error: No matching features. Check query location, tags, and log.
# 247/544: (30.5683, 74.9704)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 248/544: (30.3097, 75.8893)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 249/544: (30.2855, 75.7927)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 250/544: (30.7802, 75.9984)
#   Dumps error: No matching features. Check query location, tags, and log.
# 251/544: (32.0318, 75.0285)
#   Dumps error: No matching features. Check query location, tags, and log.
# 252/544: (30.5882, 76.8439)
#   Dumps error: No matching features. Check query location, tags, and log.
# 253/544: (30.1810, 76.2291)
#   Dumps error: No matching features. Check query location, tags, and log.
# 254/544: (30.6693, 76.2975)
#   Dumps error: No matching features. Check query location, tags, and log.
# 255/544: (30.5413, 74.8190)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 256/544: (31.7467, 75.1974)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 257/544: (31.2922, 75.5679)
#   Dumps error: No matching features. Check query location, tags, and log.
# 258/544: (30.7006, 76.2221)
#   Dumps error: No matching features. Check query location, tags, and log.
# 259/544: (30.2512, 75.7748)
#   Dumps error: No matching features. Check query location, tags, and log.
# 260/544: (30.2793, 75.8409)
#   Dumps error: No matching features. Check query location, tags, and log.
# 261/544: (30.4520, 74.9655)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 262/544: (30.9090, 75.8516)
#   Dumps error: No matching features. Check query location, tags, and log.
# 263/544: (30.4825, 75.8073)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 264/544: (31.1591, 76.0341)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 265/544: (31.5167, 74.2500)
#   Dumps error: No matching features. Check query location, tags, and log.
# 266/544: (30.4024, 75.6542)
#   Dumps error: No matching features. Check query location, tags, and log.
# 267/544: (31.3799, 76.3600)
#   Dumps error: No matching features. Check query location, tags, and log.
# 268/544: (30.2093, 76.3397)
#   Dumps error: No matching features. Check query location, tags, and log.
# 269/544: (30.4769, 74.7752)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 270/544: (30.2946, 75.0831)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 271/544: (30.4582, 75.6189)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 272/544: (30.3730, 76.2573)
#   Dumps error: No matching features. Check query location, tags, and log.
# 273/544: (30.4384, 75.5852)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 274/544: (31.0917, 76.5290)
#   Dumps error: No matching features. Check query location, tags, and log.
# 275/544: (30.3305, 75.6577)
#   Dumps error: No matching features. Check query location, tags, and log.
# 276/544: (30.4227, 75.6129)
#   Dumps error: No matching features. Check query location, tags, and log.
# 277/544: (26.4691, 74.6390)
#   Dumps error: No matching features. Check query location, tags, and log.
# 278/544: (27.4140, 76.6170)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 279/544: (27.0247, 77.2920)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 280/544: (28.2039, 76.8374)
#   Dumps error: No matching features. Check query location, tags, and log.
# 281/544: (24.8890, 74.6260)
#   Dumps error: No matching features. Check query location, tags, and log.
# 282/544: (26.9155, 75.8190)
#   Dumps error: No matching features. Check query location, tags, and log.
# 283/544: (26.2968, 73.0351)
#   Dumps error: No matching features. Check query location, tags, and log.
# 284/544: (25.1737, 75.8574)
#   Dumps error: No matching features. Check query location, tags, and log.
# 285/544: (25.4552, 73.4194)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 286/544: (24.5787, 73.6863)
#   Dumps error: No matching features. Check query location, tags, and log.
# 287/544: (27.8133, 88.5200)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 288/544: (27.3290, 88.6123)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 289/544: (27.7503, 88.5212)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 290/544: (27.3031, 88.3786)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 291/544: (27.3004, 88.2357)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 292/544: (27.1744, 88.5303)
#   Dumps error: No matching features. Check query location, tags, and log.
# 293/544: (27.3051, 88.3645)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 294/544: (27.2320, 88.4971)
#   Dumps error: No matching features. Check query location, tags, and log.
# 295/544: (13.0837, 80.2702)
#   Dumps error: No matching features. Check query location, tags, and log.
# 296/544: (11.0018, 76.9628)
#   Dumps error: No matching features. Check query location, tags, and log.
# 297/544: (11.5202, 79.3396)
#   Dumps error: No matching features. Check query location, tags, and log.
# 298/544: (12.1456, 78.1132)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 299/544: (13.4309, 80.0821)
#   Dumps error: No matching features. Check query location, tags, and log.
# 300/544: (9.9261, 78.1141)
#   Dumps error: No matching features. Check query location, tags, and log.
# 301/544: (11.7928, 77.8649)
#   Dumps error: No matching features. Check query location, tags, and log.
# 302/544: (8.1782, 77.4326)
#   Dumps error: No matching features. Check query location, tags, and log.
# 303/544: (11.2903, 78.9300)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 304/544: (11.6470, 78.2107)
#   Dumps error: No matching features. Check query location, tags, and log.
# 305/544: (9.9651, 78.7204)
#   Dumps error: No matching features. Check query location, tags, and log.
# 306/544: (10.8071, 78.6881)
#   Dumps error: No matching features. Check query location, tags, and log.
# 307/544: (9.8693, 77.4223)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 308/544: (12.4289, 78.9992)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 309/544: (10.8621, 79.4790)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 310/544: (11.9960, 79.7674)
# 311/544: (8.8274, 78.1294)
#   Dumps error: No matching features. Check query location, tags, and log.
# 312/544: (19.6759, 78.5340)
#   Dumps error: No matching features. Check query location, tags, and log.
# 313/544: (17.3850, 78.4867)
# 314/544: (18.4348, 79.1328)
#   Dumps error: No matching features. Check query location, tags, and log.
# 315/544: (17.2465, 80.1500)
#   Dumps error: No matching features. Check query location, tags, and log.
# 316/544: (17.1486, 78.2887)
#   Dumps error: No matching features. Check query location, tags, and log.
# 317/544: (16.8580, 79.2175)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 318/544: (18.6733, 78.0978)
#   Dumps error: No matching features. Check query location, tags, and log.
# 319/544: (17.5310, 78.2645)
#   Dumps error: No matching features. Check query location, tags, and log.
# 320/544: (18.7596, 79.4740)
#   Dumps error: No matching features. Check query location, tags, and log.
# 321/544: (17.8684, 77.8227)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 322/544: (17.9821, 79.5971)
#   Dumps error: No matching features. Check query location, tags, and log.
# 323/544: (23.8312, 91.2824)
#   Dumps error: No matching features. Check query location, tags, and log.
# 324/544: (27.1753, 78.0098)
#   Dumps error: No matching features. Check query location, tags, and log.
# 325/544: (27.8761, 78.1358)
#   Dumps error: No matching features. Check query location, tags, and log.
# 326/544: (25.4381, 81.8338)
#   Dumps error: No matching features. Check query location, tags, and log.
# 327/544: (24.2055, 82.7715)
#   Dumps error: No matching features. Check query location, tags, and log.
# 328/544: (26.7991, 82.2052)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 329/544: (28.9673, 77.6648)
# 330/544: (28.3670, 79.4304)
#   Dumps error: No matching features. Check query location, tags, and log.
# 331/544: (28.3874, 77.9744)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 332/544: (27.1942, 78.4605)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 333/544: (28.8446, 78.2396)
#   Dumps error: No matching features. Check query location, tags, and log.
# 334/544: (28.7750, 77.4587)
#   Dumps error: No matching features. Check query location, tags, and log.
# 335/544: (26.6678, 83.3642)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 336/544: (28.4671, 77.5138)
#   Dumps error: No matching features. Check query location, tags, and log.
# 337/544: (28.7167, 77.8904)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 338/544: (25.5299, 78.6528)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 339/544: (26.4609, 80.3218)
# 340/544: (28.2063, 77.8764)
#   Dumps error: No matching features. Check query location, tags, and log.
# 341/544: (26.8381, 80.9346)
# 342/544: (27.4956, 77.6856)
#   Dumps error: No matching features. Check query location, tags, and log.
# 343/544: (29.0019, 77.7680)
# 344/544: (28.8797, 78.8095)
#   Dumps error: No matching features. Check query location, tags, and log.
# 345/544: (29.4497, 77.7429)
#   Dumps error: No matching features. Check query location, tags, and log.
# 346/544: (28.5706, 77.3272)
#   Dumps error: No matching features. Check query location, tags, and log.
# 347/544: (29.9857, 77.5041)
#   Dumps error: No matching features. Check query location, tags, and log.
# 348/544: (26.5673, 80.6198)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 349/544: (25.3356, 83.0076)
#   Dumps error: No matching features. Check query location, tags, and log.
# 350/544: (30.3256, 78.0437)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 351/544: (29.2145, 79.5279)
#   Dumps error: No matching features. Check query location, tags, and log.
# 352/544: (29.9384, 78.1453)
#   Dumps error: No matching features. Check query location, tags, and log.
# 353/544: (29.2118, 78.9617)
#   Dumps error: No matching features. Check query location, tags, and log.
# 354/544: (30.1087, 78.2916)
#   Dumps error: No matching features. Check query location, tags, and log.
# 355/544: (28.9707, 79.3973)
#   Dumps error: No matching features. Check query location, tags, and log.
# 356/544: (26.4852, 89.5247)
#   Dumps error: No matching features. Check query location, tags, and log.
# 357/544: (22.3669, 88.2777)
#   Dumps error: No matching features. Check query location, tags, and log.
# 358/544: (23.6871, 86.9747)
#   Dumps error: No matching features. Check query location, tags, and log.
# 359/544: (24.1045, 88.2511)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 360/544: (25.2234, 88.7781)
#   Dumps error: No matching features. Check query location, tags, and log.
# 361/544: (23.1324, 87.2082)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 362/544: (22.7191, 88.4826)
#   Dumps error: No matching features. Check query location, tags, and log.
# 363/544: (23.2496, 87.8682)
#   Dumps error: No matching features. Check query location, tags, and log.
# 364/544: (26.2303, 81.2330)
#   Dumps error: No matching features. Check query location, tags, and log.
# 365/544: (22.3607, 88.4323)
#   Dumps error: No matching features. Check query location, tags, and log.
# 366/544: (23.6612, 87.6962)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 367/544: (22.9024, 88.3893)
#   Dumps error: No matching features. Check query location, tags, and log.
# 368/544: (26.3257, 89.4511)
#   Dumps error: No matching features. Check query location, tags, and log.
# 369/544: (22.6821, 88.2907)
#   Dumps error: No matching features. Check query location, tags, and log.
# 370/544: (27.0378, 88.2632)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 371/544: (23.5350, 87.3380)
#   Dumps error: No matching features. Check query location, tags, and log.
# 372/544: (22.6823, 87.6992)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 373/544: (22.0281, 88.0633)
#   Dumps error: No matching features. Check query location, tags, and log.
# 374/544: (22.5736, 88.3251)
# 375/544: (26.6263, 88.7334)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 376/544: (22.4539, 86.9949)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 377/544: (27.0703, 88.4724)
#   Dumps error: No matching features. Check query location, tags, and log.
# 378/544: (22.9750, 88.4346)
#   Dumps error: No matching features. Check query location, tags, and log.
# 379/544: (22.3431, 87.3013)
#   Dumps error: No matching features. Check query location, tags, and log.
# 380/544: (22.5726, 88.3639)
# 381/544: (23.4058, 88.4959)
#   Dumps error: No matching features. Check query location, tags, and log.
# 382/544: (22.6948, 88.4530)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 383/544: (25.0057, 88.1398)
#   Dumps error: No matching features. Check query location, tags, and log.
# 384/544: (22.4207, 87.3270)
#   Dumps error: No matching features. Check query location, tags, and log.
# 385/544: (23.2021, 86.3229)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 386/544: (25.6167, 88.1167)
#   Dumps error: No matching features. Check query location, tags, and log.
# 387/544: (24.1763, 87.7860)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 388/544: (23.1738, 88.5637)
#   Dumps error: No matching features. Check query location, tags, and log.
# 389/544: (23.6030, 87.1194)
#   Dumps error: No matching features. Check query location, tags, and log.
# 390/544: (22.7247, 88.3434)
#   Dumps error: No matching features. Check query location, tags, and log.
# 391/544: (22.5575, 88.2046)
#   Dumps error: No matching features. Check query location, tags, and log.
# 392/544: (26.7164, 88.4310)
#   Dumps error: No matching features. Check query location, tags, and log.
# 393/544: (23.9081, 87.5277)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 394/544: (22.2897, 87.9256)
#   Dumps error: No matching features. Check query location, tags, and log.
# 395/544: (22.9903, 88.3983)
#   Dumps error: No matching features. Check query location, tags, and log.
# 396/544: (22.4700, 88.1011)
#   Dumps error: No matching features. Check query location, tags, and log.
# 397/544: (14.6819, 77.6006)
#   Dumps error: No matching features. Check query location, tags, and log.
# 398/544: (17.0005, 81.8040)
#   Dumps error: No matching features. Check query location, tags, and log.
# 399/544: (25.8972, 91.8733)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 400/544: (26.7006, 91.9730)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 401/544: (27.2840, 95.6675)
#   Dumps error: No matching features. Check query location, tags, and log.
# 402/544: (26.1346, 87.4654)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 403/544: (25.5603, 84.6632)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 404/544: (24.8033, 84.4110)
#   Dumps error: No matching features. Check query location, tags, and log.
# 405/544: (25.5125, 86.0883)
# ...
# 415/544: (26.6507, 84.9115)
#   Dumps error: No matching features. Check query location, tags, and log.
# 416/544: (25.2203, 86.5161)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 417/544: (25.7759, 87.4088)
#   Dumps error: No matching features. Check query location, tags, and log.
# 418/544: (25.0300, 85.4207)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 419/544: (25.8331, 86.6144)
#   Dumps error: No matching features. Check query location, tags, and log.
# 420/544: (25.7748, 85.8672)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 421/544: (24.9510, 84.0149)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 422/544: (26.1310, 84.3911)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 423/544: (31.2522, 77.0839)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 424/544: (20.4143, 72.8328)
#   Dumps error: No matching features. Check query location, tags, and log.
# 425/544: (20.3819, 72.9037)
#   Dumps error: No matching features. Check query location, tags, and log.
# 426/544: (20.2739, 73.0083)
#   Dumps error: No matching features. Check query location, tags, and log.
# 427/544: (26.6139, 77.2090)
#   Dumps error: No matching features. Check query location, tags, and log.
# 428/544: (15.2860, 74.0943)
#   Dumps error: No matching features. Check query location, tags, and log.
# 429/544: (29.8136, 76.4776)
#   Dumps error: No matching features. Check query location, tags, and log.
# 430/544: (33.1323, 75.5670)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 431/544: (32.7266, 74.8570)
#   Dumps error: No matching features. Check query location, tags, and log.
# 432/544: (32.5620, 75.1200)
#   Dumps error: No matching features. Check query location, tags, and log.
# 433/544: (32.9247, 75.1357)
#   Dumps error: No matching features. Check query location, tags, and log.
# 434/544: (14.7180, 75.3656)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 435/544: (9.3867, 76.5763)
#   Dumps error: No matching features. Check query location, tags, and log.
# 436/544: (8.5241, 76.9366)
# 437/544: (22.0378, 78.8789)
#   Dumps error: No matching features. Check query location, tags, and log.
# 438/544: (20.8111, 77.0132)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 439/544: (11.9146, 79.8083)
#   Dumps error: No matching features. Check query location, tags, and log.
# 440/544: (31.6357, 74.8787)
#   Dumps error: No matching features. Check query location, tags, and log.
# 441/544: (31.9037, 75.2276)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 442/544: (32.3022, 75.6589)
#   Dumps error: No matching features. Check query location, tags, and log.
# 443/544: (30.6250, 76.3854)
#   Dumps error: No matching features. Check query location, tags, and log.
# 444/544: (11.1531, 79.2586)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 445/544: (12.6841, 79.9836)
#   Dumps error: No matching features. Check query location, tags, and log.
# 446/544: (10.4257, 77.8157)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 447/544: (12.7183, 77.8229)
#   Dumps error: No matching features. Check query location, tags, and log.
# 448/544: (12.9647, 79.9840)
#   Dumps error: No matching features. Check query location, tags, and log.
# 449/544: (8.1880, 77.4290)
#   Dumps error: No matching features. Check query location, tags, and log.
# 450/544: (11.4127, 76.7031)
#   Dumps error: No matching features. Check query location, tags, and log.
# 451/544: (9.5206, 78.5185)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 452/544: (11.1672, 77.3473)
#   Dumps error: No matching features. Check query location, tags, and log.
# 453/544: (8.8053, 78.1453)
#   Dumps error: No matching features. Check query location, tags, and log.
# 454/544: (12.9022, 79.0611)
#   Dumps error: No matching features. Check query location, tags, and log.
# 455/544: (17.3606, 78.4741)
# 456/544: (29.0375, 77.3063)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 457/544: (28.4582, 79.4047)
#   Dumps error: No matching features. Check query location, tags, and log.
# 458/544: (27.5958, 78.0524)
#   Dumps error: No matching features. Check query location, tags, and log.
# 459/544: (27.5754, 77.6938)
#   Dumps error: No matching features. Check query location, tags, and log.
# 460/544: (23.6739, 86.9524)
#   Dumps error: No matching features. Check query location, tags, and log.
# 461/544: (22.7665, 88.3709)
#   Dumps error: No matching features. Check query location, tags, and log.
# 462/544: (26.7113, 89.1390)
#   Dumps error: No matching features. Check query location, tags, and log.
# 463/544: (26.8549, 89.3767)
#   Dumps error: No matching features. Check query location, tags, and log.
# 464/544: (26.3133, 89.4871)
#   Dumps error: No matching features. Check query location, tags, and log.
# 465/544: (22.6670, 88.3411)
#   Dumps error: No matching features. Check query location, tags, and log.
# 466/544: (11.6234, 92.7265)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 467/544: (14.7242, 77.4307)
#   Dumps error: No matching features. Check query location, tags, and log.
# 468/544: (13.2026, 79.0032)
#   Dumps error: No matching features. Check query location, tags, and log.
# 469/544: (16.9966, 81.7726)
#   Dumps error: No matching features. Check query location, tags, and log.
# 470/544: (24.8330, 92.7789)
#   Dumps error: No matching features. Check query location, tags, and log.
# 471/544: (22.0966, 83.1119)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 472/544: (21.9587, 83.6635)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 473/544: (21.9041, 83.6582)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 474/544: (21.7612, 83.4108)
#   Dumps error: No matching features. Check query location, tags, and log.
# 475/544: (28.9954, 77.0234)
#   Dumps error: No matching features. Check query location, tags, and log.
# 476/544: (32.2669, 77.1876)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 477/544: (33.2346, 75.2376)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 478/544: (19.1628, 74.8580)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 479/544: (20.9320, 77.7523)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 480/544: (19.8758, 75.3393)
#   Dumps error: No matching features. Check query location, tags, and log.
# 481/544: (19.1668, 73.2368)
#   Dumps error: No matching features. Check query location, tags, and log.
# 482/544: (19.0222, 73.0390)
#   Dumps error: No matching features. Check query location, tags, and log.
# 483/544: (19.2967, 73.0631)
#   Dumps error: No matching features. Check query location, tags, and log.
# 484/544: (19.8036, 72.7559)
#   Dumps error: No matching features. Check query location, tags, and log.
# 485/544: (19.9500, 79.3000)
#   Dumps error: No matching features. Check query location, tags, and log.
# 486/544: (20.9013, 74.7774)
#   Dumps error: No matching features. Check query location, tags, and log.
# 487/544: (19.2183, 73.0864)
#   Dumps error: No matching features. Check query location, tags, and log.
# 488/544: (21.0107, 75.5684)
#   Dumps error: No matching features. Check query location, tags, and log.
# 489/544: (19.8410, 75.8866)
#   Dumps error: No matching features. Check query location, tags, and log.
# 490/544: (16.7050, 74.2433)
#   Dumps error: No matching features. Check query location, tags, and log.
# 491/544: (18.4000, 76.5833)
#   Dumps error: No matching features. Check query location, tags, and log.
# 492/544: (18.0833, 73.4167)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 493/544: (20.5537, 74.5288)
#   Dumps error: No matching features. Check query location, tags, and log.
# 494/544: (19.2952, 72.8544)
# 495/544: (19.0760, 72.8777)
# 496/544: (21.1458, 79.0882)
#   Dumps error: No matching features. Check query location, tags, and log.
# 497/544: (19.1383, 77.3210)
#   Dumps error: No matching features. Check query location, tags, and log.
# 498/544: (19.9975, 73.7898)
#   Dumps error: No matching features. Check query location, tags, and log.
# 499/544: (19.0330, 73.0297)
#   Dumps error: No matching features. Check query location, tags, and log.
# 500/544: (19.2700, 76.7600)
#   Dumps error: No matching features. Check query location, tags, and log.
# 501/544: (18.6279, 73.8007)
# 502/544: (18.5204, 73.8567)
# 503/544: (18.4408, 73.1190)
#   Dumps error: No matching features. Check query location, tags, and log.
# 504/544: (16.8524, 74.5815)
#   Dumps error: No matching features. Check query location, tags, and log.
# 505/544: (17.6599, 75.9064)
#   Dumps error: No matching features. Check query location, tags, and log.
# 506/544: (19.8667, 72.7000)
#   Dumps error: No matching features. Check query location, tags, and log.
# 507/544: (19.2183, 72.9781)
#   Dumps error: No matching features. Check query location, tags, and log.
# 508/544: (19.2167, 73.1500)
#   Dumps error: No matching features. Check query location, tags, and log.
# 509/544: (19.3850, 72.8295)
#   Dumps error: No matching features. Check query location, tags, and log.
# 510/544: (24.8170, 93.9368)
#   Dumps error: No matching features. Check query location, tags, and log.
# 511/544: (25.2029, 92.0344)
#   Dumps error: No matching features. Check query location, tags, and log.
# 512/544: (25.5170, 91.2666)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 513/544: (25.5788, 91.8933)
#   Dumps error: No matching features. Check query location, tags, and log.
# 514/544: (25.5142, 90.2026)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 515/544: (25.8227, 91.8694)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 516/544: (23.7271, 92.7176)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 517/544: (23.4560, 93.3291)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 518/544: (24.2240, 92.6787)
#   Dumps error: No matching features. Check query location, tags, and log.
# 519/544: (22.5411, 92.8926)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 520/544: (22.8660, 92.7330)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 521/544: (23.9292, 92.4900)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 522/544: (22.4837, 92.9745)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 523/544: (23.2980, 92.8460)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 524/544: (25.9091, 93.7260)
#   Dumps error: No matching features. Check query location, tags, and log.
# 525/544: (25.6747, 94.1100)
#   Dumps error: No matching features. Check query location, tags, and log.
# 526/544: (20.8410, 85.0970)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 527/544: (21.4942, 86.9316)
#   Dumps error: No matching features. Check query location, tags, and log.
# 528/544: (21.9407, 86.7198)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 529/544: (20.2961, 85.8245)
# 530/544: (22.0900, 85.3300)
#   Dumps error: No matching features. Check query location, tags, and log.
# 531/544: (21.8200, 83.9200)
#   Dumps error: No matching features. Check query location, tags, and log.
# 532/544: (20.4625, 85.8828)
#   Dumps error: No matching features. Check query location, tags, and log.
# 533/544: (21.8553, 84.0060)
#   Dumps error: No matching features. Check query location, tags, and log.
# 534/544: (21.6333, 85.5833)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 535/544: (19.8974, 86.1140)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 536/544: (20.1280, 85.0961)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 537/544: (20.3167, 86.6167)
#   Dumps error: No matching features. Check query location, tags, and log.
# 538/544: (19.8135, 85.8312)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 539/544: (22.2780, 86.1847)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 540/544: (22.2604, 84.8536)
#   Dumps error: No matching features. Check query location, tags, and log.
# 541/544: (21.4700, 83.9701)
#   Dumps error: No matching features. Check query location, tags, and log.
# 542/544: (21.6367, 85.5775)
#   Industrial error: No matching features. Check query location, tags, and log.
#   Dumps error: No matching features. Check query location, tags, and log.
# 543/544: (20.9483, 85.2332)
#   Dumps error: No matching features. Check query location, tags, and log.
# 544/544: (21.8728, 85.1713)
#   Dumps error: No matching features. Check query location, tags, and log.

# %%
import pandas as pd
import geopandas as gpd
import osmnx as ox
import time

SEARCH_RADIUS = 5000  # 5 km
INPUT_FILE = "Air_Quality_with_OSM_Features_5KM.xlsx"

# 1) Load main data and unique points
df = pd.read_excel(INPUT_FILE, sheet_name="All Data")  # has lat/lon for all sites [file:2]
unique_locs = df[["Latitude", "Longitude"]].drop_duplicates().reset_index(drop=True)

# 2) Empty GeoDataFrame for agriculture (WGS84)
agri_gdf = gpd.GeoDataFrame(columns=["osm_id", "geometry"], crs="EPSG:4326")

def append_features(gdf_base, features):
    if features is None or features.empty:
        return gdf_base
    tmp = features.reset_index()
    osm_ids = tmp["osmid"] if "osmid" in tmp.columns else tmp[tmp.columns[0]]
    out = gpd.GeoDataFrame(
        {"osm_id": osm_ids, "geometry": tmp["geometry"]},
        crs=features.crs
    )
    out = out.drop_duplicates(subset="osm_id")
    return pd.concat([gdf_base, out], ignore_index=True)

# 3) Query only agricultural / green landuse
# farmland, meadows, orchards, vineyards, grass etc. are common agriculture/green tags [web:8][web:12]
agri_tags = {
    "landuse": [
        "farmland", "farm", "meadow", "orchard", "vineyard", "paddy", "grass"
    ]
}

for i, row in unique_locs.iterrows():
    lat, lon = row["Latitude"], row["Longitude"]
    print(f"{i+1}/{len(unique_locs)}: ({lat:.4f}, {lon:.4f})")

    try:
        agri = ox.features_from_point((lat, lon), tags=agri_tags, dist=SEARCH_RADIUS)  # [web:17]
        agri_gdf = append_features(agri_gdf, agri)
    except Exception as e:
        print("  Agriculture error:", e)

    time.sleep(0.5)

# 4) Deduplicate and project to metric CRS
agri_gdf = agri_gdf.drop_duplicates(subset="osm_id").reset_index(drop=True)
agri_gdf_m = agri_gdf.to_crs(3857)

# 5) Save only agriculture layer
agri_gdf_m.to_file("osm_agriculture_5km.gpkg", layer="agriculture", driver="GPKG")
# Out:
# 1/544: (16.4942, 80.5106)
# 2/544: (14.6824, 77.6017)
# 3/544: (13.2162, 79.1051)
# 4/544: (16.7104, 81.1154)
# 5/544: (16.2915, 80.4542)
# 6/544: (14.4753, 78.8217)
# 7/544: (16.9437, 82.2351)
# 8/544: (15.8309, 78.0425)
# 9/544: (14.4494, 79.9874)
# 10/544: (15.5059, 80.0499)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 11/544: (17.0050, 81.7805)
# 12/544: (18.2949, 83.8939)
# 13/544: (13.6316, 79.4232)
# 14/544: (16.5115, 80.6160)
# 15/544: (17.6936, 83.2921)
# 16/544: (18.1141, 83.4114)
# 17/544: (27.0980, 93.6237)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 18/544: (27.1309, 93.7097)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 19/544: (26.4800, 90.5580)
# 20/544: (26.7851, 91.5145)
# 21/544: (27.4845, 94.9019)
# 22/544: (26.5108, 93.9744)
# 23/544: (26.1806, 91.7539)
# 24/544: (27.2864, 95.6702)
# 25/544: (26.3314, 92.7525)
# 26/544: (26.3534, 91.3984)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 27/544: (27.2544, 94.1120)
# 28/544: (24.8333, 92.7789)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 29/544: (26.9835, 94.6394)
# 30/544: (26.6170, 92.7650)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 31/544: (27.4880, 95.3602)
# 32/544: (24.6794, 85.0116)
# 33/544: (25.6906, 85.2090)
# 34/544: (26.1483, 85.3316)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 35/544: (25.6093, 85.1235)
# 36/544: (30.7333, 76.7794)
# 37/544: (22.1638, 82.1366)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 38/544: (21.1888, 81.2849)
# 39/544: (22.5198, 82.6350)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 40/544: (22.2362, 83.3530)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 41/544: (21.2381, 81.6337)
# 42/544: (20.4283, 72.8397)
# 43/544: (28.6139, 77.2090)
# 44/544: (15.5354, 73.9838)
# 45/544: (15.5891, 73.8103)
# 46/544: (15.5558, 73.9773)
# 47/544: (15.3567, 74.1238)
# 48/544: (15.1801, 73.9979)
# 49/544: (15.5431, 74.0586)
# 50/544: (15.4597, 73.9613)
# 51/544: (15.5909, 73.8102)
# 52/544: (15.2729, 73.9583)
# 53/544: (15.4990, 73.8282)
# 54/544: (15.3979, 74.0080)
# 55/544: (15.2283, 74.1513)
# 56/544: (15.2806, 74.0943)
# 57/544: (15.6666, 73.7957)
# 58/544: (15.4892, 74.0703)
# 59/544: (15.3984, 73.8129)
# 60/544: (23.0215, 72.5801)
# 61/544: (21.6293, 72.9945)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 62/544: (23.2233, 72.6492)
# 63/544: (22.4732, 70.0552)
# 64/544: (22.4178, 73.0949)
# 65/544: (19.2310, 82.5482)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 66/544: (22.3053, 70.8028)
# 67/544: (21.2095, 72.8317)
# 68/544: (23.0475, 72.6036)
# 69/544: (22.2973, 73.1943)
# 70/544: (20.3735, 72.9084)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 71/544: (22.9590, 72.6298)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 72/544: (30.3844, 76.7704)
# 73/544: (28.6610, 76.8347)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 74/544: (28.2941, 77.3592)
# 75/544: (28.7932, 76.1391)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 76/544: (28.5920, 76.2720)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 77/544: (28.2055, 76.7953)
# 78/544: (28.4031, 77.3106)
# 79/544: (29.5359, 75.5753)
# 80/544: (28.4646, 77.0299)
# 81/544: (29.8292, 76.4723)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 82/544: (29.3152, 76.3141)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 83/544: (29.7997, 76.3990)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 84/544: (29.7256, 76.9107)
# 85/544: (29.9694, 76.8483)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 86/544: (27.8971, 76.9922)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 87/544: (28.3247, 76.9264)
# 88/544: (28.0438, 76.1062)
# 89/544: (28.0599, 77.3223)
# 90/544: (30.6942, 76.8606)
# 91/544: (29.3913, 76.9772)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 92/544: (28.9011, 76.5802)
# 93/544: (29.6063, 74.9037)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 94/544: (28.9920, 77.0343)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 95/544: (30.1389, 77.3011)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 96/544: (30.9763, 76.7674)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 97/544: (32.2539, 75.6722)
# 98/544: (32.2143, 76.3197)
# 99/544: (32.0131, 76.6688)
# 100/544: (32.2455, 77.1873)
# 101/544: (31.1060, 76.6567)
# 102/544: (30.8379, 76.9602)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 103/544: (30.4366, 77.6247)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 104/544: (31.1042, 77.1710)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 105/544: (31.5163, 76.8840)
# 106/544: (31.5835, 76.2351)
# 107/544: (33.7782, 76.5762)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 108/544: (33.8747, 74.8998)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 109/544: (34.0837, 74.7973)
# 110/544: (22.1641, 85.4078)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 111/544: (23.7953, 86.4310)
# 112/544: (22.8015, 86.2030)
# 113/544: (23.7408, 86.4146)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 114/544: (23.7167, 86.4110)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 115/544: (23.3701, 85.3250)
# 116/544: (22.7464, 85.9169)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 117/544: (23.6752, 86.4896)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 118/544: (16.2904, 75.5916)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 119/544: (12.9768, 77.5901)
# 120/544: (15.8573, 74.5069)
# 121/544: (18.0207, 77.2487)
# 122/544: (16.8333, 75.7176)
# 123/544: (11.9544, 77.1069)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 124/544: (13.0994, 77.3887)
# 125/544: (13.4059, 75.6388)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 126/544: (14.3049, 76.5297)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 127/544: (14.4644, 75.9218)
# 128/544: (15.4167, 75.6816)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 129/544: (17.3297, 76.8343)
# 130/544: (13.0302, 76.1745)
# 131/544: (15.3428, 75.1695)
# 132/544: (13.1805, 78.2669)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 133/544: (15.5748, 76.3118)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 134/544: (12.4215, 75.7388)
# 135/544: (12.6369, 76.7275)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 136/544: (12.8698, 74.8430)
# 137/544: (12.3052, 76.6554)
# 138/544: (16.0547, 76.9004)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 139/544: (12.7200, 77.3184)
# 140/544: (13.9299, 75.5681)
# 141/544: (13.3422, 77.1010)
# 142/544: (13.5270, 74.8732)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 143/544: (16.5744, 76.9254)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 144/544: (9.5007, 76.4124)
# 145/544: (10.0670, 76.2989)
# 146/544: (9.9837, 76.2740)
# 147/544: (11.8764, 75.3738)
# 148/544: (9.9679, 76.2444)
# 149/544: (8.8871, 76.5907)
# 150/544: (9.6287, 76.6455)
# 151/544: (11.2451, 75.7755)
# 152/544: (11.0730, 76.0740)
# 153/544: (10.7874, 76.4742)
# 154/544: (9.2781, 76.9737)
# 155/544: (8.5441, 76.9366)
# 156/544: (10.5270, 76.2146)
# 157/544: (11.7151, 76.1271)
# 158/544: (23.1733, 81.5917)
# 159/544: (23.2585, 77.4020)
# 160/544: (22.0004, 78.8972)
# 161/544: (23.7981, 79.5419)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 162/544: (22.8057, 76.2940)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 163/544: (26.2037, 78.1574)
# 164/544: (22.7204, 75.8682)
# 165/544: (23.1702, 79.9325)
# 166/544: (23.7176, 80.2610)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 167/544: (24.2604, 80.7593)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 168/544: (23.0938, 77.5114)
# 169/544: (23.4579, 75.4191)
# 170/544: (22.6106, 75.6790)
# 171/544: (23.5022, 74.9552)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 172/544: (24.7561, 81.3811)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 173/544: (23.8083, 78.7583)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 174/544: (24.6954, 80.7770)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 175/544: (24.2431, 82.3828)
# 176/544: (23.1885, 75.7717)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 177/544: (20.7618, 77.1921)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 178/544: (19.2016, 73.2005)
# 179/544: (21.1545, 77.6443)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 180/544: (19.8773, 75.3390)
# 181/544: (19.1666, 73.2389)
# 182/544: (19.3026, 73.0588)
# 183/544: (20.0968, 79.5045)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 184/544: (19.2569, 73.1329)
# 185/544: (20.8429, 75.5261)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 186/544: (19.9188, 75.8709)
# 187/544: (16.7028, 74.2405)
# 188/544: (18.3553, 76.7549)
# 189/544: (19.0550, 72.8692)
# 190/544: (21.1498, 79.0821)
# 191/544: (19.0940, 77.4832)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 192/544: (20.0112, 73.7902)
# 193/544: (19.0308, 73.0199)
# 194/544: (18.6279, 73.8010)
# 195/544: (18.5214, 73.8545)
# 196/544: (18.4466, 73.1239)
# 197/544: (17.1727, 74.5868)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 198/544: (17.8499, 75.2763)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 199/544: (19.1943, 72.9702)
# 200/544: (19.0642, 72.8848)
# 201/544: (19.4210, 72.8197)
# 202/544: (24.7991, 93.9364)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 203/544: (25.9045, 91.8695)
# 204/544: (25.1856, 92.0216)
# 205/544: (25.3570, 92.3534)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 206/544: (25.5726, 91.2541)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 207/544: (25.5760, 91.8828)
# 208/544: (25.5126, 90.2172)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 209/544: (25.6710, 91.8991)
# 210/544: (23.8389, 92.6243)
# 211/544: (23.6317, 93.3493)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 212/544: (23.7191, 92.7142)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 213/544: (24.2313, 92.6766)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 214/544: (22.3913, 92.7397)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 215/544: (22.9520, 92.6339)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 216/544: (23.8407, 92.6211)
# 217/544: (23.7564, 92.4515)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 218/544: (22.4880, 92.9813)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 219/544: (23.3053, 92.8455)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 220/544: (25.9041, 93.7178)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 221/544: (25.6619, 94.1019)
# 222/544: (21.1025, 84.9537)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 223/544: (21.5006, 86.9199)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 224/544: (21.4931, 86.6327)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 225/544: (20.2603, 85.8395)
# 226/544: (21.7474, 84.3569)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 227/544: (21.8499, 83.9255)
# 228/544: (20.4686, 85.8792)
# 229/544: (21.8019, 83.9714)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 230/544: (20.2680, 85.7623)
# 231/544: (19.9074, 86.1420)
# 232/544: (20.2797, 86.6123)
# 233/544: (19.8076, 85.8253)
# 234/544: (22.1861, 84.5835)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 235/544: (19.4427, 83.5873)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 236/544: (22.2309, 84.8679)
# 237/544: (21.5571, 84.1529)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 238/544: (20.9322, 85.2006)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 239/544: (10.9167, 79.8333)
# 240/544: (11.9416, 79.8083)
# 241/544: (30.7994, 75.4945)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 242/544: (31.6340, 74.8723)
# 243/544: (30.4078, 75.6212)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 244/544: (31.1150, 75.8134)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 245/544: (31.8193, 75.2000)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 246/544: (30.2068, 74.9464)
# 247/544: (30.5683, 74.9704)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 248/544: (30.3097, 75.8893)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 249/544: (30.2855, 75.7927)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 250/544: (30.7802, 75.9984)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 251/544: (32.0318, 75.0285)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 252/544: (30.5882, 76.8439)
# 253/544: (30.1810, 76.2291)
# 254/544: (30.6693, 76.2975)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 255/544: (30.5413, 74.8190)
# 256/544: (31.7467, 75.1974)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 257/544: (31.2922, 75.5679)
# 258/544: (30.7006, 76.2221)
# 259/544: (30.2512, 75.7748)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 260/544: (30.2793, 75.8409)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 261/544: (30.4520, 74.9655)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 262/544: (30.9090, 75.8516)
# 263/544: (30.4825, 75.8073)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 264/544: (31.1591, 76.0341)
# 265/544: (31.5167, 74.2500)
# 266/544: (30.4024, 75.6542)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 267/544: (31.3799, 76.3600)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 268/544: (30.2093, 76.3397)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 269/544: (30.4769, 74.7752)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 270/544: (30.2946, 75.0831)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 271/544: (30.4582, 75.6189)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 272/544: (30.3730, 76.2573)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 273/544: (30.4384, 75.5852)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 274/544: (31.0917, 76.5290)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 275/544: (30.3305, 75.6577)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 276/544: (30.4227, 75.6129)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 277/544: (26.4691, 74.6390)
# 278/544: (27.4140, 76.6170)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 279/544: (27.0247, 77.2920)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 280/544: (28.2039, 76.8374)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 281/544: (24.8890, 74.6260)
# 282/544: (26.9155, 75.8190)
# 283/544: (26.2968, 73.0351)
# 284/544: (25.1737, 75.8574)
# 285/544: (25.4552, 73.4194)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 286/544: (24.5787, 73.6863)
# 287/544: (27.8133, 88.5200)
# 288/544: (27.3290, 88.6123)
# 289/544: (27.7503, 88.5212)
# 290/544: (27.3031, 88.3786)
# 291/544: (27.3004, 88.2357)
# 292/544: (27.1744, 88.5303)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 293/544: (27.3051, 88.3645)
# 294/544: (27.2320, 88.4971)
# 295/544: (13.0837, 80.2702)
# 296/544: (11.0018, 76.9628)
# 297/544: (11.5202, 79.3396)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 298/544: (12.1456, 78.1132)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 299/544: (13.4309, 80.0821)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 300/544: (9.9261, 78.1141)
# 301/544: (11.7928, 77.8649)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 302/544: (8.1782, 77.4326)
# 303/544: (11.2903, 78.9300)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 304/544: (11.6470, 78.2107)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 305/544: (9.9651, 78.7204)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 306/544: (10.8071, 78.6881)
# 307/544: (9.8693, 77.4223)
# 308/544: (12.4289, 78.9992)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 309/544: (10.8621, 79.4790)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 310/544: (11.9960, 79.7674)
# 311/544: (8.8274, 78.1294)
# 312/544: (19.6759, 78.5340)
# 313/544: (17.3850, 78.4867)
# 314/544: (18.4348, 79.1328)
# 315/544: (17.2465, 80.1500)
# 316/544: (17.1486, 78.2887)
# 317/544: (16.8580, 79.2175)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 318/544: (18.6733, 78.0978)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 319/544: (17.5310, 78.2645)
#   Agriculture error: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=180)
# 320/544: (18.7596, 79.4740)
# 321/544: (17.8684, 77.8227)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 322/544: (17.9821, 79.5971)
# 323/544: (23.8312, 91.2824)
# 324/544: (27.1753, 78.0098)
# 325/544: (27.8761, 78.1358)
# 326/544: (25.4381, 81.8338)
# 327/544: (24.2055, 82.7715)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 328/544: (26.7991, 82.2052)
# 329/544: (28.9673, 77.6648)
# 330/544: (28.3670, 79.4304)
# 331/544: (28.3874, 77.9744)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 332/544: (27.1942, 78.4605)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 333/544: (28.8446, 78.2396)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 334/544: (28.7750, 77.4587)
# 335/544: (26.6678, 83.3642)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 336/544: (28.4671, 77.5138)
# 337/544: (28.7167, 77.8904)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 338/544: (25.5299, 78.6528)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 339/544: (26.4609, 80.3218)
# 340/544: (28.2063, 77.8764)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 341/544: (26.8381, 80.9346)
# 342/544: (27.4956, 77.6856)
# 343/544: (29.0019, 77.7680)
# 344/544: (28.8797, 78.8095)
# 345/544: (29.4497, 77.7429)
# 346/544: (28.5706, 77.3272)
# 347/544: (29.9857, 77.5041)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 348/544: (26.5673, 80.6198)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 349/544: (25.3356, 83.0076)
# 350/544: (30.3256, 78.0437)
# 351/544: (29.2145, 79.5279)
# 352/544: (29.9384, 78.1453)
# 353/544: (29.2118, 78.9617)
# 354/544: (30.1087, 78.2916)
# 355/544: (28.9707, 79.3973)
# 356/544: (26.4852, 89.5247)
# 357/544: (22.3669, 88.2777)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 358/544: (23.6871, 86.9747)
# 359/544: (24.1045, 88.2511)
# 360/544: (25.2234, 88.7781)
# 361/544: (23.1324, 87.2082)
# 362/544: (22.7191, 88.4826)
# 363/544: (23.2496, 87.8682)
# 364/544: (26.2303, 81.2330)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 365/544: (22.3607, 88.4323)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 366/544: (23.6612, 87.6962)
# 367/544: (22.9024, 88.3893)
# 368/544: (26.3257, 89.4511)
# 369/544: (22.6821, 88.2907)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 370/544: (27.0378, 88.2632)
# 371/544: (23.5350, 87.3380)
# 372/544: (22.6823, 87.6992)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 373/544: (22.0281, 88.0633)
# 374/544: (22.5736, 88.3251)
# 375/544: (26.6263, 88.7334)
# 376/544: (22.4539, 86.9949)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 377/544: (27.0703, 88.4724)
# 378/544: (22.9750, 88.4346)
# 379/544: (22.3431, 87.3013)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 380/544: (22.5726, 88.3639)
# 381/544: (23.4058, 88.4959)
# 382/544: (22.6948, 88.4530)
# 383/544: (25.0057, 88.1398)
# 384/544: (22.4207, 87.3270)
# 385/544: (23.2021, 86.3229)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 386/544: (25.6167, 88.1167)
# 387/544: (24.1763, 87.7860)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 388/544: (23.1738, 88.5637)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 389/544: (23.6030, 87.1194)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 390/544: (22.7247, 88.3434)
# 391/544: (22.5575, 88.2046)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 392/544: (26.7164, 88.4310)
# 393/544: (23.9081, 87.5277)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 394/544: (22.2897, 87.9256)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 395/544: (22.9903, 88.3983)
# 396/544: (22.4700, 88.1011)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 397/544: (14.6819, 77.6006)
# 398/544: (17.0005, 81.8040)
# 399/544: (25.8972, 91.8733)
# 400/544: (26.7006, 91.9730)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 401/544: (27.2840, 95.6675)
# 402/544: (26.1346, 87.4654)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 403/544: (25.5603, 84.6632)
# 404/544: (24.8033, 84.4110)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 405/544: (25.5125, 86.0883)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 406/544: (26.7911, 84.5601)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 407/544: (25.2861, 87.1304)
# 408/544: (25.1939, 85.5209)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 409/544: (25.5045, 84.1098)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 410/544: (25.7733, 84.7850)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 411/544: (26.0830, 86.0325)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 412/544: (25.5586, 87.6457)
# 413/544: (26.2984, 87.9467)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 414/544: (26.3583, 85.3282)
# 415/544: (26.6507, 84.9115)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 416/544: (25.2203, 86.5161)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 417/544: (25.7759, 87.4088)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 418/544: (25.0300, 85.4207)
# 419/544: (25.8331, 86.6144)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 420/544: (25.7748, 85.8672)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 421/544: (24.9510, 84.0149)
# 422/544: (26.1310, 84.3911)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 423/544: (31.2522, 77.0839)
# 424/544: (20.4143, 72.8328)
# 425/544: (20.3819, 72.9037)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 426/544: (20.2739, 73.0083)
# 427/544: (26.6139, 77.2090)
# 428/544: (15.2860, 74.0943)
# 429/544: (29.8136, 76.4776)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 430/544: (33.1323, 75.5670)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 431/544: (32.7266, 74.8570)
# 432/544: (32.5620, 75.1200)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 433/544: (32.9247, 75.1357)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 434/544: (14.7180, 75.3656)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 435/544: (9.3867, 76.5763)
# 436/544: (8.5241, 76.9366)
# 437/544: (22.0378, 78.8789)
# 438/544: (20.8111, 77.0132)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 439/544: (11.9146, 79.8083)
# 440/544: (31.6357, 74.8787)
# 441/544: (31.9037, 75.2276)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 442/544: (32.3022, 75.6589)
# 443/544: (30.6250, 76.3854)
# 444/544: (11.1531, 79.2586)
# 445/544: (12.6841, 79.9836)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 446/544: (10.4257, 77.8157)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 447/544: (12.7183, 77.8229)
# 448/544: (12.9647, 79.9840)
# 449/544: (8.1880, 77.4290)
# 450/544: (11.4127, 76.7031)
# 451/544: (9.5206, 78.5185)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 452/544: (11.1672, 77.3473)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 453/544: (8.8053, 78.1453)
# 454/544: (12.9022, 79.0611)
# 455/544: (17.3606, 78.4741)
# 456/544: (29.0375, 77.3063)
# 457/544: (28.4582, 79.4047)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 458/544: (27.5958, 78.0524)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 459/544: (27.5754, 77.6938)
# 460/544: (23.6739, 86.9524)
# 461/544: (22.7665, 88.3709)
# 462/544: (26.7113, 89.1390)
# 463/544: (26.8549, 89.3767)
# 464/544: (26.3133, 89.4871)
# 465/544: (22.6670, 88.3411)
# 466/544: (11.6234, 92.7265)
# 467/544: (14.7242, 77.4307)
# 468/544: (13.2026, 79.0032)
# 469/544: (16.9966, 81.7726)
# 470/544: (24.8330, 92.7789)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 471/544: (22.0966, 83.1119)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 472/544: (21.9587, 83.6635)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 473/544: (21.9041, 83.6582)
# 474/544: (21.7612, 83.4108)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 475/544: (28.9954, 77.0234)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 476/544: (32.2669, 77.1876)
# 477/544: (33.2346, 75.2376)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 478/544: (19.1628, 74.8580)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 479/544: (20.9320, 77.7523)
# 480/544: (19.8758, 75.3393)
# 481/544: (19.1668, 73.2368)
# 482/544: (19.0222, 73.0390)
# 483/544: (19.2967, 73.0631)
# 484/544: (19.8036, 72.7559)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 485/544: (19.9500, 79.3000)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 486/544: (20.9013, 74.7774)
# 487/544: (19.2183, 73.0864)
# 488/544: (21.0107, 75.5684)
# 489/544: (19.8410, 75.8866)
# 490/544: (16.7050, 74.2433)
# 491/544: (18.4000, 76.5833)
# 492/544: (18.0833, 73.4167)
# 493/544: (20.5537, 74.5288)
# 494/544: (19.2952, 72.8544)
# 495/544: (19.0760, 72.8777)
# 496/544: (21.1458, 79.0882)
# 497/544: (19.1383, 77.3210)
# 498/544: (19.9975, 73.7898)
# 499/544: (19.0330, 73.0297)
# 500/544: (19.2700, 76.7600)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 501/544: (18.6279, 73.8007)
# 502/544: (18.5204, 73.8567)
# 503/544: (18.4408, 73.1190)
# 504/544: (16.8524, 74.5815)
# 505/544: (17.6599, 75.9064)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 506/544: (19.8667, 72.7000)
# 507/544: (19.2183, 72.9781)
# 508/544: (19.2167, 73.1500)
# 509/544: (19.3850, 72.8295)
# 510/544: (24.8170, 93.9368)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 511/544: (25.2029, 92.0344)
# 512/544: (25.5170, 91.2666)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 513/544: (25.5788, 91.8933)
# 514/544: (25.5142, 90.2026)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 515/544: (25.8227, 91.8694)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 516/544: (23.7271, 92.7176)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 517/544: (23.4560, 93.3291)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 518/544: (24.2240, 92.6787)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 519/544: (22.5411, 92.8926)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 520/544: (22.8660, 92.7330)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 521/544: (23.9292, 92.4900)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 522/544: (22.4837, 92.9745)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 523/544: (23.2980, 92.8460)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 524/544: (25.9091, 93.7260)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 525/544: (25.6747, 94.1100)
# 526/544: (20.8410, 85.0970)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 527/544: (21.4942, 86.9316)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 528/544: (21.9407, 86.7198)
# 529/544: (20.2961, 85.8245)
# 530/544: (22.0900, 85.3300)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 531/544: (21.8200, 83.9200)
# 532/544: (20.4625, 85.8828)
# 533/544: (21.8553, 84.0060)
# 534/544: (21.6333, 85.5833)
# 535/544: (19.8974, 86.1140)
# 536/544: (20.1280, 85.0961)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 537/544: (20.3167, 86.6167)
# 538/544: (19.8135, 85.8312)
# 539/544: (22.2780, 86.1847)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 540/544: (22.2604, 84.8536)
# 541/544: (21.4700, 83.9701)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 542/544: (21.6367, 85.5775)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 543/544: (20.9483, 85.2332)
#   Agriculture error: No matching features. Check query location, tags, and log.
# 544/544: (21.8728, 85.1713)
#   Agriculture error: No matching features. Check query location, tags, and log.

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

SEARCH_RADIUS = 5000  # m
INPUT_FILE = "Air_Quality_with_OSM_Features_5KM.xlsx"

# a) Read main AQ + weather data
df = pd.read_excel(INPUT_FILE, sheet_name="All Data")  # has Lat/Long, AQ, weather, counts etc. [file:2]

# b) Turn stations into GeoDataFrame (WGS84)
gdf_pts = gpd.GeoDataFrame(
    df.copy(),
    geometry=gpd.points_from_xy(df["Longitude"], df["Latitude"]),
    crs="EPSG:4326"
)

# c) Reproject points to metric CRS (same as saved OSM layers)
gdf_pts = gdf_pts.to_crs(3857)

# d) Load OSM feature layers (already in 3857 from your previous step)
roads_gdf_m = gpd.read_file("osm_roads_5km.gpkg", layer="roads")
inds_gdf_m  = gpd.read_file("osm_industries_5km.gpkg", layer="industries")
dumps_gdf_m = gpd.read_file("osm_dumps_5km.gpkg", layer="dumps")
agri_gdf_m  = gpd.read_file("osm_agriculture_5km.gpkg", layer="agriculture")

# %%
def nearest_distance(points, targets, max_dist=None):
    """
    Compute distance (meters) from each point to nearest geometry in targets.
    points and targets must be in the same projected CRS (e.g. EPSG:3857).
    """
    if targets.empty:
        return pd.Series([None] * len(points), index=points.index)

    # GeoSeries of point geometries
    pts = points.geometry

    # spatial index
    sidx = targets.sindex

    # query_nearest: pass GeoSeries, get back arrays of indices
    # (for shapely 2.x via geopandas 0.13+)
    idx_src, idx_tgt = sidx.nearest(pts, return_distance=False)

    # idx_src: indices in pts; idx_tgt: corresponding indices in targets
    # Build a Series mapping point index -> nearest target index
    nearest_target_idx = pd.Series(idx_tgt, index=pts.index[idx_src])

    # Now compute distances
    dists = []
    for i in pts.index:
        if i not in nearest_target_idx.index:
            dists.append(None)
            continue
        j = nearest_target_idx.loc[i]
        d = pts.loc[i].distance(targets.geometry.iloc[j])
        if max_dist is not None and d > max_dist:
            dists.append(None)
        else:
            dists.append(d)

    return pd.Series(dists, index=pts.index)


# Add distance columns (meters)
gdf_pts["dist_nearest_road_m"]   = nearest_distance(gdf_pts, roads_gdf_m)
gdf_pts["dist_nearest_ind_m"]    = nearest_distance(gdf_pts, inds_gdf_m)
gdf_pts["dist_nearest_dump_m"]   = nearest_distance(gdf_pts, dumps_gdf_m)
gdf_pts["dist_nearest_agri_m"]   = nearest_distance(gdf_pts, agri_gdf_m)

# %%
# Start from gdf_pts with distance columns already added
df_full = gdf_pts.copy()

# Drop geometry only (for CSV / ML)
df_full = df_full.drop(columns="geometry")

# Just save everything
df_full.to_csv("Air Quality Dataset 2021-2023.csv", index=False)
